wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])

# %% [markdown]
# Set the Information of the Process (temperature, pressure, wi0, wi8, L, D)

# %%
T=298.15
p=1E5
nc=3 # number of components
L=1E-4 # estimated thickness of the ASD
wi0=np.asarray([0.49999,0.49999,0.00002]) # Weight fractions of the components API, polymer, water at t=0
wi8=np.asarray([0.00001,0.00001,0.99998]) # Weight fractions of the components API, polymer, water at t=8.T
Mi= np.asarray([357.79,65000,16.02])

# %% [markdown]
# Creating a vector which holds the MS diffusion coefficients

# %%
Dvec =np.asarray([1E-5,2E-12,8E-12])

# %% [markdown]
# Calculate the values for the concentrations inside the ASD

# %%
import numpy as np
from numpy import array
import scipy as sp
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()
from scipy.optimize import curve_fit

texp=array([5,15,30,60,90,120,150,180,210,240,270,300])
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
Mi= np.asarray([357.79,65000,16.02])
mobile= np.asarray([True,True,True])
wi_8 =np.asarray([0.0001,0.0001,0.9998])
Dvec =np.asarray([1E-1,2E-12,8E-1])

nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2

def Conc_ASD(wAPI_B,w0API_B,w0API_ASD,wPol_B,w0Pol_B,w0Pol_ASD,wH2O_B,w0H2O_B,w0H2O_ASD,m_B,m_ASD):
   
    wAPI_ASD= (w0API_B-wAPI_B)*(m_B/m_ASD)+w0API_ASD
    wPol_ASD=(w0Pol_B-wPol_B)*(m_B/m_ASD)+w0Pol_ASD
    wH2O_ASD= (w0H2O_B-wH2O_B)*(m_B/m_ASD)+w0H2O_ASD
    wges_ASD= wAPI_ASD + wPol_ASD + wH2O_ASD
    return wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD


def plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    plt.plot(texp, wAPI_ASD,'ro')
    plt.plot(texp,wPol_ASD,'go')
    plt.plot(texp,wH2O_ASD,'bo')
    plt.plot(texp,wges_ASD,'yo')
    plt.xlabel("t [s]")
    plt.ylabel("wi [-]")

def fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    def funcline(x,a,b):
        return a*x+b
    def funcquad(x,a,b,c):
        return a*x**2+b*x+c
    popt_API, pcov_API= curve_fit(funcline,texp,wAPI_ASD)
    plt.plot(texp,funcline(texp,*popt_API),'r-')
    qopt_API, qcov_API= curve_fit(funcline,texp,wAPI_ASD)
    plt.plot(texp,funcline(texp,*qopt_API),'r--')
    popt_Pol, pcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    plt.plot(texp,funcline(texp,*popt_Pol),'g-')
    qopt_Pol, qcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    plt.plot(texp,funcline(texp,*qopt_Pol),'g--')
    popt_H2O, pcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    plt.plot(texp,funcline(texp,*popt_H2O),'b-')
    qopt_H2O, qcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    plt.plot(texp,funcline(texp,*qopt_H2O),'b--')
  #  MSopt, MScov = curve_fit(Diffusion_MS,texp,wAPI_ASD)
  #  plt.plot(texp,Diffusion_MS(texp,*MSopt),'r*')
    
def Choose_ASD(ASD_L,ASD_DL):
    if ASD_L == 1 and ASD_DL == 0.3:
        wIND = wINDL1D03
        w0IND = 0.3
        wPol = wPolL1D03
        wH2O = wH2OL1D03
        mASD = mASDL1D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L ==1 and ASD_DL ==0.5:
        wIND = wINDL1D05
        w0IND = 0.5
        wPol = wPolL1D05
        wH2O = wH2OL1D05
        mASD = mASDL1D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L ==1 and ASD_DL == 0.7:
        wIND = wINDL1D07
        w0IND = 0.7
        wPol = wPolL1D07
        wH2O = wH2OL1D07
        mASD = mASDL1D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    elif ASD_L == 0.25 and ASD_DL== 0.3:
        wIND = wINDL25D03
        w0IND = 0.3
        wPol = wPolL25D03
        wH2O = wH2OL25D03
        mASD = mASDL25D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L == 0.25 and ASD_DL ==0.5:
        wIND = wINDL25D05
        w0IND = 0.5
        wPol = wPolL25D05
        wH2O = wH2OL25D05
        mASD = mASDL25D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L == 0.25 and ASD_DL == 0.7:
        wIND = wINDL25D07
        w0IND = 0.7
        wPol = wPolL25D07
        wH2O = wH2OL25D07
        mASD = mASDL25D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    else: print("Bitte gültige Werte für Länge und Drugload eingeben")
    w0Pol = 1 - w0IND  
    L = ASD_L * 10E-4 

   

    wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD=Conc_ASD(wIND,0,w0IND,wPol,0,w0Pol,wH2O,1,0,mB_0,mASD)
    plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    # wt= Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    def fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
        def Diffforfit(t,D1,D2,D3):
            Dscale=1E14
            Dvec=np.asarray([D1,D2,D3])/Dscale
            # Dvec=np.fmax(Dvec,1E-16)
            wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
            return wt[:,0]
        wexp=np.hstack((wAPI_ASD,wPol_ASD,wH2O_ASD))
        Dscale=1E14
        qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wAPI_ASD)
        Dvecopt=qopt_H2O/Dscale
        print(Dvecopt)
        wt=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile)
        # qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,p0=(1,1,1))

    # plt.plot(texp,funcline(texp,*qopt_H2O),'b--')    
        plt.plot(t,wt[:,0],'r-')
        plt.plot(t,wt[:,1],'g-')
        plt.plot(t,wt[:,2],'b-')
    
    fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)


Choose_ASD(1,0.5)
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1691912 seconds ----------------
# ------------- Initialization and postprocessing took 0.0158386 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.01009 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0192084 seconds ----------------
# ------------- Initialization and postprocessing took 0.0023921 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0130613 seconds ----------------
# ------------- Initialization and postprocessing took 0.0055935 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0235087 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025901 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0130967 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009999 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0140559 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0160025 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0136991 seconds ----------------
# ------------- Initialization and postprocessing took 0.0024316 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0194181 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010331 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0090018 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0214058 seconds ----------------
# ------------- Initialization and postprocessing took 0.0030257 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0143777 seconds ----------------
# ------------- Initialization and postprocessing took 0.0098205 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.013192 seconds ----------------
# ------------- Initialization and postprocessing took 0.0056998 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0141144 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0128809 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020239 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0194349 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018658 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0147602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020565 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0132697 seconds ----------------
# ------------- Initialization and postprocessing took 0.0030399 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0321165 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029059 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0187815 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020251 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0160509 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018654 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0264508 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0140496 seconds ----------------
# ------------- Initialization and postprocessing took 0.002252 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0127906 seconds ----------------
# ------------- Initialization and postprocessing took 0.0059019 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0207635 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0164504 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011123 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0128068 seconds ----------------
# ------------- Initialization and postprocessing took 0.001286 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0215548 seconds ----------------
# ------------- Initialization and postprocessing took 0.0097661 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0141762 seconds ----------------
# ------------- Initialization and postprocessing took 0.0038488 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0078847 seconds ----------------
# ------------- Initialization and postprocessing took 0.0063013 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0190286 seconds ----------------
# ------------- Initialization and postprocessing took 0.0001581 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0167575 seconds ----------------
# ------------- Initialization and postprocessing took 0.0063188 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0410603 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013819 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.039308 seconds ----------------
# ------------- Initialization and postprocessing took 0.0073096 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0536546 seconds ----------------
# ------------- Initialization and postprocessing took 0.0058908 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0375358 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009961 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.029867 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012921 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0378383 seconds ----------------
# ------------- Initialization and postprocessing took 0.0038786 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0241807 seconds ----------------
# ------------- Initialization and postprocessing took 0.0041937 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0330305 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019984 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0482322 seconds ----------------
# ------------- Initialization and postprocessing took 0.0038473 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0339872 seconds ----------------
# ------------- Initialization and postprocessing took 0.008772 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0771222 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029644 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0262002 seconds ----------------
# ------------- Initialization and postprocessing took 0.004689 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1299428 seconds ----------------
# ------------- Initialization and postprocessing took 0.0114016 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1205032 seconds ----------------
# ------------- Initialization and postprocessing took 0.0066637 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0672293 seconds ----------------
# ------------- Initialization and postprocessing took 0.0040767 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0815791 seconds ----------------
# ------------- Initialization and postprocessing took 0.0035763 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0534344 seconds ----------------
# ------------- Initialization and postprocessing took 0.0046267 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0620308 seconds ----------------
# ------------- Initialization and postprocessing took 0.0047019 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0693457 seconds ----------------
# ------------- Initialization and postprocessing took 0.0093692 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0560445 seconds ----------------
# ------------- Initialization and postprocessing took 0.0024791 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.113264 seconds ----------------
# ------------- Initialization and postprocessing took 0.0055912 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1676567 seconds ----------------
# ------------- Initialization and postprocessing took 0.0109325 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0643905 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027471 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0840594 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020243 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.043018 seconds ----------------
# ------------- Initialization and postprocessing took 0.0125695 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.056433 seconds ----------------
# ------------- Initialization and postprocessing took 0.0061728 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0540619 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012054 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0528703 seconds ----------------
# ------------- Initialization and postprocessing took 0.003228 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0463025 seconds ----------------
# ------------- Initialization and postprocessing took 0.0040443 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0496756 seconds ----------------
# ------------- Initialization and postprocessing took 0.0088807 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0637674 seconds ----------------
# ------------- Initialization and postprocessing took 0.002031 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0445982 seconds ----------------
# ------------- Initialization and postprocessing took 0.0033475 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0878087 seconds ----------------
# ------------- Initialization and postprocessing took 0.0098684 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.059954 seconds ----------------
# ------------- Initialization and postprocessing took 0.0078839 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0564967 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011782 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0535955 seconds ----------------
# ------------- Initialization and postprocessing took 0.0055064 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0955549 seconds ----------------
# ------------- Initialization and postprocessing took 0.0034024 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0525838 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009867 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0606949 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009963 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0506026 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0543762 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009991 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0849491 seconds ----------------
# ------------- Initialization and postprocessing took 0.0072634 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0485143 seconds ----------------
# ------------- Initialization and postprocessing took 0.0001034 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0536405 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019951 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0526135 seconds ----------------
# ------------- Initialization and postprocessing took 0.0033932 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0535602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0073206 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0636475 seconds ----------------
# ------------- Initialization and postprocessing took 0.0045405 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0660734 seconds ----------------
# ------------- Initialization and postprocessing took 0.0044404 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0631611 seconds ----------------
# ------------- Initialization and postprocessing took 0.0046098 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0530465 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018586 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.045538 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018866 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.056952 seconds ----------------
# ------------- Initialization and postprocessing took 0.0136933 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0505826 seconds ----------------
# ------------- Initialization and postprocessing took 0.0004395 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0528136 seconds ----------------
# ------------- Initialization and postprocessing took 0.010866 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0501587 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010205 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0466039 seconds ----------------
# ------------- Initialization and postprocessing took 0.0082993 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0938665 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020302 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0591108 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025773 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0722862 seconds ----------------
# ------------- Initialization and postprocessing took 0.0028142 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0604262 seconds ----------------
# ------------- Initialization and postprocessing took 0.0141048 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0699203 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009978 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0678102 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009986 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0556335 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020624 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0482334 seconds ----------------
# ------------- Initialization and postprocessing took 0.007041 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0450622 seconds ----------------
# ------------- Initialization and postprocessing took 0.001034 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0655847 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018981 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.113719 seconds ----------------
# ------------- Initialization and postprocessing took 0.0038769 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0466336 seconds ----------------
# ------------- Initialization and postprocessing took 0.0065605 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0496633 seconds ----------------
# ------------- Initialization and postprocessing took 0.0045373 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0527578 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011745 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0998442 seconds ----------------
# ------------- Initialization and postprocessing took 0.0152281 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0576237 seconds ----------------
# ------------- Initialization and postprocessing took 0.0006067 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0544431 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010677 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0882819 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011906 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0532954 seconds ----------------
# ------------- Initialization and postprocessing took 0.00415 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0666497 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009337 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0867966 seconds ----------------
# ------------- Initialization and postprocessing took 0.0036662 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0510565 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011838 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1147553 seconds ----------------
# ------------- Initialization and postprocessing took 0.0016678 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0848064 seconds ----------------
# ------------- Initialization and postprocessing took 0.0064843 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0748626 seconds ----------------
# ------------- Initialization and postprocessing took 0.001162 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0519857 seconds ----------------
# ------------- Initialization and postprocessing took 0.0001874 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0624122 seconds ----------------
# ------------- Initialization and postprocessing took 0.0062097 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0593944 seconds ----------------
# ------------- Initialization and postprocessing took 0.0035641 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0831641 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013127 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0848882 seconds ----------------
# ------------- Initialization and postprocessing took 0.000961 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0735755 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025964 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0470126 seconds ----------------
# ------------- Initialization and postprocessing took 0.0066528 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0900033 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012769 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0669026 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009984 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0459253 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015465 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0513805 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005965 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0969742 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029105 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0490398 seconds ----------------
# ------------- Initialization and postprocessing took 0.0024295 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0504239 seconds ----------------
# ------------- Initialization and postprocessing took 0.0021899 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0490194 seconds ----------------
# ------------- Initialization and postprocessing took 0.0037547 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.085726 seconds ----------------
# ------------- Initialization and postprocessing took 0.0024742 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0531203 seconds ----------------
# ------------- Initialization and postprocessing took 0.0031649 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0663189 seconds ----------------
# ------------- Initialization and postprocessing took 0.0067604 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0896807 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013788 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0436315 seconds ----------------
# ------------- Initialization and postprocessing took 0.0073644 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0599011 seconds ----------------
# ------------- Initialization and postprocessing took 0.0072091 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0513425 seconds ----------------
# ------------- Initialization and postprocessing took 0.003513 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0744505 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018748 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0479394 seconds ----------------
# ------------- Initialization and postprocessing took 0.0001762 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0622904 seconds ----------------
# ------------- Initialization and postprocessing took 0.0054008 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0445626 seconds ----------------
# ------------- Initialization and postprocessing took 0.0146776 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0970404 seconds ----------------
# ------------- Initialization and postprocessing took 0.0041976 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0506964 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011084 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0957383 seconds ----------------
# ------------- Initialization and postprocessing took 0.0033594 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0730912 seconds ----------------
# ------------- Initialization and postprocessing took 0.0083251 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1045399 seconds ----------------
# ------------- Initialization and postprocessing took 0.003419 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0851339 seconds ----------------
# ------------- Initialization and postprocessing took 0.0115735 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0563946 seconds ----------------
# ------------- Initialization and postprocessing took 0.0060493 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0551211 seconds ----------------
# ------------- Initialization and postprocessing took 0.0064654 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0535368 seconds ----------------
# ------------- Initialization and postprocessing took 0.0100831 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.083004 seconds ----------------
# ------------- Initialization and postprocessing took 0.0088234 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.052001 seconds ----------------
# ------------- Initialization and postprocessing took 0.0052546 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0566494 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012503 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0947065 seconds ----------------
# ------------- Initialization and postprocessing took 0.0034281 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1489762 seconds ----------------
# ------------- Initialization and postprocessing took 0.0069814 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0579199 seconds ----------------
# ------------- Initialization and postprocessing took 0.00783 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0778646 seconds ----------------
# ------------- Initialization and postprocessing took 0.0051199 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0872636 seconds ----------------
# ------------- Initialization and postprocessing took 0.0056635 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.057904 seconds ----------------
# ------------- Initialization and postprocessing took 0.0001755 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0811185 seconds ----------------
# ------------- Initialization and postprocessing took 0.0006664 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0914252 seconds ----------------
# ------------- Initialization and postprocessing took 0.0039397 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0447249 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018916 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0798066 seconds ----------------
# ------------- Initialization and postprocessing took 0.0067896 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1149536 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019774 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1028265 seconds ----------------
# ------------- Initialization and postprocessing took 0.0100084 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0654771 seconds ----------------
# ------------- Initialization and postprocessing took 0.0037456 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.066073 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009999 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0927406 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005258 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0913288 seconds ----------------
# ------------- Initialization and postprocessing took 0.0090337 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0629334 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009116 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0625147 seconds ----------------
# ------------- Initialization and postprocessing took 0.0033459 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0693287 seconds ----------------
# ------------- Initialization and postprocessing took 0.0037258 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0482652 seconds ----------------
# ------------- Initialization and postprocessing took 0.001083 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.060354 seconds ----------------
# ------------- Initialization and postprocessing took 0.0066182 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0533006 seconds ----------------
# ------------- Initialization and postprocessing took 0.0067397 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1246248 seconds ----------------
# ------------- Initialization and postprocessing took 0.0058177 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1140629 seconds ----------------
# ------------- Initialization and postprocessing took 0.0024641 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0607253 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020071 seconds----------------
# [1.26362509e-07 2.54848530e-09 6.50092130e-08]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0728147 seconds ----------------
# ------------- Initialization and postprocessing took 0.0073541 seconds----------------

# %% [markdown]
# First model

# %%
mobile= np.asarray([True,True,True])
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2    
import time

wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)

color1 = "#99CDE9"
color2 = "#F08208"
color3 = "#99CC00"

fig,ax=origin_like.subplots()

origin_like.plot(ax,t,wt[:,0],"c-")
origin_like.plot(ax,t,wt[:,1],"r-")
origin_like.plot(ax,t,wt[:,2],"b-")
origin_like.plot(ax,texp,wINDL1D03,"co")
origin_like.plot(ax,texp,wPolL1D03,"ro")
origin_like.set_xlabel(ax,"t","s")
origin_like.set_ylabel(ax,"w_i","-")
origin_like.set_ticks(ax,0,300,0,1)
plt.show()
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0336925 seconds ----------------
# ------------- Initialization and postprocessing took 0.006494 seconds----------------

# %% [markdown]
# First try of an fitting function: leastsq

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import scipy as sc
import matplotlib.pyplot as plt

x= np.array([1,3,4,5,7,8,12,15,19,24])
y = np.array([3,7,14,25,41,48,59,73,78,95])

plt.plot(x,y,'ro')

def funcline (x,a,b):
    return a*x+b
def funcquad (x,a,b,c):
    return a*x**2+b*x+c   

X= np.linspace(x.min(),x.max(),50)
popt, pcov = curve_fit(funcline,x,y)
print(popt)
plt.plot(x,funcline(x, *popt))

qopt, qcov= curve_fit(funcquad,x,y)
plt.plot(x,funcquad(x,*qopt))
# Out:
# [4.12009419 3.92307692]
