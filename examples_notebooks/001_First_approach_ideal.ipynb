# %% [markdown]
# # First approach on ideal modelling

# %% [markdown]
# 1. Implementing all necessary packages

# %%
import numpy as np
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()

# %% [markdown]
# import the input data for diffusionpy from master thesis

# %%
from numpy import array
mH2O0= 0,5
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wPolL1D03= array([5.1687E-06,8.11419000e-06,1.16988000e-05,1.82872000e-05,2.43481000e-05,2.97692000e-05,3.50846000e-05,3.91787000e-05,4.30863000e-05,4.68326000e-05,4.92799000e-05,5.08487000e-05])
wH2OL1D03= array([9.99994489e-01,9.99991222e-01,9.99986998e-01,9.99979094e-01,9.99971590e-01,9.99964725e-01,9.99957805e-01,9.99951993e-01,9.99946538e-01,9.99940884e-01,9.99937297e-01,9.99934266e-01])
wINDL1D05= array([5.95664000e-07,1.11906000e-06,1.85585000e-06,3.47314000e-06,4.42371000e-06,6.09469000e-06,7.07050000e-06,8.10867000e-06,9.81494000e-06,1.09211000e-05,1.22759000e-05,1.35512000e-05])
wPolL1D05=array([7.34838000e-07,1.07111000e-06,1.42408000e-06,1.86380000e-06,1.99883000e-06,2.04584000e-06,2.04858000e-06,1.96896000e-06,2.13912000e-06,2.19015000e-06,2.16470000e-06,2.24988000e-06])
wH2OL1D05=array([9.99998669e-01,9.99997810e-01,9.99996720e-01,9.99994663e-01,9.99993577e-01,9.99991859e-01,9.99990881e-01,9.99989922e-01, 9.99988046e-01,9.99986889e-01,9.99985559e-01,9.99984199e-01])
wINDL1D07= array([6.52542000e-07,1.19485000e-06,2.98026000e-06,3.78514000e-06,5.18938000e-06,6.62873000e-06,8.19091000e-06,9.45838000e-06,1.10233000e-05,1.23274000e-05,1.34266000e-05,1.46734000e-05])
wPolL1D07=array([5.43067000e-07,2.32437000e-07,-1.31550000e-07,2.39324000e-07,3.19550000e-07,3.11173000e-07,3.24043000e-07,2.83174000e-07,1.86216000e-07,3.26324000e-07,7.64666000e-07,2.35801000e-07])
wH2OL1D07=array([9.99998804e-01,9.99998573e-01,9.99997151e-01,9.99995976e-01,9.99994491e-01,9.99993060e-01,9.99991485e-01,9.99990258e-01,9.99988790e-01,9.99987346e-01,9.99985809e-01,9.99985091e-01])
wINDL25D03=array([3.38334000e-07,7.27514000e-07,1.13529000e-06,2.29403000e-06,3.20807000e-06,4.11030000e-06,4.97144000e-06,5.76267000e-06,6.66612000e-06,7.58597000e-06,8.33222000e-06,9.19885000e-06])
wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])

# %% [markdown]
# Set the Information of the Process (temperature, pressure, wi0, wi8, L, D)

# %%
T=298.15
p=1E5
nc=3 # number of components
L=1E-4 # estimated thickness of the ASD
wi0=np.asarray([0.49999,0.49999,0.00002]) # Weight fractions of the components API, polymer, water at t=0
wi8=np.asarray([0.00001,0.00001,0.99998]) # Weight fractions of the components API, polymer, water at t=8.T
Mi= np.asarray([357.79,65000,16.02])

# %% [markdown]
# Creating a vector which holds the MS diffusion coefficients

# %%
Dvec =np.asarray([1E-5,2E-12,8E-12])

# %% [markdown]
# Calculate the values for the concentrations inside the ASD

# %%
import numpy as np
from numpy import array
import scipy as sp
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()
from scipy.optimize import curve_fit

texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wPolL1D03= array([5.1687E-06,8.11419000e-06,1.16988000e-05,1.82872000e-05,2.43481000e-05,2.97692000e-05,3.50846000e-05,3.91787000e-05,4.30863000e-05,4.68326000e-05,4.92799000e-05,5.08487000e-05])
wH2OL1D03= array([9.99994489e-01,9.99991222e-01,9.99986998e-01,9.99979094e-01,9.99971590e-01,9.99964725e-01,9.99957805e-01,9.99951993e-01,9.99946538e-01,9.99940884e-01,9.99937297e-01,9.99934266e-01])
wINDL1D05= array([5.95664000e-07,1.11906000e-06,1.85585000e-06,3.47314000e-06,4.42371000e-06,6.09469000e-06,7.07050000e-06,8.10867000e-06,9.81494000e-06,1.09211000e-05,1.22759000e-05,1.35512000e-05])
wPolL1D05=array([7.34838000e-07,1.07111000e-06,1.42408000e-06,1.86380000e-06,1.99883000e-06,2.04584000e-06,2.04858000e-06,1.96896000e-06,2.13912000e-06,2.19015000e-06,2.16470000e-06,2.24988000e-06])
wH2OL1D05=array([9.99998669e-01,9.99997810e-01,9.99996720e-01,9.99994663e-01,9.99993577e-01,9.99991859e-01,9.99990881e-01,9.99989922e-01, 9.99988046e-01,9.99986889e-01,9.99985559e-01,9.99984199e-01])
wINDL1D07= array([6.52542000e-07,1.19485000e-06,2.98026000e-06,3.78514000e-06,5.18938000e-06,6.62873000e-06,8.19091000e-06,9.45838000e-06,1.10233000e-05,1.23274000e-05,1.34266000e-05,1.46734000e-05])
wPolL1D07=array([5.43067000e-07,2.32437000e-07,-1.31550000e-07,2.39324000e-07,3.19550000e-07,3.11173000e-07,3.24043000e-07,2.83174000e-07,1.86216000e-07,3.26324000e-07,7.64666000e-07,2.35801000e-07])
wH2OL1D07=array([9.99998804e-01,9.99998573e-01,9.99997151e-01,9.99995976e-01,9.99994491e-01,9.99993060e-01,9.99991485e-01,9.99990258e-01,9.99988790e-01,9.99987346e-01,9.99985809e-01,9.99985091e-01])
wINDL25D03=array([3.38334000e-07,7.27514000e-07,1.13529000e-06,2.29403000e-06,3.20807000e-06,4.11030000e-06,4.97144000e-06,5.76267000e-06,6.66612000e-06,7.58597000e-06,8.33222000e-06,9.19885000e-06])
wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
Mi= np.asarray([357.79,65000,16.02])
mobile= np.asarray([True,False,True])
wi_8 =np.asarray([0.0001,0.0001,0.9998])
Dvec =np.asarray([1E-1,2E-12,8E-1])
Dvec=np.asarray([327081.87865031627,386294.20602000307,644379.7545334897])/1E14

Dvec=np.asarray([244258.29860143378,
632465.849552949,
762682.380133524])/1E14
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2

def Conc_ASD(wAPI_B,w0API_B,w0API_ASD,wPol_B,w0Pol_B,w0Pol_ASD,wH2O_B,w0H2O_B,w0H2O_ASD,m_B,m_ASD):
   
    wAPI_ASD= (w0API_B-wAPI_B)*(m_B/m_ASD)+w0API_ASD
    wPol_ASD=(w0Pol_B-wPol_B)*(m_B/m_ASD)+w0Pol_ASD
    wH2O_ASD= (w0H2O_B-wH2O_B)*(m_B/m_ASD)+w0H2O_ASD
    wges_ASD= wAPI_ASD + wPol_ASD + wH2O_ASD
    return wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD


def plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    plt.plot(texp, wAPI_ASD,'ro')
    plt.plot(texp,wPol_ASD,'go')
    plt.plot(texp,wH2O_ASD,'bo')
    plt.plot(texp,wges_ASD,'yo')
    plt.xlabel("t [s]")
    plt.ylabel("wi [-]")

def fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    def funcline(x,a,b):
        return a*x+b
    def funcquad(x,a,b,c):
        return a*x**2+b*x+c
    # popt_API, pcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*popt_API),'r-')
    # qopt_API, qcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*qopt_API),'r--')
    # popt_Pol, pcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*popt_Pol),'g-')
    # qopt_Pol, qcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*qopt_Pol),'g--')
    # popt_H2O, pcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*popt_H2O),'b-')
    # qopt_H2O, qcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*qopt_H2O),'b--')
  #  MSopt, MScov = curve_fit(Diffusion_MS,texp,wAPI_ASD)
  #  plt.plot(texp,Diffusion_MS(texp,*MSopt),'r*')
    
def Choose_ASD(ASD_L,ASD_DL):
    if ASD_L == 1 and ASD_DL == 0.3:
        wIND = wINDL1D03
        w0IND = 0.3
        wPol = wPolL1D03
        wH2O = wH2OL1D03
        mASD = mASDL1D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L ==1 and ASD_DL ==0.5:
        wIND = wINDL1D05
        w0IND = 0.5
        wPol = wPolL1D05
        wH2O = wH2OL1D05
        mASD = mASDL1D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L ==1 and ASD_DL == 0.7:
        wIND = wINDL1D07
        w0IND = 0.7
        wPol = wPolL1D07
        wH2O = wH2OL1D07
        mASD = mASDL1D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    elif ASD_L == 0.25 and ASD_DL== 0.3:
        wIND = wINDL25D03
        w0IND = 0.3
        wPol = wPolL25D03
        wH2O = wH2OL25D03
        mASD = mASDL25D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L == 0.25 and ASD_DL ==0.5:
        wIND = wINDL25D05
        w0IND = 0.5
        wPol = wPolL25D05
        wH2O = wH2OL25D05
        mASD = mASDL25D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L == 0.25 and ASD_DL == 0.7:
        wIND = wINDL25D07
        w0IND = 0.7
        wPol = wPolL25D07
        wH2O = wH2OL25D07
        mASD = mASDL25D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    else: print("Bitte gültige Werte für Länge und Drugload eingeben")
    w0Pol = 1 - w0IND  
    L = ASD_L * 10E-4 
    

    wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD=Conc_ASD(wIND,0,w0IND,wPol,0,w0Pol,wH2O,1,0,mB_0,mASD)

    
    #fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    # wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    # wt= Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    def fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
        def Diffforfit(t,D1,D2,D3):
            Dscale=1E13 #Hilfsvariable
            Dvec=np.asarray([D1,D2,D3])/Dscale #Normieren der Diffusionskoeffs (DKs)
            # Dvec=np.fmax(Dvec,1E-16)
            print(D1) #Ausgeben der normierten DKs
            print(D2)
            print(D3)
            wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True)
            return np.hstack((wt[:,0],wt[:,1])) #Rückgabe von wAPI_ASD und wPol_ASD
        wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-6,1E12),p0=(0.1,0.1,100)) #Einsetzen von normierten DKs in Solver
        Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dvecopt)
        

        return Dvecopt
        
        

        
    Dvecopt= fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-8,1E-8])
    wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True) #Aufrufen der Diffusionsgleichung mit optimierten Dks
    DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
    
    return wt, Dvecopt, wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z





def Plot_Fit (ASD_L,DL):
    list1 =[]
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    plt.plot(t,wt[:,0],'r-') #Plotten der angepassten Kurven
    plt.plot(t,wt[:,1],'g-')
    plt.plot(t,wt[:,2],'b-')
    plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    xDL =np.linspace(0.3,0.7,3)
    for D in xDL:
         wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD,DL_z= Choose_ASD(ASD_L,D)
         list1.append(b)
    Dvec_array= np.array(list1)
    fig,axis =plt.subplots()
    axis.plot(xDL,Dvec_array[0,:],'r*')
    axis.plot(xDL,Dvec_array[1,:],'g*')
    axis.plot(xDL,Dvec_array[2,:],'b*')
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    fig,ax =plt.subplots()
    z= np.linspace(0,ASD_L,20)
    ax.plot(z,DL_z[0,0:20],'y-',label ='t = 0s')
    ax.plot(z,DL_z[19,0:20],'c-',label ='t = 4500s')
    ax.plot(z,DL_z[39,0:20],'m-',label ='t = 9000s')
    ax.plot(z,DL_z[59,0:20],'k-',label ='t = 13500s')
    ax.plot(z,DL_z[79,0:20],'g-',label ='t = 18000s')
    ax.set_xlabel('z [mm]')
    ax.set_ylabel('Drugload []')
    ax.legend()
   


    
#Choose_ASD(1,0.7)
Plot_Fit (1,0.7)
# Out:
# 0.1
# 0.1
# 100.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1037224 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019698 seconds----------------
# 0.1000000149011612
# 0.1
# 100.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0937472 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019702 seconds----------------
# 0.1
# 0.1000000149011612
# 100.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0888966 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009637 seconds----------------
# 0.1
# 0.1
# 100.00000149011612
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0909174 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009781 seconds----------------
# 0.06019814003689274
# 1.3260730581260354
# 73.17331520762669
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0658656 seconds ----------------
# ------------- Initialization and postprocessing took 0.001992 seconds----------------
# 0.06019815493805394
# 1.3260730581260354
# 73.17331520762669
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0648428 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020035 seconds----------------
# 0.06019814003689274
# 1.3260730778860639
# 73.17331520762669
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0659505 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020042 seconds----------------
# 0.06019814003689274
# 1.3260730581260354
# 73.17331629799405
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0658223 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009972 seconds----------------
# 0.05851375494978799
# 3.82974723862538
# 73.17328341416322
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0659591 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010122 seconds----------------
# 0.058513769850949186
# 3.82974723862538
# 73.17328341416322
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0669529 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009961 seconds----------------
# 0.05851375494978799
# 3.829747295693061
# 73.17328341416322
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0648261 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019954 seconds----------------
# 0.05851375494978799
# 3.82974723862538
# 73.17328450453012
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0687892 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010244 seconds----------------
# 0.058489586001148564
# 4.445037977707757
# 73.17324861262284
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0698085 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009965 seconds----------------
# 0.05848960090230976
# 4.445037977707757
# 73.17324861262284
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0698451 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009611 seconds----------------
# 0.058489586001148564
# 4.445038043943984
# 73.17324861262284
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0688165 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.058489586001148564
# 4.445037977707757
# 73.17324970298921
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0688146 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029631 seconds----------------
# 0.058441825350977535
# 4.444999473025189
# 73.17302783763856
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0668226 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019951 seconds----------------
# 0.05844184025213873
# 4.444999473025189
# 73.17302783763856
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0689322 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020136 seconds----------------
# 0.058441825350977535
# 4.444999539260842
# 73.17302783763856
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0688482 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019909 seconds----------------
# 0.058441825350977535
# 4.444999473025189
# 73.17302892800164
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0689216 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009967 seconds----------------
# 0.05834556189002087
# 5.352319282299009
# 73.17270382228418
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0637814 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020189 seconds----------------
# 0.058417760265080186
# 5.350129590118908
# 73.17294689070926
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0678092 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020047 seconds----------------
# 0.058435812763809734
# 5.349581638867231
# 73.17300761668714
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0708107 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019949 seconds----------------
# 0.05844033705106881
# 5.34943979174476
# 73.1730228325428
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0608109 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019905 seconds----------------
# 0.058441518701062005
# 5.34933810298294
# 73.17302680639833
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0630601 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029916 seconds----------------
# 0.05844182534847551
# 4.835624863530371
# 73.17302783763037
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.064825 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019916 seconds----------------
# 0.058441825350641415
# 4.542655820676077
# 73.17302783763748
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0689408 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019688 seconds----------------
# 0.05844184025180261
# 4.542655820676077
# 73.17302783763748
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0668227 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019616 seconds----------------
# 0.058441825350641415
# 4.542655888366924
# 73.17302783763748
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0678501 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009973 seconds----------------
# 0.058441825350641415
# 4.542655820676077
# 73.17302892800056
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0678523 seconds ----------------
# ------------- Initialization and postprocessing took 0.000973 seconds----------------
# 0.05844180191641204
# 4.542655804533709
# 73.17302775994486
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0690148 seconds ----------------
# ------------- Initialization and postprocessing took 0.000965 seconds----------------
# 0.05844181681757323
# 4.542655804533709
# 73.17302775994486
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0709609 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.05844180191641204
# 4.542655872224556
# 73.17302775994486
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0668203 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019983 seconds----------------
# 0.05844180191641204
# 4.542655804533709
# 73.17302885030794
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0708345 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019949 seconds----------------
# [5.84418019e-15 4.54265580e-13 7.31730278e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0718402 seconds ----------------
# ------------- Initialization and postprocessing took 0.0059304 seconds----------------

# %% [markdown]
# Fitting the sorption Data und Calculation of the Sorption MS Coefficients

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from diffusionpy import Diffusion_MS
from scipy.optimize import curve_fit

tsorpL1D03= np.array([0,1001,2002,3003,4004,5005,6005,7007,8008,9008,10009,11010,12010,13012,14012,15013,16015,17015,18016])
wwsorpL1D03 = np.array([1.4E-5,8.35E-3,1.443E-2,1.947E-2,2.39E-2,2.79E-2,3.158E-2,3.5E-2,3.821E-2,4.125E-2,4.413E-2,4.689E-2,4.952E-2,5.204E-2,5.447E-2,5.681E-2,5.906E-2,6.124E-2,6.336E-2])
tsorpL1D05= np.array([0,1005,2006,3007,4009,5010,6011,7013,8014,9016,10017,11018,12019,13021,14022,15023,16024,17026,18027])
wwsorpL1D05= np.array([3.1E-6,5.1E-3,7.4E-3,9E-3,1.029E-2,1.114E-2,1.238E-2,1.327E-2,1.408E-2,1.484E-2,1.554E-2,1.62E-2,1.682E-2,1.742E-2,1.798E-2,1.852E-2,1.904E-2,1.954E-2,2.002E-2])
tsorpL1D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL1D07= np.array([0,1.82E-3,2.59E-3,3.08E-3,3.46E-3,3.77E-3,4.04E-3,4.29E-3,4.51E-3,4.71E-3,4.91E-3,5.09E-3,5.26E-3,5.42E-3,5.58E-3,5.73E-3])
tsorpL25D03= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D03= np.array([6.6E-6,4.128E-2,6.4E-2,8.099E-2,9.493E-2,0.10691,0.11746,0.12691,0.13548,0.14328,0.15036,0.15677,0.1625,0.1676,0.1721,0.17607,0.17955,0.18263,0.18535])
tsorpL25D05= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D05= np.array([1.1E-4,2.438E-2,3.352E-2,3.902E-2,4.284E-2,4.581E-2,4.825E-2,5.048E-2,5.25E-2,5.435E-2,5.606E-2,5.773E-2,5.913E-2,6.056E-2,6.194E-2,6.314E-2,6.429E-2,6.556E-2,6.656E-2])
tsorpL25D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL25D07= np.array([0,8.1E-3,1.106E-2,1.32E-2,1.494E-2,1.642E-2,1.771E-2,1.887E-2,1.994E-2,2.0904E-2,2.1806E-2,2.2643E-2,2.343E-2,2.417E-2,2.487E-2,2.554E-2])
wi_0= np.array([0.9999,0.0001])
mobile =np.array([False, True])
Mi0= np.asarray([357.79,65000,16.02])



def Choose_Sorp(L_ASD,DL_ASD):
    if L_ASD == 1 and DL_ASD == 0.3:
        t_sorp= tsorpL1D03
        ww_sorp= wwsorpL1D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==1 and DL_ASD ==0.5: 
        t_sorp= tsorpL1D05
        ww_sorp= wwsorpL1D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==1 and DL_ASD ==0.7: 
        t_sorp= tsorpL1D07
        ww_sorp= wwsorpL1D07
        wi_8 = np.array([0.9405,0.0505])
    elif L_ASD == 0.25 and DL_ASD == 0.3:
        t_sorp= tsorpL25D03
        ww_sorp= wwsorpL25D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==0.25 and DL_ASD ==0.5: 
        t_sorp= tsorpL25D05
        ww_sorp= wwsorpL25D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==0.25 and DL_ASD ==0.7: 
        t_sorp= tsorpL25D07
        ww_sorp= wwsorpL25D07
        wi_8 = np.array([0.9405,0.0505])
    else: print('Bitte gültige Länge und Drugload eingeben!')
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    L= L_ASD*10E-4
    w_APIPol= 1-ww_sorp
    M_APIPol= 1/((DL_ASD/Mi0[0])+((1-DL_ASD)/Mi0[1])) #Mittlere molare Masse
    Mi = np.array([M_APIPol,16.02])
    from numpy import array

    def fit_Diff_Sorp (ww_sorp,w_APIPol):
        def Diff_for_fit(t,D_sorp):
            Dscale=1E13 #Hilfsvariable
            Dsorp_norm=np.array([D_sorp])/Dscale #Normieren des Diffusionskoeffs (DKs)
            print(Dsorp_norm) #Ausgeben des normierten DKs
            ww=Diffusion_MS(t,L,Dsorp_norm,wi_0,wi_8,Mi,mobile) #Ouput ist 2D
            return ww[:,1] #Rückgabe von w_H2O in ww
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diff_for_fit,t_sorp,ww_sorp,bounds=(1E-6,1E10),p0=(10)) #Einsetzen von normierten DKs in Solver
        Dsorpopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dsorpopt)
        
        return Dsorpopt
    Dsorpopt= fit_Diff_Sorp(ww_sorp,w_APIPol)
    ww= Diffusion_MS(t,L,Dsorpopt,wi_0,wi_8,Mi,mobile)
    return ww, Dsorpopt, t_sorp, ww_sorp
     



def plot_sorp (t_sorp, ww_sorp):
    plt.plot(t_sorp,ww_sorp,'bo')
    plt.xlabel('t [s]')
    plt.ylabel('ww [-]')

def plot_fit_sorp (L,DL):
    list =[]
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(L,DL)
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    plt.plot(t, ww [:,1],'b-')
    plot_sorp (t_sorp, ww_sorp)
    xL = np.linspace(0.3,0.7,3)
    for D in xL:
        a,b,c,d = Choose_Sorp(L,D)
        list.append(b)
    Dvec_sorp= np.array(list)
    fig,axis = plt.subplots()
    axis.plot(xL,Dvec_sorp,'b*')

    



plot_fit_sorp(1,0.3)
# Out:
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139626 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139616 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149548 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010031 seconds----------------
# [2.00000003e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139402 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020171 seconds----------------
# [4.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0189176 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [4.00000006e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.018949 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009979 seconds----------------
# [7.91354038e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209448 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019926 seconds----------------
# [7.9135405e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0170553 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.91282872e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0189287 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029801 seconds----------------
# [7.91336247e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169573 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019909 seconds----------------
# [7.91349591e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0201048 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [7.91352927e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0199786 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.9135376e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179473 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019725 seconds----------------
# [7.91353969e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0199469 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009973 seconds----------------
# [7.91354021e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0219304 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009968 seconds----------------
# [7.91354034e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0189174 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [7.91354038e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209158 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010249 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129558 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129306 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019976 seconds----------------
# [2.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169223 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009975 seconds----------------
# [2.00000003e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.013967 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019902 seconds----------------
# [4.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0171697 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [4.00000006e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179202 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009982 seconds----------------
# [7.91354038e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179449 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010051 seconds----------------
# [7.9135405e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0189494 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009969 seconds----------------
# [7.91282872e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.017951 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.91336247e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179453 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010044 seconds----------------
# [7.91349591e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169532 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019952 seconds----------------
# [7.91352927e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179509 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.9135376e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179164 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019975 seconds----------------
# [7.91353969e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179196 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009975 seconds----------------
# [7.91354021e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.017952 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009975 seconds----------------
# [7.91354034e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179522 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.91354038e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0189488 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009657 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129659 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129654 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009966 seconds----------------
# [2.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.013963 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019948 seconds----------------
# [2.00000003e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149601 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019937 seconds----------------
# [2.72907567e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159576 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009973 seconds----------------
# [2.72907571e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159562 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019944 seconds----------------
# [2.86052802e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0141496 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019431 seconds----------------
# [2.86052807e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139628 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019935 seconds----------------
# [2.86052627e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149601 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [2.86052631e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169569 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009942 seconds----------------
# [2.86052275e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009977 seconds----------------
# [2.86052279e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0160994 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019945 seconds----------------
# [2.86051572e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149604 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009978 seconds----------------
# [2.86051576e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169601 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019899 seconds----------------
# [2.86050166e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009976 seconds----------------
# [2.8605017e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149591 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [2.86047354e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.01496 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009978 seconds----------------
# [2.86047358e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159577 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009973 seconds----------------
# [2.86041729e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009979 seconds----------------
# [2.86041734e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159561 seconds ----------------
# ------------- Initialization and postprocessing took 0.001995 seconds----------------
# [2.86036105e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149617 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.86036109e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139634 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019592 seconds----------------
# [2.86030481e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149631 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.86030485e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0150789 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019946 seconds----------------
# [2.86024856e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149605 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009972 seconds----------------
# [2.86024861e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159697 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009859 seconds----------------
# [2.86013608e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139553 seconds ----------------
# ------------- Initialization and postprocessing took 0.001 seconds----------------
# [2.86013612e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149603 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.8600236e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0161119 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.86002364e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0140987 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [2.85979864e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159561 seconds ----------------
# ------------- Initialization and postprocessing took 0.001995 seconds----------------
# [2.85979868e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149604 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [2.85934874e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149612 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009998 seconds----------------
# [2.85934878e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149473 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009784 seconds----------------
# [2.85844901e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139628 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019895 seconds----------------
# [2.85844905e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139629 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019617 seconds----------------
# [2.85664983e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149852 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009976 seconds----------------
# [2.85664988e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.014968 seconds ----------------
# ------------- Initialization and postprocessing took 0.001986 seconds----------------
# [2.85305262e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149603 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019945 seconds----------------
# [2.85305266e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169912 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009975 seconds----------------
# [2.84586271e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.014929 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.84586275e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169548 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009977 seconds----------------
# [2.83150103e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139627 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019952 seconds----------------
# [2.83150107e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149613 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019951 seconds----------------
# [2.81670235e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149604 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.81670239e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179653 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019823 seconds----------------
# [2.7945518e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.01496 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019949 seconds----------------
# [2.79455184e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149598 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019949 seconds----------------
# [2.7944631e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0159574 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020003 seconds----------------
# [2.79446314e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149238 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009974 seconds----------------
# [2.79183757e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0179566 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010188 seconds----------------
# [2.79380672e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0219424 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019952 seconds----------------
# [2.79429901e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169205 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019972 seconds----------------
# [2.79442208e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209445 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019935 seconds----------------
# [2.79445285e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0160423 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009133 seconds----------------
# [2.79446054e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149575 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020286 seconds----------------
# [2.79446246e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149915 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019758 seconds----------------
# [2.79446294e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0149602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.79446306e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0151293 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.79446309e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.013963 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019695 seconds----------------
# [2.7944631e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0169547 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009977 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129653 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019954 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129654 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009979 seconds----------------
# [9.62347065e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139664 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [9.62347079e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139631 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019606 seconds----------------
# [9.59368502e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129666 seconds ----------------
# ------------- Initialization and postprocessing took 0.001993 seconds----------------
# [9.61602424e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0119602 seconds ----------------
# ------------- Initialization and postprocessing took 0.000998 seconds----------------
# [9.62160905e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0129646 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020199 seconds----------------
# [9.62300525e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0119682 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [9.6233543e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0139627 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019939 seconds----------------
# [9.62344156e-13]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 13 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=95'>96</a>     fig,axis = plt.subplots()
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=96'>97</a>     axis.plot(xL,Dvec_sorp,'b*')
# --> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=102'>103</a> plot_fit_sorp(1,0.3)
#
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 13 line 9
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=90'>91</a> xL = np.linspace(0.3,0.7,3)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=91'>92</a> for D in xL:
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=92'>93</a>     a,b,c,d = Choose_Sorp(L,D)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=93'>94</a>     list.append(b)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=94'>95</a> Dvec_sorp= np.array(list)
#
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 13 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=68'>69</a>     print(Dsorpopt)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=70'>71</a>     return Dsorpopt
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=71'>72</a> Dsorpopt= fit_Diff_Sorp(ww_sorp,w_APIPol)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=72'>73</a> ww= Diffusion_MS(t,L,Dsorpopt,wi_0,wi_8,Mi,mobile)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=73'>74</a> return ww, Dsorpopt, t_sorp, ww_sorp
#
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 13 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=64'>65</a>     return ww[:,1] #Rückgabe von w_H2O in ww
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=65'>66</a> Dscale=1E13
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=66'>67</a> qopt_H2O, qcov_H2O= curve_fit(Diff_for_fit,t_sorp,ww_sorp,bounds=(1E-6,1E10),p0=(10)) #Einsetzen von normierten DKs in Solver
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=67'>68</a> Dsorpopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=68'>69</a> print(Dsorpopt)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:974, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     971 if 'max_nfev' not in kwargs:
#     972     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 974 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                     **kwargs)
#     977 if not res.success:
#     978     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:938, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     934     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     935                           max_nfev, x_scale, diff_step)
#     937 elif method == 'trf':
# --> 938     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     939                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     940                  tr_options.copy(), verbose)
#     942 elif method == 'dogbox':
#     943     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:338, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338 f_new = fun(x_new)
#     339 nfev += 1
#     341 step_h_norm = norm(step_h)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:828, in least_squares.<locals>.fun_wrapped(x)
#     827 def fun_wrapped(x):
# --> 828     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:507, in _lightweight_memoizer.<locals>._memoized_func(params)
#     504 if np.all(_memoized_func.last_params == params):
#     505     return _memoized_func.last_val
# --> 507 val = f(params)
#     509 if _memoized_func.last_params is None:
#     510     _memoized_func.last_params = np.copy(params)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _wrap_func.<locals>.func_wrapped(params)
#     522 def func_wrapped(params):
# --> 523     return func(xdata, *params) - ydata
#
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 13 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=61'>62</a> Dsorp_norm=np.array([D_sorp])/Dscale #Normieren des Diffusionskoeffs (DKs)
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=62'>63</a> print(Dsorp_norm) #Ausgeben des normierten DKs
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=63'>64</a> ww=Diffusion_MS(t,L,Dsorp_norm,wi_0,wi_8,Mi,mobile) #Ouput ist 2D
#      <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X15sZmlsZQ%3D%3D?line=64'>65</a> return ww[:,1]
#
# File ~\diffusionpy\diffusionpy\Stefan_Maxwell_segmental.py:50, in Diffusion_MS(tint, L, Dvec, wi0, wi8, Mi, mobile, full_output, dlnai_dlnwi, **kwargs)
#      14 def Diffusion_MS(tint,L,Dvec,wi0,wi8,Mi,mobile,full_output=False,dlnai_dlnwi=None,**kwargs):
#      15     """
#      16     Method that computes the multi-component diffusion kinetics
#      17
#    (...)
#      48         diffusionpy.D_Matrix
#      49     """
# ---> 50     @njit(['f8[::1](f8, f8[:],f8[:], f8[:,:,::1,::1], i8[::1], i8[::1], f8[::1], f8[:,:], b1, f8[::1],f8[:,:],f8[:,::1])'],cache=True)
#      51     def ode(t,x,tint,THFaktor,mobiles,immobiles,Mi,D,allflux,wi0,dmuext,wiB):
#      52         """change in the weight fraction with time"""
#      53         def vanishing_check(dwvdt,wv):# Realitätscheck gegen neg. Konz.
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\decorators.py:241, in _jit.<locals>.wrapper(func)
#     239     with typeinfer.register_dispatcher(disp):
#     240         for sig in sigs:
# --> 241             disp.compile(sig)
#     242         disp.disable_compile()
#     243 return disp
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\dispatcher.py:946, in Dispatcher.compile(self, sig)
#     944     return existing.entry_point
#     945 # Try to load from disk cache
# --> 946 cres = self._cache.load_overload(sig, self.targetctx)
#     947 if cres is not None:
#     948     self._cache_hits[sig] += 1
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\caching.py:635, in Cache.load_overload(self, sig, target_context)
#     633 target_context.refresh()
#     634 with self._guard_against_spurious_io_errors():
# --> 635     return self._load_overload(sig, target_context)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\caching.py:644, in Cache._load_overload(self, sig, target_context)
#     642 data = self._cache_file.load(key)
#     643 if data is not None:
# --> 644     data = self._impl.rebuild(target_context, data)
#     645 return data
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\caching.py:395, in CompileResultCacheImpl.rebuild(self, target_context, payload)
#     391 def rebuild(self, target_context, payload):
#     392     """
#     393     Returns the unserialized CompileResult
#     394     """
# --> 395     return compiler.CompileResult._rebuild(target_context, *payload)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\compiler.py:242, in CompileResult._rebuild(cls, target_context, libdata, fndesc, env, signature, objectmode, lifted, typeann, reload_init, referenced_envs)
#     239     for fn in reload_init:
#     240         fn()
# --> 242 library = target_context.codegen().unserialize_library(libdata)
#     243 cfunc = target_context.get_executable(library, fndesc, env)
#     244 cr = cls(target_context=target_context,
#     245          typing_context=target_context.typing_context,
#     246          library=library,
#    (...)
#     258          referenced_envs=referenced_envs,
#     259          )
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\codegen.py:1158, in Codegen.unserialize_library(self, serialized)
#    1157 def unserialize_library(self, serialized):
# -> 1158     return self._library_class._unserialize(self, serialized)
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\numba\core\codegen.py:939, in CPUCodeLibrary._unserialize(cls, codegen, state)
#     937 self.enable_object_caching()
#     938 self._set_compiled_object(object_code)
# --> 939 self._shared_module = ll.parse_bitcode(shared_bitcode)
#     940 self._finalize_final_module()
#     941 # Load symbols from cache
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\module.py:38, in parse_bitcode(bitcode, context)
#      36 bufsize = len(bitcode)
#      37 with ffi.OutputString() as errmsg:
# ---> 38     mod = ModuleRef(ffi.lib.LLVMPY_ParseBitcode(
#      39         context, buf, bufsize, errmsg), context)
#      40     if errmsg:
#      41         mod.close()
#
# File c:\Users\Justin\AppData\Local\Programs\Python\Python311\Lib\site-packages\llvmlite\binding\ffi.py:190, in _lib_fn_wrapper.__call__(self, *args, **kwargs)
#     188 def __call__(self, *args, **kwargs):
#     189     with self._lock:
# --> 190         return self._cfn(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# First model

# %%
mobile= np.asarray([True,True,True])
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2    
import time

wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)

color1 = "#99CDE9"
color2 = "#F08208"
color3 = "#99CC00"

fig,ax=origin_like.subplots()

origin_like.plot(ax,t,wt[:,0],"c-")
origin_like.plot(ax,t,wt[:,1],"r-")
origin_like.plot(ax,t,wt[:,2],"b-")
origin_like.plot(ax,texp,wINDL1D03,"co")
origin_like.plot(ax,texp,wPolL1D03,"ro")
origin_like.set_xlabel(ax,"t","s")
origin_like.set_ylabel(ax,"w_i","-")
origin_like.set_ticks(ax,0,300,0,1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Justin\diffusionpy\examples_notebooks\001_First_approach_ideal.ipynb Cell 15 line 6
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X20sZmlsZQ%3D%3D?line=2'>3</a> t=np.linspace(0,texp[-1]**0.5,nt)**2
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X20sZmlsZQ%3D%3D?line=3'>4</a> import time
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> color1 = "#99CDE9"
#       <a href='vscode-notebook-cell:/c%3A/Users/Justin/diffusionpy/examples_notebooks/001_First_approach_ideal.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> color2 = "#F08208"
#
# NameError: name 'L' is not defined

# %% [markdown]
# First try of an fitting function: leastsq

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import scipy as sc
import matplotlib.pyplot as plt

x= np.array([1,3,4,5,7,8,12,15,19,24])
y = np.array([3,7,14,25,41,48,59,73,78,95])

plt.plot(x,y,'ro')

def funcline (x,a,b):
    return a*x+b
def funcquad (x,a,b,c):
    return a*x**2+b*x+c   

X= np.linspace(x.min(),x.max(),50)
popt, pcov = curve_fit(funcline,x,y)
print(popt)
plt.plot(x,funcline(x, *popt))

qopt, qcov= curve_fit(funcquad,x,y)
plt.plot(x,funcquad(x,*qopt))
# Out:
# [4.12009419 3.92307692]
