wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])

# %% [markdown]
# Set the Information of the Process (temperature, pressure, wi0, wi8, L, D)

# %%
T=298.15
p=1E5
nc=3 # number of components
L=1E-4 # estimated thickness of the ASD
wi0=np.asarray([0.49999,0.49999,0.00002]) # Weight fractions of the components API, polymer, water at t=0
wi8=np.asarray([0.00001,0.00001,0.99998]) # Weight fractions of the components API, polymer, water at t=8.T
Mi= np.asarray([357.79,65000,16.02])

# %% [markdown]
# Creating a vector which holds the MS diffusion coefficients

# %%
Dvec =np.asarray([1E-5,2E-12,8E-12])

# %% [markdown]
# Calculate the values for the concentrations inside the ASD

# %%
import numpy as np
from numpy import array
import scipy as sp
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()
from scipy.optimize import curve_fit

texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wPolL1D03= array([5.1687E-06,8.11419000e-06,1.16988000e-05,1.82872000e-05,2.43481000e-05,2.97692000e-05,3.50846000e-05,3.91787000e-05,4.30863000e-05,4.68326000e-05,4.92799000e-05,5.08487000e-05])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
Mi= np.asarray([357.79,65000,16.02])
mobile= np.asarray([True,True,True])
wi_8 =np.asarray([0.0001,0.0001,0.9998])
Dvec =np.asarray([1E-1,2E-12,8E-1])
Dvec=np.asarray([327081.87865031627,386294.20602000307,644379.7545334897])/1E14

Dvec=np.asarray([244258.29860143378,
632465.849552949,
762682.380133524])/1E14
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2

def Conc_ASD(wAPI_B,w0API_B,w0API_ASD,wPol_B,w0Pol_B,w0Pol_ASD,wH2O_B,w0H2O_B,w0H2O_ASD,m_B,m_ASD):
   
    wAPI_ASD= (w0API_B-wAPI_B)*(m_B/m_ASD)+w0API_ASD
    wPol_ASD=(w0Pol_B-wPol_B)*(m_B/m_ASD)+w0Pol_ASD
    wH2O_ASD= (w0H2O_B-wH2O_B)*(m_B/m_ASD)+w0H2O_ASD
    wges_ASD= wAPI_ASD + wPol_ASD + wH2O_ASD
    return wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD


def plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    plt.plot(texp, wAPI_ASD,'ro')
    plt.plot(texp,wPol_ASD,'go')
    plt.plot(texp,wH2O_ASD,'bo')
    plt.plot(texp,wges_ASD,'yo')
    plt.xlabel("t [s]")
    plt.ylabel("wi [-]")

def fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    def funcline(x,a,b):
        return a*x+b
    def funcquad(x,a,b,c):
        return a*x**2+b*x+c
    # popt_API, pcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*popt_API),'r-')
    # qopt_API, qcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*qopt_API),'r--')
    # popt_Pol, pcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*popt_Pol),'g-')
    # qopt_Pol, qcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*qopt_Pol),'g--')
    # popt_H2O, pcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*popt_H2O),'b-')
    # qopt_H2O, qcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*qopt_H2O),'b--')
  #  MSopt, MScov = curve_fit(Diffusion_MS,texp,wAPI_ASD)
  #  plt.plot(texp,Diffusion_MS(texp,*MSopt),'r*')
    
def Choose_ASD(ASD_L,ASD_DL):
    if ASD_L == 1 and ASD_DL == 0.3:
        wIND = wINDL1D03
        w0IND = 0.3
        wPol = wPolL1D03
        wH2O = wH2OL1D03
        mASD = mASDL1D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L ==1 and ASD_DL ==0.5:
        wIND = wINDL1D05
        w0IND = 0.5
        wPol = wPolL1D05
        wH2O = wH2OL1D05
        mASD = mASDL1D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L ==1 and ASD_DL == 0.7:
        wIND = wINDL1D07
        w0IND = 0.7
        wPol = wPolL1D07
        wH2O = wH2OL1D07
        mASD = mASDL1D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    elif ASD_L == 0.25 and ASD_DL== 0.3:
        wIND = wINDL25D03
        w0IND = 0.3
        wPol = wPolL25D03
        wH2O = wH2OL25D03
        mASD = mASDL25D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L == 0.25 and ASD_DL ==0.5:
        wIND = wINDL25D05
        w0IND = 0.5
        wPol = wPolL25D05
        wH2O = wH2OL25D05
        mASD = mASDL25D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L == 0.25 and ASD_DL == 0.7:
        wIND = wINDL25D07
        w0IND = 0.7
        wPol = wPolL25D07
        wH2O = wH2OL25D07
        mASD = mASDL25D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    else: print("Bitte gültige Werte für Länge und Drugload eingeben")
    w0Pol = 1 - w0IND  
    L = ASD_L * 10E-4 
    

    wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD=Conc_ASD(wIND,0,w0IND,wPol,0,w0Pol,wH2O,1,0,mB_0,mASD)

    
    #fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    # wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    # wt= Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    def fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
        def Diffforfit(t,D1,D2,D3):
            Dscale=1E13 #Hilfsvariable
            Dvec=np.asarray([D1,D2,D3])/Dscale #Normieren der Diffusionskoeffs (DKs)
            # Dvec=np.fmax(Dvec,1E-16)
            print(D1) #Ausgeben der normierten DKs
            print(D2)
            print(D3)
            wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True)
            return np.hstack((wt[:,0],wt[:,1])) #Rückgabe von wAPI_ASD und wPol_ASD
        wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-6,1E12),p0=(0.01,1,1)) #Einsetzen von normierten DKs in Solver
        Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dvecopt)
        

        return Dvecopt
        
        

        
    Dvecopt=  fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-12,1E-8]) 
    wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True) #Aufrufen der Diffusionsgleichung mit optimierten Dks
    DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
    
    return wt, Dvecopt, wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z





def Plot_Fit (ASD_L,DL):
    list1 =[]
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    plt.plot(t,wt[:,0],'r-') #Plotten der angepassten Kurven
    plt.plot(t,wt[:,1],'g-')
    plt.plot(t,wt[:,2],'b-')
    plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    xDL =np.linspace(0.3,0.7,3)
    for D in xDL:
         wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD,DL_z= Choose_ASD(ASD_L,D)
         list1.append(b)
    Dvec_array= np.array(list1)
    fig,axis =plt.subplots()
    axis.plot(xDL,Dvec_array[0,:],'r*')
    axis.plot(xDL,Dvec_array[1,:],'g*')
    axis.plot(xDL,Dvec_array[2,:],'b*')
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    fig,ax =plt.subplots()
    z= np.linspace(0,ASD_L,20)
    ax.plot(z,DL_z[0,0:20],'y-',label ='t = 0s')
    ax.plot(z,DL_z[19,0:20],'c-',label ='t = 4500s')
    ax.plot(z,DL_z[39,0:20],'m-',label ='t = 9000s')
    ax.plot(z,DL_z[59,0:20],'k-',label ='t = 13500s')
    ax.plot(z,DL_z[79,0:20],'g-',label ='t = 18000s')
    ax.set_xlabel('z [mm]')
    ax.set_ylabel('Drugload []')
    ax.legend()
   


    
#Choose_ASD(1,0.7)
Plot_Fit (1,0.3)
# Out:
# 0.001
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0254539 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.0010000149011611939
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0219506 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010045 seconds----------------
# 0.001
# 1.0000000149011612
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.024636 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005077 seconds----------------
# 0.001
# 1.0
# 1.0000000149011612
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0273368 seconds ----------------
# ------------- Initialization and postprocessing took 0.002033 seconds----------------
# 0.2651046060294299
# 1.5989195480424139
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0257565 seconds ----------------
# ------------- Initialization and postprocessing took 0.0008714 seconds----------------
# 0.2651046209305911
# 1.5989195480424139
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0277893 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.2651046060294299
# 1.5989195718681717
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0210277 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.2651046060294299
# 1.5989195480424139
# 2.253612865378722
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0218252 seconds ----------------
# ------------- Initialization and postprocessing took 0.0035087 seconds----------------
# 0.28655095039950007
# 1.676525733189389
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0208704 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.28655096530066126
# 1.676525733189389
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0248941 seconds ----------------
# ------------- Initialization and postprocessing took 0.0083514 seconds----------------
# 0.28655095039950007
# 1.6765257581715691
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0186128 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.28655095039950007
# 1.676525733189389
# 2.5978764277434245
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209807 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134329055004893
# 1.863058661841405
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.030116 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134330545121013
# 1.863058661841405
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0210226 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134329055004893
# 1.8630586896031422
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0264074 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134329055004893
# 1.863058661841405
# 3.275823207424582
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.024014 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.6601718624455712
# 2.3450916993857924
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0299722 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010272 seconds----------------
# 0.6601718773467324
# 2.3450916993857924
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0274013 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.6601718624455712
# 2.345091734330382
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0232847 seconds ----------------
# ------------- Initialization and postprocessing took 0.0040387 seconds----------------
# 0.6601718624455712
# 2.3450916993857924
# 4.57133341014368
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0223415 seconds ----------------
# ------------- Initialization and postprocessing took 0.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0327926 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75755806914154
# 68.73446793726596
# 173.5156074476631
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.036691 seconds ----------------
# ------------- Initialization and postprocessing took 0.001414 seconds----------------
# 124.75721957801355
# 68.73441134741846
# 173.51560744766473
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0314529 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75713505750021
# 68.73439660457319
# 173.51560744766513
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0350363 seconds ----------------
# ------------- Initialization and postprocessing took 0.0065356 seconds----------------
# 124.75711393453587
# 68.73439287808537
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0369288 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75711579356174
# 68.73439287808537
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0401909 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012109 seconds----------------
# 124.75711393453587
# 68.73439390230764
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0358829 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75711393453587
# 68.73439287808537
# 173.5156100332493
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0456619 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75711572196565
# 68.73439287808537
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0335579 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75711758099153
# 68.73439287808537
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0356087 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 124.75711572196565
# 68.73439390230764
# 173.51560744766525
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0387336 seconds ----------------
# ------------- Initialization and postprocessing took 0.0050051 seconds----------------
# 124.75711572196565
# 68.73439287808537
# 173.5156100332493
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0301262 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010471 seconds----------------
# [1.24757116e-11 6.87343929e-12 1.73515607e-11]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.038869 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027564 seconds----------------
# 0.001
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.021472 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.0010000149011611939
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0263017 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.001
# 1.0000000149011612
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0196309 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013694 seconds----------------
# 0.001
# 1.0
# 1.0000000149011612
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0201517 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015432 seconds----------------
# 0.2651046060294299
# 1.5989195480424139
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.020444 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009973 seconds----------------
# 0.2651046209305911
# 1.5989195480424139
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0178789 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009993 seconds----------------
# 0.2651046060294299
# 1.5989195718681717
# 2.2536128317972737
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209289 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.2651046060294299
# 1.5989195480424139
# 2.253612865378722
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0203898 seconds ----------------
# ------------- Initialization and postprocessing took 0.0008365 seconds----------------
# 0.28655095039950007
# 1.676525733189389
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0239695 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020319 seconds----------------
# 0.28655096530066126
# 1.676525733189389
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0235699 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009982 seconds----------------
# 0.28655095039950007
# 1.6765257581715691
# 2.5978763890320495
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0190836 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010011 seconds----------------
# 0.28655095039950007
# 1.676525733189389
# 2.5978764277434245
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0211342 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134329055004893
# 1.863058661841405
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0253202 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.36134330545121013
# 1.863058661841405
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0244014 seconds ----------------
# ------------- Initialization and postprocessing took 0.0080444 seconds----------------
# 0.36134329055004893
# 1.8630586896031422
# 3.275823158611013
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0244708 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010438 seconds----------------
# 0.36134329055004893
# 1.863058661841405
# 3.275823207424582
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0243022 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.6601718624455712
# 2.3450916993857924
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0249765 seconds ----------------
# ------------- Initialization and postprocessing took 0.0080516 seconds----------------
# 0.6601718773467324
# 2.3450916993857924
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0306254 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.6601718624455712
# 2.345091734330382
# 4.571333342025505
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0203917 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.6601718624455712
# 2.3450916993857924
# 4.57133341014368
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0296439 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 1.584560590721947
# 3.495822796975544
# 6.984076059360527
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0293329 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005097 seconds----------------
# 1.5845606143337398
# 3.495822796975544
# 6.984076059360527
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0226001 seconds ----------------
# ------------- Initialization and postprocessing took 0.0071309 seconds----------------
# 1.584560590721947
# 3.495822849067363
# 6.984076059360527
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0288717 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.00041937408826343294
# 10.152088330456635
# 0.9774374684591295
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0396866 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012361 seconds----------------
# 0.0004193591871022391
# 10.15208848173454
# 0.9774374684591295
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0392509 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.0004193591871022391
# 10.152088330456635
# 0.9774374833602907
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0360111 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.0016684046793494806
# 86.6331696251467
# 0.003911841260332949
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0302513 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 0.003507164350822863
# 29.175810030812727
# 2.911855983126734
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9411604 seconds ----------------
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v2.ipynb Cell 11 line 2
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=195'>196</a>     ax.legend()
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=200'>201</a> #Choose_ASD(1,0.7)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=201'>202</a> Plot_Fit (1,0.3)
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v2.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=176'>177</a> xDL =np.linspace(0.3,0.7,3)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=177'>178</a> for D in xDL:
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=178'>179</a>      wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD,DL_z= Choose_ASD(ASD_L,D)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=179'>180</a>      list1.append(b)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=180'>181</a> Dvec_array= np.array(list1)
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v2.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=151'>152</a>     print(Dvecopt)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=154'>155</a>     return Dvecopt
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=159'>160</a> Dvecopt=  fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-12,1E-8])
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=160'>161</a> wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True) #Aufrufen der Diffusionsgleichung mit optimierten Dks
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=161'>162</a> DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v2.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=147'>148</a> wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=148'>149</a> Dscale=1E13
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=149'>150</a> qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-6,1E12),p0=(0.001,1,1)) #Einsetzen von normierten DKs in Solver
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=150'>151</a> Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=151'>152</a> print(Dvecopt)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:974, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     971 if 'max_nfev' not in kwargs:
#     972     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 974 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                     **kwargs)
#     977 if not res.success:
#     978     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:938, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     934     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     935                           max_nfev, x_scale, diff_step)
#     937 elif method == 'trf':
# --> 938     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     939                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     940                  tr_options.copy(), verbose)
#     942 elif method == 'dogbox':
#     943     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:338, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338 f_new = fun(x_new)
#     339 nfev += 1
#     341 step_h_norm = norm(step_h)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:825, in least_squares.<locals>.fun_wrapped(x)
#     824 def fun_wrapped(x):
# --> 825     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:507, in _lightweight_memoizer.<locals>._memoized_func(params)
#     504 if np.all(_memoized_func.last_params == params):
#     505     return _memoized_func.last_val
# --> 507 val = f(params)
#     509 if _memoized_func.last_params is None:
#     510     _memoized_func.last_params = np.copy(params)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _wrap_func.<locals>.func_wrapped(params)
#     522 def func_wrapped(params):
# --> 523     return func(xdata, *params) - ydata
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v2.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=143'>144</a> print(D2)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=144'>145</a> print(D3)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=145'>146</a> wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v2.ipynb#X13sZmlsZQ%3D%3D?line=146'>147</a> return np.hstack((wt[:,0],wt[:,1]))
#
# File C:\GitHub_Projects\diffusionpy\diffusionpy\Stefan_Maxwell_segmental.py:201, in Diffusion_MS(tint, L, Dvec, wi0, wi8, Mi, mobile, full_output, dlnai_dlnwi, **kwargs)
#     199 end=time.time_ns()
#     200 print("------------- Diffusion modeling took "+str((end-start)/1E9)+" seconds ----------------")
# --> 201 if not sol["success"]: raise Exception(sol["message"]+f" The time step of failing was {tint[len(sol['y'])]} seconds")# the initial conditions are returned instead ----------------"); #return wi0*np.ones((nc,nt)).T
#     202 # x_sol=np.exp(sol["y"] ) if "EJ" not in kwargs else sol["y"]
#     203 x_sol=sol["y"]
#
# IndexError: index 63 is out of bounds for axis 0 with size 12

# %% [markdown]
# Fitting the sorption Data und Calculation of the Sorption MS Coefficients

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from diffusionpy import Diffusion_MS
from scipy.optimize import curve_fit

tsorpL1D03= np.array([0,1001,2002,3003,4004,5005,6005,7007,8008,9008,10009,11010,12010,13012,14012,15013,16015,17015,18016])
wwsorpL1D03 = np.array([1.4E-5,8.35E-3,1.443E-2,1.947E-2,2.39E-2,2.79E-2,3.158E-2,3.5E-2,3.821E-2,4.125E-2,4.413E-2,4.689E-2,4.952E-2,5.204E-2,5.447E-2,5.681E-2,5.906E-2,6.124E-2,6.336E-2])
tsorpL1D05= np.array([0,1005,2006,3007,4009,5010,6011,7013,8014,9016,10017,11018,12019,13021,14022,15023,16024,17026,18027])
wwsorpL1D05= np.array([3.1E-6,5.1E-3,7.4E-3,9E-3,1.029E-2,1.114E-2,1.238E-2,1.327E-2,1.408E-2,1.484E-2,1.554E-2,1.62E-2,1.682E-2,1.742E-2,1.798E-2,1.852E-2,1.904E-2,1.954E-2,2.002E-2])
tsorpL1D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL1D07= np.array([0,1.82E-3,2.59E-3,3.08E-3,3.46E-3,3.77E-3,4.04E-3,4.29E-3,4.51E-3,4.71E-3,4.91E-3,5.09E-3,5.26E-3,5.42E-3,5.58E-3,5.73E-3])
tsorpL25D03= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D03= np.array([6.6E-6,4.128E-2,6.4E-2,8.099E-2,9.493E-2,0.10691,0.11746,0.12691,0.13548,0.14328,0.15036,0.15677,0.1625,0.1676,0.1721,0.17607,0.17955,0.18263,0.18535])
tsorpL25D05= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D05= np.array([1.1E-4,2.438E-2,3.352E-2,3.902E-2,4.284E-2,4.581E-2,4.825E-2,5.048E-2,5.25E-2,5.435E-2,5.606E-2,5.773E-2,5.913E-2,6.056E-2,6.194E-2,6.314E-2,6.429E-2,6.556E-2,6.656E-2])
tsorpL25D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL25D07= np.array([0,8.1E-3,1.106E-2,1.32E-2,1.494E-2,1.642E-2,1.771E-2,1.887E-2,1.994E-2,2.0904E-2,2.1806E-2,2.2643E-2,2.343E-2,2.417E-2,2.487E-2,2.554E-2])
wi_0= np.array([0.9999,0.0001])
mobile =np.array([False, True])
Mi0= np.asarray([357.79,65000,16.02])



def Choose_Sorp(L_ASD,DL_ASD):
    if L_ASD == 1 and DL_ASD == 0.3:
        t_sorp= tsorpL1D03
        ww_sorp= wwsorpL1D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==1 and DL_ASD ==0.5: 
        t_sorp= tsorpL1D05
        ww_sorp= wwsorpL1D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==1 and DL_ASD ==0.7: 
        t_sorp= tsorpL1D07
        ww_sorp= wwsorpL1D07
        wi_8 = np.array([0.9405,0.0505])
    elif L_ASD == 0.25 and DL_ASD == 0.3:
        t_sorp= tsorpL25D03
        ww_sorp= wwsorpL25D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==0.25 and DL_ASD ==0.5: 
        t_sorp= tsorpL25D05
        ww_sorp= wwsorpL25D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==0.25 and DL_ASD ==0.7: 
        t_sorp= tsorpL25D07
        ww_sorp= wwsorpL25D07
        wi_8 = np.array([0.9405,0.0505])
    else: print('Bitte gültige Länge und Drugload eingeben!')
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    L= L_ASD*10E-4
    w_APIPol= 1-ww_sorp
    M_APIPol= 1/((DL_ASD/Mi0[0])+((1-DL_ASD)/Mi0[1])) #Mittlere molare Masse
    Mi = np.array([M_APIPol,16.02])
    from numpy import array

    def fit_Diff_Sorp (ww_sorp,w_APIPol):
        def Diff_for_fit(t,D_sorp):
            Dscale=1E13 #Hilfsvariable
            Dsorp_norm=np.array([D_sorp])/Dscale #Normieren des Diffusionskoeffs (DKs)
            print(Dsorp_norm) #Ausgeben des normierten DKs
            ww=Diffusion_MS(t,L,Dsorp_norm,wi_0,wi_8,Mi,mobile) #Ouput ist 2D
            return ww[:,1] #Rückgabe von w_H2O in ww
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diff_for_fit,t_sorp,ww_sorp,bounds=(1E-6,1E10),p0=(10)) #Einsetzen von normierten DKs in Solver
        Dsorpopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dsorpopt)
        
        return Dsorpopt
    Dsorpopt= fit_Diff_Sorp(ww_sorp,w_APIPol)
    ww= Diffusion_MS(t,L,Dsorpopt,wi_0,wi_8,Mi,mobile)
    return ww, Dsorpopt, t_sorp, ww_sorp
     



def plot_sorp (t_sorp, ww_sorp):
    plt.plot(t_sorp,ww_sorp,'bo')
    plt.xlabel('t [s]')
    plt.ylabel('ww [-]')

def plot_fit_sorp (L,DL):
    list =[]
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(L,DL)
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    plt.plot(t, ww [:,1],'b-')
    plot_sorp (t_sorp, ww_sorp)
    xL = np.linspace(0.3,0.7,3)
    for D in xL:
        a,b,c,d = Choose_Sorp(L,D)
        list.append(b)
    Dvec_sorp= np.array(list)
    fig,axis = plt.subplots()
    axis.plot(xL,Dvec_sorp,'b*')

    



plot_fit_sorp(1,0.3)
# Out:
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.007736 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010265 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.006635 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0111437 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0100322 seconds ----------------
# ------------- Initialization and postprocessing took 0.0008672 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0090471 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010424 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0091427 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005479 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.010568 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0070217 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011022 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0067698 seconds ----------------
# ------------- Initialization and postprocessing took 0.0030846 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.009105 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.004533 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0084259 seconds ----------------
# ------------- Initialization and postprocessing took 0.001538 seconds----------------

# %% [markdown]
# First model

# %%
mobile= np.asarray([True,True,True])
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2    
import time

wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)

color1 = "#99CDE9"
color2 = "#F08208"
color3 = "#99CC00"

fig,ax=origin_like.subplots()

origin_like.plot(ax,t,wt[:,0],"c-")
origin_like.plot(ax,t,wt[:,1],"r-")
origin_like.plot(ax,t,wt[:,2],"b-")
origin_like.plot(ax,texp,wINDL1D03,"co")
origin_like.plot(ax,texp,wPolL1D03,"ro")
origin_like.set_xlabel(ax,"t","s")
origin_like.set_ylabel(ax,"w_i","-")
origin_like.set_ticks(ax,0,300,0,1)
plt.show()
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1118428 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------

# %% [markdown]
# First try of an fitting function: leastsq

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import scipy as sc
import matplotlib.pyplot as plt

x= np.array([1,3,4,5,7,8,12,15,19,24])
y = np.array([3,7,14,25,41,48,59,73,78,95])

plt.plot(x,y,'ro')

def funcline (x,a,b):
    return a*x+b
def funcquad (x,a,b,c):
    return a*x**2+b*x+c   

X= np.linspace(x.min(),x.max(),50)
popt, pcov = curve_fit(funcline,x,y)
print(popt)
plt.plot(x,funcline(x, *popt))

qopt, qcov= curve_fit(funcquad,x,y)
plt.plot(x,funcquad(x,*qopt))
# Out:
# [4.12009419 3.92307692]
