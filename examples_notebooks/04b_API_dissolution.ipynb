# %% [markdown]
# # Stefan-Maxwell diffusion involving three components

# %% [markdown]
# This example demonstrates the modeling of the multicomponent Stefan-Maxwell model involving three componentt.
# First we import the Stefan-Maxwell diffusion module

# %%
import numpy as np
from numpy import array
from diffusionpy import Diffusion_MS,D_Matrix,Diffusion_MS_iter,vpure,dlnai_dlnxi,lngi,dlnai_dlnxi_loop
import matplotlib.pyplot as plt

# %% [markdown]
# experimental data

# %%
texp=array([5,15,30,60,90,120,150,180,210,240,270,300])
wL1D03=array([[5.1687E-06,	3.42274E-07, 9.99994489e-01],
        [8.11419000e-06, 6.63373000e-07, 9.99991222e-01],
       [1.16988000e-05, 1.30293000e-06, 9.99986998e-01],
       [1.82872000e-05, 2.61848000e-06, 9.99979094e-01],
       [2.43481000e-05, 4.06235000e-06, 9.99971590e-01],
       [2.97692000e-05, 5.50577000e-06, 9.99964725e-01],
       [3.50846000e-05, 7.11082000e-06, 9.99957805e-01],
       [3.91787000e-05, 8.82865000e-06, 9.99951993e-01],
       [4.30863000e-05, 1.03757000e-05, 9.99946538e-01],
       [4.68326000e-05, 1.22831000e-05, 9.99940884e-01],
       [4.92799000e-05, 1.34226000e-05, 9.99937297e-01],
       [5.08487000e-05, 1.48856000e-05, 9.99934266e-01]])

# wL1D03=array([[2.47540000e-06, 3.38334000e-07, 9.99997186e-01],
#        [5.76787000e-06, 7.27514000e-07, 9.99993505e-01],
#        [9.85161000e-06, 1.13529000e-06, 9.99989013e-01],
#        [1.43790000e-05, 2.29403000e-06, 9.99983327e-01],
#        [1.61947000e-05, 3.20807000e-06, 9.99980597e-01],
#        [1.67283000e-05, 4.11030000e-06, 9.99979161e-01],
#        [1.71512000e-05, 4.97144000e-06, 9.99977877e-01],
#        [1.73003000e-05, 5.76267000e-06, 9.99976937e-01],
#        [1.73463000e-05, 6.66612000e-06, 9.99975988e-01],
#        [1.71751000e-05, 7.58597000e-06, 9.99975239e-01],
#        [1.73692000e-05, 8.33222000e-06, 9.99974299e-01],
#        [1.75724000e-05, 9.19885000e-06, 9.99973229e-01]])

msol=500000
m0=array([43.491+18.639,0])
ww0=0.01
dl0=1
dl8=1
wi0=np.asarray([dl0*(1-ww0),ww0])
# release=wL1D03*msol/m0
# notreleased=1-release
# wexp=notreleased*wi0
# wexp[:,2]=1-wexp[:,0]-wexp[:,1]

wexp=wL1D03

# %% [markdown]
# We want to describe the diffusion of water into an ASD film. The ASD-water mixture is a ternary system. First we define starting and equilibrium weight fractions.

# %%
nc=2
L=0.001
ww8=0.14
ww8=0.99999
wi8=np.asarray([dl8*(1-ww8),ww8])
Mi=np.asarray([357.57,18.015])
T=298.15
p=1E5

kij=D_Matrix(np.asarray([-0.025]),nc)
par={"mi":np.asarray([ 14.283,1.20469]),
"si": np.asarray([ 3.535,2.797059952]),
"ui" :np.asarray([262.79,353.95]),
"eAi" :np.asarray([ 886.4,2425.67]),
"kAi":np.asarray([ 0.02,0.04509]),
"NAi":np.asarray([3.,1.]),
"Mi": Mi,
"kij":kij,
"kijA":np.asarray([[0.]])}

vpures=vpure(p,T,**par)
par["vpure"]=vpures
lngi_fun=lambda wi :lngi(T,wi,**par)
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi_loop(T,wi,**par)

# %% [markdown]
# For a the diffusion of three components, three binary diffusion coefficients need to be defined

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# 0 & 0 & Ð_{23} \\
# 0 & 0 & 0 \\
# \end{array}\right]$
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$

# %%
Dvec=np.asarray([6E-13,2E-12,1E-12]) #ideal
# Dvec=np.asarray([1E-13,1E-14,1E-14]) #real
# Dvec=np.asarray([1E-13,1E-13,1E-13])
Dvec=np.asarray([10E-12])*10 #real

# %% [markdown]
# Next we define the time array and which component is mobile

# %%
nt=21
t=np.linspace(0,(300*60)**0.5,nt)**2
# t=np.linspace(0,(22000)**0.5,nt)**2
mobile=np.asarray([True,True])
# mobile=np.asarray([False,False,True])

# %%
wt,wtz,zvec,Lt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,swelling=True,full_output=True,nz=20)
taui=np.asarray([500])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,np.asarray([True,False]),taui)

wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,swelling=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,method="weg",maxit=9,nz=20,witB=witB)
notreleased=wt/wi0
release=1-notreleased# wtid=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,swelling=True)

wt=m0/msol*release
wt[:,1]=1-wt[:,0]
wtid=wt
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0540362 seconds ----------------
# ------------- Initialization and postprocessing took 0.0749917 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1236032 seconds ----------------
# ------------- Initialization and postprocessing took 0.0859152 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1392846 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 15.16896488 15.16628504
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 15.1689556  15.1287281
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... 11.40777034 -7.51755693
#    0.99957054]
#  [15.16896505 15.16896505 15.16896505 ...  9.97702607 -7.80984122
#    0.99957054]
#  [15.16896505 15.16896505 15.16896505 ...  8.31548851 -7.94190345
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4750864 seconds ----------------
# ------------- Initialization and postprocessing took 0.1053384 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.2097024 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.93672715 13.25154599
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.36215741 11.22215298
#   -5.37653907]
#  ...
#  [15.16895692 15.16895444 15.16894876 ... -7.91875579 -5.26429324
#    0.99957054]
#  [15.16882865 15.1687955  15.16872185 ... -7.82329466 -5.07932215
#    0.99957054]
#  [15.16750342 15.16721711 15.16659359 ... -7.70855078 -4.89276338
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4931518 seconds ----------------
# ------------- Initialization and postprocessing took 0.1079185 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.2000506 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95512074 13.23302382
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.41826142 11.02391517
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... -3.29202178 -1.33777279
#    0.99957054]
#  [15.16896505 15.16896505 15.16896505 ... -3.09921131 -1.22186101
#    0.99957054]
#  [15.16896505 15.16896505 15.16896505 ... -2.9227512  -1.11698279
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.083677 seconds ----------------
# ------------- Initialization and postprocessing took 0.1451485 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1635801 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540019 13.23277584
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42374473 11.01636613
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... -3.53254512 -1.48444808
#    0.99957054]
#  [15.16896503 15.16896503 15.16896502 ... -3.33691278 -1.36487647
#    0.99957054]
#  [15.16896493 15.16896491 15.16896487 ... -3.1533512  -1.25409227
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.2855467 seconds ----------------
# ------------- Initialization and postprocessing took 0.134566 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1783494 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540646 13.23277064
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42440492 11.01621932
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... -3.7085095  -1.59315042
#    0.99957054]
#  [15.16896503 15.16896502 15.16896501 ... -3.5041932  -1.46669442
#    0.99957054]
#  [15.16896489 15.16896486 15.16896481 ... -3.31061811 -1.34873425
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.6004383 seconds ----------------
# ------------- Initialization and postprocessing took 0.1335639 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1989867 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540661 13.23277054
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42467208 11.01629124
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... -3.77582909 -1.63473329
#    0.99957054]
#  [15.16896503 15.16896502 15.16896501 ... -3.57152764 -1.5082427
#    0.99957054]
#  [15.16896488 15.16896485 15.16896478 ... -3.36883218 -1.38453484
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.5039027 seconds ----------------
# ------------- Initialization and postprocessing took 0.1420906 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.193915 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540659 13.23277057
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42489845 11.01636005
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896505 ... -3.84994879 -1.68135471
#    0.99957054]
#  [15.16896503 15.16896502 15.16896501 ... -3.63788415 -1.54877795
#    0.99957054]
#  [15.16896487 15.16896484 15.16896477 ... -3.4253012  -1.41823976
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.1372938 seconds ----------------
# ------------- Initialization and postprocessing took 0.1499004 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1645759 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540657 13.2327706
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42511388 11.016425
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896504 ... -3.84263228 -1.67688968
#    0.99957054]
#  [15.16896502 15.16896502 15.16896501 ... -3.67519161 -1.57190504
#    0.99957054]
#  [15.16896486 15.16896483 15.16896476 ... -3.41245367 -1.41041159
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.0912776 seconds ----------------
# ------------- Initialization and postprocessing took 0.1543736 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.1586199 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540655 13.23277063
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42534492 11.01649382
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896504 ... -3.88021247 -1.70008081
#    0.99957054]
#  [15.16896502 15.16896502 15.16896501 ... -3.62757151 -1.54232771
#    0.99957054]
#  [15.16896485 15.16896482 15.16896475 ... -3.3758008  -1.3883164
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.0484352 seconds ----------------
# ------------- Initialization and postprocessing took 0.1252681 seconds----------------
# ------------- Initialization and postprocessing ----------------
# [[15.16896505 15.16896505 15.16896505 ... 15.16896505 15.16896505
#   15.16896505]
#  [15.16896505 15.16896505 15.16896505 ... 14.95540653 13.23277066
#    3.45876347]
#  [15.16896505 15.16896505 15.16896505 ... 13.42562471 11.01657628
#   -5.37653907]
#  ...
#  [15.16896505 15.16896505 15.16896504 ... -3.87076034 -1.69437888
#    0.99957054]
#  [15.16896502 15.16896502 15.16896501 ... -3.65799824 -1.56126853
#    0.99957054]
#  [15.16896485 15.16896482 15.16896474 ... -3.40314168 -1.40513173
#    0.99957054]]
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.7719475 seconds ----------------
# ------------- Initialization and postprocessing took 0.1347627 seconds----------------

# %% [markdown]
# We can determine the mass dissolved in the dissolution medium by quantifying the mass that leaves the ASD. The initial mass of the ASD and the mass of the dissolution medium must be known

# %% [markdown]
# We plot the results

# %%
font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)

# ax.plot(t/60,wtid[:,0], "--",color = color1 , 
#         linewidth = 2.0, label = "wPol")
# ax.plot(t/60,wtid[:,1], "--",color = color2 , 
#         linewidth = 2.0, label = "wAPI")

ax.plot(t/60,wt[:,1], "-",color = color1 , 
        linewidth = 2.0, label = "wPol")
ax.plot(t/60,wt[:,0], "-",color = color2 , 
        linewidth = 2.0, label = "wAPI")

ax.plot(texp,wexp[:,0], "ro",color = color1 , 
        linewidth = 2.0, label = "wPol")
ax.plot(texp,wexp[:,1], "go",color = color2 , 
        linewidth = 2.0, label = "wAPI")



ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 6E-5])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()



# ax2.plot(zexp2*Lt[0],tolu, "o")

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]

# [ax3.plot(zvec*1E6,wtz[i,2,:], "-",color = color3 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]
# Out:
# [[<matplotlib.lines.Line2D at 0x20a39fec2d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a02e9d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a02f310>],
#  [<matplotlib.lines.Line2D at 0x20a3a02fb90>],
#  [<matplotlib.lines.Line2D at 0x20a3a03c4d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a03ce10>],
#  [<matplotlib.lines.Line2D at 0x20a3a03d6d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a03e010>],
#  [<matplotlib.lines.Line2D at 0x20a3a03e8d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a03f1d0>],
#  [<matplotlib.lines.Line2D at 0x20a3a03fb10>],
#  [<matplotlib.lines.Line2D at 0x20a3a04c250>],
#  [<matplotlib.lines.Line2D at 0x20a3a04cbd0>],
#  [<matplotlib.lines.Line2D at 0x20a3a04d410>],
#  [<matplotlib.lines.Line2D at 0x20a3a04dd10>],
#  [<matplotlib.lines.Line2D at 0x20a3a04e650>],
#  [<matplotlib.lines.Line2D at 0x20a3a04ee50>],
#  [<matplotlib.lines.Line2D at 0x20a3a04f790>],
#  [<matplotlib.lines.Line2D at 0x20a3a05c090>],
#  [<matplotlib.lines.Line2D at 0x20a3a05ca50>],
#  [<matplotlib.lines.Line2D at 0x20a3a05d310>]]
