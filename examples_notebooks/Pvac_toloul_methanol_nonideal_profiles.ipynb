# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0939658 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1394608 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.206506 seconds ----------------
# iter 0: ||F|| = 0.00086202, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1880517 seconds ----------------
# iter 1: ||F|| = 0.000858587, sigma = 251.089
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1870667 seconds ----------------
# iter 2: ||F|| = 0.000181647, sigma = 262.14
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2434324 seconds ----------------
# iter 3: ||F|| = 4.87376e-05, sigma = 280.327
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2793832 seconds ----------------
# iter 4: ||F|| = 1.28314e-05, sigma = 369.832
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2147287 seconds ----------------
# iter 5: ||F|| = 1.80526e-06, sigma = 396.987
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2313971 seconds ----------------
# iter 6: ||F|| = 5.04754e-07, sigma = 341.908
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2137235 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x233b8f4bfa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f55280>],
#  [<matplotlib.lines.Line2D at 0x233b8f55520>],
#  [<matplotlib.lines.Line2D at 0x233b8f557c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f55a60>],
#  [<matplotlib.lines.Line2D at 0x233b8f55d00>],
#  [<matplotlib.lines.Line2D at 0x233b8f55fa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f5d280>],
#  [<matplotlib.lines.Line2D at 0x233b8f5d520>],
#  [<matplotlib.lines.Line2D at 0x233b8f5d7c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f5da60>],
#  [<matplotlib.lines.Line2D at 0x233b8f5dd00>],
#  [<matplotlib.lines.Line2D at 0x233b8f5dfa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f66280>],
#  [<matplotlib.lines.Line2D at 0x233b8f66520>],
#  [<matplotlib.lines.Line2D at 0x233b8f667c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f66a60>],
#  [<matplotlib.lines.Line2D at 0x233b8f66d00>],
#  [<matplotlib.lines.Line2D at 0x233b8f66fa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f70280>],
#  [<matplotlib.lines.Line2D at 0x233b8f70520>],
#  [<matplotlib.lines.Line2D at 0x233b8f707c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f70a60>],
#  [<matplotlib.lines.Line2D at 0x233b8f70d00>],
#  [<matplotlib.lines.Line2D at 0x233b8f70fa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f7b280>],
#  [<matplotlib.lines.Line2D at 0x233b8f7b520>],
#  [<matplotlib.lines.Line2D at 0x233b8f7b7c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f7ba60>],
#  [<matplotlib.lines.Line2D at 0x233b8f7bd00>],
#  [<matplotlib.lines.Line2D at 0x233b8f7bfa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f88280>],
#  [<matplotlib.lines.Line2D at 0x233b8f88520>],
#  [<matplotlib.lines.Line2D at 0x233b8f887c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f88a60>],
#  [<matplotlib.lines.Line2D at 0x233b8f88d00>],
#  [<matplotlib.lines.Line2D at 0x233b8f88fa0>],
#  [<matplotlib.lines.Line2D at 0x233b8f92280>],
#  [<matplotlib.lines.Line2D at 0x233b8f92520>],
#  [<matplotlib.lines.Line2D at 0x233b8f927c0>],
#  [<matplotlib.lines.Line2D at 0x233b8f92a90>],
#  [<matplotlib.lines.Line2D at 0x233b8f92d30>],
#  [<matplotlib.lines.Line2D at 0x233b8f92fd0>],
#  [<matplotlib.lines.Line2D at 0x233b8f9f2b0>],
#  [<matplotlib.lines.Line2D at 0x233b8f9f550>],
#  [<matplotlib.lines.Line2D at 0x233b8f9f7f0>],
#  [<matplotlib.lines.Line2D at 0x233b8f9fa90>],
#  [<matplotlib.lines.Line2D at 0x233b8f9fd30>],
#  [<matplotlib.lines.Line2D at 0x233b8f9ffd0>],
#  [<matplotlib.lines.Line2D at 0x233b8fa72b0>],
#  [<matplotlib.lines.Line2D at 0x233b8fa7550>],
#  [<matplotlib.lines.Line2D at 0x233b8fa77f0>],
#  [<matplotlib.lines.Line2D at 0x233b8fa7a90>],
#  [<matplotlib.lines.Line2D at 0x233b8fa7d30>],
#  [<matplotlib.lines.Line2D at 0x233b8fa7fd0>],
#  [<matplotlib.lines.Line2D at 0x233b8fb42b0>],
#  [<matplotlib.lines.Line2D at 0x233b8fb4550>],
#  [<matplotlib.lines.Line2D at 0x233b8fb47f0>],
#  [<matplotlib.lines.Line2D at 0x233b8fb4a90>],
#  [<matplotlib.lines.Line2D at 0x233b8fb4d30>],
#  [<matplotlib.lines.Line2D at 0x233b8fb4fd0>],
#  [<matplotlib.lines.Line2D at 0x233b8fc02b0>],
#  [<matplotlib.lines.Line2D at 0x233b8fc0550>],
#  [<matplotlib.lines.Line2D at 0x233b8fc07f0>],
#  [<matplotlib.lines.Line2D at 0x233b8fc0a90>],
#  [<matplotlib.lines.Line2D at 0x233b8fc0d60>],
#  [<matplotlib.lines.Line2D at 0x233b8fcb040>],
#  [<matplotlib.lines.Line2D at 0x233b8fcb2e0>],
#  [<matplotlib.lines.Line2D at 0x233b8fcb580>],
#  [<matplotlib.lines.Line2D at 0x233b8fcb820>],
#  [<matplotlib.lines.Line2D at 0x233b8fcbac0>],
#  [<matplotlib.lines.Line2D at 0x233b8fcbd60>],
#  [<matplotlib.lines.Line2D at 0x233b8fd7040>],
#  [<matplotlib.lines.Line2D at 0x233b8fd72e0>],
#  [<matplotlib.lines.Line2D at 0x233b8fd7580>],
#  [<matplotlib.lines.Line2D at 0x233b8fd7820>],
#  [<matplotlib.lines.Line2D at 0x233b8fd7ac0>],
#  [<matplotlib.lines.Line2D at 0x233b8fd7d60>],
#  [<matplotlib.lines.Line2D at 0x233b8fe1040>],
#  [<matplotlib.lines.Line2D at 0x233b8fe12e0>],
#  [<matplotlib.lines.Line2D at 0x233b8fe1580>],
#  [<matplotlib.lines.Line2D at 0x233b8fe1820>],
#  [<matplotlib.lines.Line2D at 0x233b8fe1ac0>],
#  [<matplotlib.lines.Line2D at 0x233b8fe1d60>],
#  [<matplotlib.lines.Line2D at 0x233b8fec040>],
#  [<matplotlib.lines.Line2D at 0x233b8fec2e0>],
#  [<matplotlib.lines.Line2D at 0x233b8fec580>],
#  [<matplotlib.lines.Line2D at 0x233b8fec820>],
#  [<matplotlib.lines.Line2D at 0x233b8fecac0>],
#  [<matplotlib.lines.Line2D at 0x233b8fecd60>],
#  [<matplotlib.lines.Line2D at 0x233b8ff9040>],
#  [<matplotlib.lines.Line2D at 0x233b8ff92e0>],
#  [<matplotlib.lines.Line2D at 0x233b8ff9580>],
#  [<matplotlib.lines.Line2D at 0x233b8ff9820>],
#  [<matplotlib.lines.Line2D at 0x233b8ff9ac0>],
#  [<matplotlib.lines.Line2D at 0x233b8ff9d60>],
#  [<matplotlib.lines.Line2D at 0x233b9003040>],
#  [<matplotlib.lines.Line2D at 0x233b90032e0>],
#  [<matplotlib.lines.Line2D at 0x233b9003580>],
#  [<matplotlib.lines.Line2D at 0x233b9003820>],
#  [<matplotlib.lines.Line2D at 0x233b9003ac0>],
#  [<matplotlib.lines.Line2D at 0x233b9003d60>],
#  [<matplotlib.lines.Line2D at 0x233b900f040>],
#  [<matplotlib.lines.Line2D at 0x233b900f2e0>],
#  [<matplotlib.lines.Line2D at 0x233b900f580>],
#  [<matplotlib.lines.Line2D at 0x233b900f820>],
#  [<matplotlib.lines.Line2D at 0x233b900fac0>],
#  [<matplotlib.lines.Line2D at 0x233b900fd60>],
#  [<matplotlib.lines.Line2D at 0x233b901b040>],
#  [<matplotlib.lines.Line2D at 0x233b901b2e0>],
#  [<matplotlib.lines.Line2D at 0x233b901b580>],
#  [<matplotlib.lines.Line2D at 0x233b901b820>],
#  [<matplotlib.lines.Line2D at 0x233b901bac0>],
#  [<matplotlib.lines.Line2D at 0x233b901bd60>],
#  [<matplotlib.lines.Line2D at 0x233b9025040>],
#  [<matplotlib.lines.Line2D at 0x233b90252e0>],
#  [<matplotlib.lines.Line2D at 0x233b9025580>],
#  [<matplotlib.lines.Line2D at 0x233b9025820>],
#  [<matplotlib.lines.Line2D at 0x233b9025ac0>],
#  [<matplotlib.lines.Line2D at 0x233b9025d60>],
#  [<matplotlib.lines.Line2D at 0x233b9031040>],
#  [<matplotlib.lines.Line2D at 0x233b90312e0>],
#  [<matplotlib.lines.Line2D at 0x233b9031580>],
#  [<matplotlib.lines.Line2D at 0x233b9031820>],
#  [<matplotlib.lines.Line2D at 0x233b9031ac0>],
#  [<matplotlib.lines.Line2D at 0x233b9031d60>],
#  [<matplotlib.lines.Line2D at 0x233b903c070>],
#  [<matplotlib.lines.Line2D at 0x233b903c310>],
#  [<matplotlib.lines.Line2D at 0x233b903c5b0>],
#  [<matplotlib.lines.Line2D at 0x233b903c850>],
#  [<matplotlib.lines.Line2D at 0x233b903caf0>],
#  [<matplotlib.lines.Line2D at 0x233b903cd90>],
#  [<matplotlib.lines.Line2D at 0x233b9047070>],
#  [<matplotlib.lines.Line2D at 0x233b9047310>],
#  [<matplotlib.lines.Line2D at 0x233b90475b0>],
#  [<matplotlib.lines.Line2D at 0x233b9047850>],
#  [<matplotlib.lines.Line2D at 0x233b9047af0>],
#  [<matplotlib.lines.Line2D at 0x233b9047d90>],
#  [<matplotlib.lines.Line2D at 0x233b9054070>],
#  [<matplotlib.lines.Line2D at 0x233b9054310>],
#  [<matplotlib.lines.Line2D at 0x233b90545b0>],
#  [<matplotlib.lines.Line2D at 0x233b9054850>],
#  [<matplotlib.lines.Line2D at 0x233b9054af0>],
#  [<matplotlib.lines.Line2D at 0x233b9054d90>],
#  [<matplotlib.lines.Line2D at 0x233b905e070>],
#  [<matplotlib.lines.Line2D at 0x233b905e310>],
#  [<matplotlib.lines.Line2D at 0x233b905e5b0>],
#  [<matplotlib.lines.Line2D at 0x233b905e850>],
#  [<matplotlib.lines.Line2D at 0x233b905eaf0>],
#  [<matplotlib.lines.Line2D at 0x233b905ed90>],
#  [<matplotlib.lines.Line2D at 0x233b9069070>],
#  [<matplotlib.lines.Line2D at 0x233b9069310>],
#  [<matplotlib.lines.Line2D at 0x233b90695b0>],
#  [<matplotlib.lines.Line2D at 0x233b9069850>],
#  [<matplotlib.lines.Line2D at 0x233b9069af0>],
#  [<matplotlib.lines.Line2D at 0x233b9069d90>],
#  [<matplotlib.lines.Line2D at 0x233b9075070>],
#  [<matplotlib.lines.Line2D at 0x233b9075310>],
#  [<matplotlib.lines.Line2D at 0x233b90755b0>],
#  [<matplotlib.lines.Line2D at 0x233b9075850>],
#  [<matplotlib.lines.Line2D at 0x233b9075af0>],
#  [<matplotlib.lines.Line2D at 0x233b9075d90>],
#  [<matplotlib.lines.Line2D at 0x233b9081070>],
#  [<matplotlib.lines.Line2D at 0x233b9081310>],
#  [<matplotlib.lines.Line2D at 0x233b90815b0>],
#  [<matplotlib.lines.Line2D at 0x233b9081850>],
#  [<matplotlib.lines.Line2D at 0x233b9081af0>],
#  [<matplotlib.lines.Line2D at 0x233b9081d90>],
#  [<matplotlib.lines.Line2D at 0x233b908d070>],
#  [<matplotlib.lines.Line2D at 0x233b908d310>],
#  [<matplotlib.lines.Line2D at 0x233b908d5b0>],
#  [<matplotlib.lines.Line2D at 0x233b908d850>],
#  [<matplotlib.lines.Line2D at 0x233b908daf0>],
#  [<matplotlib.lines.Line2D at 0x233b908dd90>],
#  [<matplotlib.lines.Line2D at 0x233b9099070>],
#  [<matplotlib.lines.Line2D at 0x233b9099310>],
#  [<matplotlib.lines.Line2D at 0x233b90995b0>],
#  [<matplotlib.lines.Line2D at 0x233b9099850>],
#  [<matplotlib.lines.Line2D at 0x233b9099af0>],
#  [<matplotlib.lines.Line2D at 0x233b9099d90>],
#  [<matplotlib.lines.Line2D at 0x233b90a2070>],
#  [<matplotlib.lines.Line2D at 0x233b90a2310>],
#  [<matplotlib.lines.Line2D at 0x233b90a25b0>],
#  [<matplotlib.lines.Line2D at 0x233b90a2850>],
#  [<matplotlib.lines.Line2D at 0x233b90a2af0>],
#  [<matplotlib.lines.Line2D at 0x233b90a2d90>],
#  [<matplotlib.lines.Line2D at 0x233b90af070>],
#  [<matplotlib.lines.Line2D at 0x233b90af310>],
#  [<matplotlib.lines.Line2D at 0x233b90af5b0>],
#  [<matplotlib.lines.Line2D at 0x233b90af850>],
#  [<matplotlib.lines.Line2D at 0x233b90afaf0>],
#  [<matplotlib.lines.Line2D at 0x233b90afd90>],
#  [<matplotlib.lines.Line2D at 0x233b90ba070>],
#  [<matplotlib.lines.Line2D at 0x233b90ba310>],
#  [<matplotlib.lines.Line2D at 0x233b90ba5b0>],
#  [<matplotlib.lines.Line2D at 0x233b90ba850>],
#  [<matplotlib.lines.Line2D at 0x233b90baaf0>],
#  [<matplotlib.lines.Line2D at 0x233b90bad90>],
#  [<matplotlib.lines.Line2D at 0x233b90c6070>],
#  [<matplotlib.lines.Line2D at 0x233b90c6310>],
#  [<matplotlib.lines.Line2D at 0x233b90c65b0>],
#  [<matplotlib.lines.Line2D at 0x233b90c6850>],
#  [<matplotlib.lines.Line2D at 0x233b90c6af0>],
#  [<matplotlib.lines.Line2D at 0x233b90c6dc0>],
#  [<matplotlib.lines.Line2D at 0x233b90d10a0>],
#  [<matplotlib.lines.Line2D at 0x233b90d1340>],
#  [<matplotlib.lines.Line2D at 0x233b90d15e0>],
#  [<matplotlib.lines.Line2D at 0x233b90d1880>],
#  [<matplotlib.lines.Line2D at 0x233b90d1b20>],
#  [<matplotlib.lines.Line2D at 0x233b90d1dc0>],
#  [<matplotlib.lines.Line2D at 0x233b90dd0a0>],
#  [<matplotlib.lines.Line2D at 0x233b90dd340>],
#  [<matplotlib.lines.Line2D at 0x233b90dd5e0>],
#  [<matplotlib.lines.Line2D at 0x233b90dd880>],
#  [<matplotlib.lines.Line2D at 0x233b90ddb20>],
#  [<matplotlib.lines.Line2D at 0x233b90dddc0>],
#  [<matplotlib.lines.Line2D at 0x233b90e70a0>],
#  [<matplotlib.lines.Line2D at 0x233b90e7340>],
#  [<matplotlib.lines.Line2D at 0x233b90e75e0>],
#  [<matplotlib.lines.Line2D at 0x233b90e7880>],
#  [<matplotlib.lines.Line2D at 0x233b90e7b20>],
#  [<matplotlib.lines.Line2D at 0x233b90e7dc0>],
#  [<matplotlib.lines.Line2D at 0x233b90f30a0>],
#  [<matplotlib.lines.Line2D at 0x233b90f3340>],
#  [<matplotlib.lines.Line2D at 0x233b90f35e0>],
#  [<matplotlib.lines.Line2D at 0x233b90f3880>],
#  [<matplotlib.lines.Line2D at 0x233b90f3b20>],
#  [<matplotlib.lines.Line2D at 0x233b90f3dc0>],
#  [<matplotlib.lines.Line2D at 0x233b90fe0a0>],
#  [<matplotlib.lines.Line2D at 0x233b90fe340>],
#  [<matplotlib.lines.Line2D at 0x233b90fe5e0>],
#  [<matplotlib.lines.Line2D at 0x233b90fe880>],
#  [<matplotlib.lines.Line2D at 0x233b90feb20>],
#  [<matplotlib.lines.Line2D at 0x233b90fedc0>],
#  [<matplotlib.lines.Line2D at 0x233b910a0a0>],
#  [<matplotlib.lines.Line2D at 0x233b910a340>],
#  [<matplotlib.lines.Line2D at 0x233b910a5e0>],
#  [<matplotlib.lines.Line2D at 0x233b910a880>],
#  [<matplotlib.lines.Line2D at 0x233b910ab20>],
#  [<matplotlib.lines.Line2D at 0x233b910adc0>],
#  [<matplotlib.lines.Line2D at 0x233b91150a0>],
#  [<matplotlib.lines.Line2D at 0x233b9115340>],
#  [<matplotlib.lines.Line2D at 0x233b91155e0>],
#  [<matplotlib.lines.Line2D at 0x233b9115880>],
#  [<matplotlib.lines.Line2D at 0x233b9115b20>],
#  [<matplotlib.lines.Line2D at 0x233b9115dc0>],
#  [<matplotlib.lines.Line2D at 0x233b91220a0>],
#  [<matplotlib.lines.Line2D at 0x233b9122340>],
#  [<matplotlib.lines.Line2D at 0x233b91225e0>],
#  [<matplotlib.lines.Line2D at 0x233b9122880>],
#  [<matplotlib.lines.Line2D at 0x233b9122b20>],
#  [<matplotlib.lines.Line2D at 0x233b9122dc0>],
#  [<matplotlib.lines.Line2D at 0x233b912a0a0>],
#  [<matplotlib.lines.Line2D at 0x233b912a340>],
#  [<matplotlib.lines.Line2D at 0x233b912a5e0>],
#  [<matplotlib.lines.Line2D at 0x233b912a880>],
#  [<matplotlib.lines.Line2D at 0x233b912ab20>],
#  [<matplotlib.lines.Line2D at 0x233b912adc0>],
#  [<matplotlib.lines.Line2D at 0x233b91370a0>],
#  [<matplotlib.lines.Line2D at 0x233b9137340>],
#  [<matplotlib.lines.Line2D at 0x233b91375e0>],
#  [<matplotlib.lines.Line2D at 0x233b9137880>],
#  [<matplotlib.lines.Line2D at 0x233b9137b20>],
#  [<matplotlib.lines.Line2D at 0x233b9137dc0>],
#  [<matplotlib.lines.Line2D at 0x233b91420a0>],
#  [<matplotlib.lines.Line2D at 0x233b9142340>],
#  [<matplotlib.lines.Line2D at 0x233b91425e0>],
#  [<matplotlib.lines.Line2D at 0x233b9142880>],
#  [<matplotlib.lines.Line2D at 0x233b9142b20>],
#  [<matplotlib.lines.Line2D at 0x233b9142dc0>],
#  [<matplotlib.lines.Line2D at 0x233b914e0a0>],
#  [<matplotlib.lines.Line2D at 0x233b914e340>],
#  [<matplotlib.lines.Line2D at 0x233b914e5e0>],
#  [<matplotlib.lines.Line2D at 0x233b914e880>],
#  [<matplotlib.lines.Line2D at 0x233b914eb20>],
#  [<matplotlib.lines.Line2D at 0x233b914edc0>],
#  [<matplotlib.lines.Line2D at 0x233b915a0a0>],
#  [<matplotlib.lines.Line2D at 0x233b915a340>],
#  [<matplotlib.lines.Line2D at 0x233b915a5e0>],
#  [<matplotlib.lines.Line2D at 0x233b915a880>],
#  [<matplotlib.lines.Line2D at 0x233b915ab20>],
#  [<matplotlib.lines.Line2D at 0x233b915adc0>],
#  [<matplotlib.lines.Line2D at 0x233b91640a0>],
#  [<matplotlib.lines.Line2D at 0x233b9164340>],
#  [<matplotlib.lines.Line2D at 0x233b91645e0>],
#  [<matplotlib.lines.Line2D at 0x233b9164880>],
#  [<matplotlib.lines.Line2D at 0x233b9164b20>],
#  [<matplotlib.lines.Line2D at 0x233b9164dc0>],
#  [<matplotlib.lines.Line2D at 0x233b916f0a0>],
#  [<matplotlib.lines.Line2D at 0x233b916f340>],
#  [<matplotlib.lines.Line2D at 0x233b916f5e0>],
#  [<matplotlib.lines.Line2D at 0x233b916f880>],
#  [<matplotlib.lines.Line2D at 0x233b916fb20>],
#  [<matplotlib.lines.Line2D at 0x233b916fdc0>],
#  [<matplotlib.lines.Line2D at 0x233b917c0a0>],
#  [<matplotlib.lines.Line2D at 0x233b917c340>],
#  [<matplotlib.lines.Line2D at 0x233b917c5e0>],
#  [<matplotlib.lines.Line2D at 0x233b917c880>],
#  [<matplotlib.lines.Line2D at 0x233b917cb20>],
#  [<matplotlib.lines.Line2D at 0x233b917cdc0>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1910186 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3862099 seconds ----------------
# iter 0: ||F|| = 0.000394436, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3791676 seconds ----------------
# iter 1: ||F|| = 0.000393184, sigma = 313.352
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3490373 seconds ----------------
# iter 2: ||F|| = 5.49762e-05, sigma = 318.317
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3637516 seconds ----------------
# iter 3: ||F|| = 9.01503e-06, sigma = 331.409
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3198186 seconds ----------------
# iter 4: ||F|| = 2.84521e-06, sigma = 342.446
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3247189 seconds ----------------
# iter 5: ||F|| = 7.77361e-07, sigma = 302.083
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.324668 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$Xi$ / -')
ax4.set_xlabel('$z$ / µm')
ax4.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0]*1E6,meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0]*1E6,tolu, "o")

ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig
