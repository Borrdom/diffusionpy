# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1039423 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2208862 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3442615 seconds ----------------
# iter 0: ||F|| = 0.000862385, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2415844 seconds ----------------
# iter 1: ||F|| = 0.000858951, sigma = 251.139
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2460022 seconds ----------------
# iter 2: ||F|| = 0.000181433, sigma = 262.119
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2666592 seconds ----------------
# iter 3: ||F|| = 4.8507e-05, sigma = 280.574
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2514046 seconds ----------------
# iter 4: ||F|| = 1.2795e-05, sigma = 370.41
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2398073 seconds ----------------
# iter 5: ||F|| = 1.70271e-06, sigma = 397.689
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2949796 seconds ----------------
# iter 6: ||F|| = 4.79351e-07, sigma = 342.715
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3263642 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x1c9b3825460>],
#  [<matplotlib.lines.Line2D at 0x1c9b3825700>],
#  [<matplotlib.lines.Line2D at 0x1c9b38259a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3825c40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3825ee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38301c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3830460>],
#  [<matplotlib.lines.Line2D at 0x1c9b3830700>],
#  [<matplotlib.lines.Line2D at 0x1c9b38309a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3830c40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3830ee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b383c1c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b383c460>],
#  [<matplotlib.lines.Line2D at 0x1c9b383c700>],
#  [<matplotlib.lines.Line2D at 0x1c9b383c9a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b383cc40>],
#  [<matplotlib.lines.Line2D at 0x1c9b383cee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b384b1c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b384b460>],
#  [<matplotlib.lines.Line2D at 0x1c9b384b700>],
#  [<matplotlib.lines.Line2D at 0x1c9b384b9a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b384bc40>],
#  [<matplotlib.lines.Line2D at 0x1c9b384bee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38571c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3857460>],
#  [<matplotlib.lines.Line2D at 0x1c9b3857700>],
#  [<matplotlib.lines.Line2D at 0x1c9b38579a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3857c40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3857ee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38671c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3867460>],
#  [<matplotlib.lines.Line2D at 0x1c9b3867700>],
#  [<matplotlib.lines.Line2D at 0x1c9b38679a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3867c40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3867ee0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38751c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3875460>],
#  [<matplotlib.lines.Line2D at 0x1c9b3875700>],
#  [<matplotlib.lines.Line2D at 0x1c9b38759a0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3875c40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3875f10>],
#  [<matplotlib.lines.Line2D at 0x1c9b38821f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3882490>],
#  [<matplotlib.lines.Line2D at 0x1c9b3882730>],
#  [<matplotlib.lines.Line2D at 0x1c9b38829d0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3882c70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3882f10>],
#  [<matplotlib.lines.Line2D at 0x1c9b38921f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3892490>],
#  [<matplotlib.lines.Line2D at 0x1c9b3892730>],
#  [<matplotlib.lines.Line2D at 0x1c9b38929d0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3892c70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3892f10>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a01f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a0490>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a0730>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a09d0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a0c70>],
#  [<matplotlib.lines.Line2D at 0x1c9b38a0f10>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ae1f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ae490>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ae730>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ae9d0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38aec70>],
#  [<matplotlib.lines.Line2D at 0x1c9b38aef10>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ba220>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ba4c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38ba760>],
#  [<matplotlib.lines.Line2D at 0x1c9b38baa00>],
#  [<matplotlib.lines.Line2D at 0x1c9b38baca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38baf40>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c9220>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c94c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c9760>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c9a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c9ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38c9f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d8220>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d84c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d8760>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d8a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d8ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38d8f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e6220>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e64c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e6760>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e6a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e6ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38e6f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f2220>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f24c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f2760>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f2a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f2ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b38f2f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3903220>],
#  [<matplotlib.lines.Line2D at 0x1c9b39034c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3903760>],
#  [<matplotlib.lines.Line2D at 0x1c9b3903a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3903ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3903f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3910220>],
#  [<matplotlib.lines.Line2D at 0x1c9b39104c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3910760>],
#  [<matplotlib.lines.Line2D at 0x1c9b3910a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3910ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3910f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b3921220>],
#  [<matplotlib.lines.Line2D at 0x1c9b39214c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3921760>],
#  [<matplotlib.lines.Line2D at 0x1c9b3921a00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3921ca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3921f40>],
#  [<matplotlib.lines.Line2D at 0x1c9b392f220>],
#  [<matplotlib.lines.Line2D at 0x1c9b392f4c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b392f760>],
#  [<matplotlib.lines.Line2D at 0x1c9b392fa00>],
#  [<matplotlib.lines.Line2D at 0x1c9b392fca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b392ff40>],
#  [<matplotlib.lines.Line2D at 0x1c9b393c220>],
#  [<matplotlib.lines.Line2D at 0x1c9b393c4c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b393c760>],
#  [<matplotlib.lines.Line2D at 0x1c9b393ca00>],
#  [<matplotlib.lines.Line2D at 0x1c9b393cca0>],
#  [<matplotlib.lines.Line2D at 0x1c9b393cf40>],
#  [<matplotlib.lines.Line2D at 0x1c9b394a220>],
#  [<matplotlib.lines.Line2D at 0x1c9b394a4f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b394a790>],
#  [<matplotlib.lines.Line2D at 0x1c9b394aa30>],
#  [<matplotlib.lines.Line2D at 0x1c9b394acd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b394af70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3958250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39584f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3958790>],
#  [<matplotlib.lines.Line2D at 0x1c9b3958a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b3958cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3958f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3966250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39664f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3966790>],
#  [<matplotlib.lines.Line2D at 0x1c9b3966a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b3966cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3966f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3976250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39764f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3976790>],
#  [<matplotlib.lines.Line2D at 0x1c9b3976a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b3976cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3976f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3984250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39844f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3984790>],
#  [<matplotlib.lines.Line2D at 0x1c9b3984a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b3984cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3984f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3993250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39934f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3993790>],
#  [<matplotlib.lines.Line2D at 0x1c9b3993a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b3993cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3993f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a1250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a14f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a1790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a1a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a1cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39a1f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39ae250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39ae4f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39ae790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39aea30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39aecd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39aef70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bd250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bd4f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bd790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bda30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bdcd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39bdf70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39cc250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39cc4f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39cc790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39cca30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39cccd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39ccf70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d9250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d94f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d9790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d9a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d9cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39d9f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e8250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e84f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e8790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e8a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e8cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39e8f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f6250>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f64f0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f6790>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f6a30>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f6cd0>],
#  [<matplotlib.lines.Line2D at 0x1c9b39f6f70>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a05280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a05520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a057c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a05a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a05d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a05fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a13280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a13520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a137c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a13a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a13d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a13fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a21280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a21520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a217c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a21a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a21d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a21fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2f280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2f520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2f7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2fa60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2fd00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a2ffa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3e280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3e520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3e7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3ea60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3ed00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a3efa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4c280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4c520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4c7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4ca60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4cd00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a4cfa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5b280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5b520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5b7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5ba60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5bd00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a5bfa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a68280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a68520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a687c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a68a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a68d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a68fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a78280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a78520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a787c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a78a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a78d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a78fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a85280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a85520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a857c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a85a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a85d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a85fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a93280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a93520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a937c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a93a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a93d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3a93fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa2280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa2520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa27c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa2a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa2d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3aa2fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab0280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab0520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab07c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab0a60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab0d00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3ab0fa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abe280>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abe520>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abe7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abea60>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abed00>],
#  [<matplotlib.lines.Line2D at 0x1c9b3abefa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7e280>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7e520>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7e7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7ea60>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7ed00>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d7efa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8a280>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8a520>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8a7c0>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8aa60>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8ad00>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d8afa0>],
#  [<matplotlib.lines.Line2D at 0x1c9b4d98280>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3291952 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8238208 seconds ----------------
# iter 0: ||F|| = 0.000394432, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.111556 seconds ----------------
# iter 1: ||F|| = 0.000393203, sigma = 319.171
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.9123844 seconds ----------------
# iter 2: ||F|| = 5.57489e-05, sigma = 318.32
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2157845 seconds ----------------
# iter 3: ||F|| = 8.85367e-06, sigma = 324.724
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2883278 seconds ----------------
# iter 4: ||F|| = 2.29924e-06, sigma = 329.68
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1690157 seconds ----------------
# iter 5: ||F|| = 1.29444e-06, sigma = 357.696
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.046239 seconds ----------------
# iter 6: ||F|| = 2.00675e-06, sigma = 160.321
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.929662 seconds ----------------
# iter 7: ||F|| = 1.27363e-06, sigma = 249.102
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8760164 seconds ----------------
# iter 8: ||F|| = 1.06844e-06, sigma = 173.572
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6585911 seconds ----------------
# iter 9: ||F|| = 1.88552e-06, sigma = 110.202
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6284601 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$Xi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0]*1E6,meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0]*1E6,tolu, "o")
