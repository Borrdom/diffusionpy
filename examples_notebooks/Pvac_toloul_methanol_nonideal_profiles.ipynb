# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.5237477 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7332895 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0183083 seconds ----------------
# iter 0: ||F|| = 0.000952904, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0945479 seconds ----------------
# iter 1: ||F|| = 0.000948867, sigma = 236.017
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9383599 seconds ----------------
# iter 2: ||F|| = 0.000236612, sigma = 249.041
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9107974 seconds ----------------
# iter 3: ||F|| = 7.63534e-05, sigma = 299.199
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7849751 seconds ----------------
# iter 4: ||F|| = 2.42253e-05, sigma = 423.87
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7477792 seconds ----------------
# iter 5: ||F|| = 2.63748e-06, sigma = 413.857
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6918959 seconds ----------------
# iter 6: ||F|| = 9.64541e-07, sigma = 370.697
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7360775 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x191f6a83820>],
#  [<matplotlib.lines.Line2D at 0x191f6a83ac0>],
#  [<matplotlib.lines.Line2D at 0x191f6a83d60>],
#  [<matplotlib.lines.Line2D at 0x191f6a91040>],
#  [<matplotlib.lines.Line2D at 0x191f6a912e0>],
#  [<matplotlib.lines.Line2D at 0x191f6a91580>],
#  [<matplotlib.lines.Line2D at 0x191f6a91820>],
#  [<matplotlib.lines.Line2D at 0x191f6a91ac0>],
#  [<matplotlib.lines.Line2D at 0x191f6a91d60>],
#  [<matplotlib.lines.Line2D at 0x191f6a9d040>],
#  [<matplotlib.lines.Line2D at 0x191f6a9d2e0>],
#  [<matplotlib.lines.Line2D at 0x191f6a9d580>],
#  [<matplotlib.lines.Line2D at 0x191f6a9d820>],
#  [<matplotlib.lines.Line2D at 0x191f6a9dac0>],
#  [<matplotlib.lines.Line2D at 0x191f6a9dd60>],
#  [<matplotlib.lines.Line2D at 0x191f6aaa040>],
#  [<matplotlib.lines.Line2D at 0x191f6aaa2e0>],
#  [<matplotlib.lines.Line2D at 0x191f6aaa580>],
#  [<matplotlib.lines.Line2D at 0x191f6aaa820>],
#  [<matplotlib.lines.Line2D at 0x191f6aaaac0>],
#  [<matplotlib.lines.Line2D at 0x191f6aaad60>],
#  [<matplotlib.lines.Line2D at 0x191f6ab8040>],
#  [<matplotlib.lines.Line2D at 0x191f6ab82e0>],
#  [<matplotlib.lines.Line2D at 0x191f6ab8580>],
#  [<matplotlib.lines.Line2D at 0x191f6ab8820>],
#  [<matplotlib.lines.Line2D at 0x191f6ab8ac0>],
#  [<matplotlib.lines.Line2D at 0x191f6ab8d60>],
#  [<matplotlib.lines.Line2D at 0x191f6ac7040>],
#  [<matplotlib.lines.Line2D at 0x191f6ac72e0>],
#  [<matplotlib.lines.Line2D at 0x191f6ac7580>],
#  [<matplotlib.lines.Line2D at 0x191f6ac7820>],
#  [<matplotlib.lines.Line2D at 0x191f6ac7ac0>],
#  [<matplotlib.lines.Line2D at 0x191f6ac7d60>],
#  [<matplotlib.lines.Line2D at 0x191f6ad3040>],
#  [<matplotlib.lines.Line2D at 0x191f6ad32e0>],
#  [<matplotlib.lines.Line2D at 0x191f6ad3580>],
#  [<matplotlib.lines.Line2D at 0x191f6ad3820>],
#  [<matplotlib.lines.Line2D at 0x191f6ad3ac0>],
#  [<matplotlib.lines.Line2D at 0x191f6ad3d60>],
#  [<matplotlib.lines.Line2D at 0x191f6ae3040>],
#  [<matplotlib.lines.Line2D at 0x191f6ae3310>],
#  [<matplotlib.lines.Line2D at 0x191f6ae35b0>],
#  [<matplotlib.lines.Line2D at 0x191f6ae3850>],
#  [<matplotlib.lines.Line2D at 0x191f6ae3af0>],
#  [<matplotlib.lines.Line2D at 0x191f6ae3d90>],
#  [<matplotlib.lines.Line2D at 0x191f6af2070>],
#  [<matplotlib.lines.Line2D at 0x191f6af2310>],
#  [<matplotlib.lines.Line2D at 0x191f6af25b0>],
#  [<matplotlib.lines.Line2D at 0x191f6af2850>],
#  [<matplotlib.lines.Line2D at 0x191f6af2af0>],
#  [<matplotlib.lines.Line2D at 0x191f6af2d90>],
#  [<matplotlib.lines.Line2D at 0x191f6aff070>],
#  [<matplotlib.lines.Line2D at 0x191f6aff310>],
#  [<matplotlib.lines.Line2D at 0x191f6aff5b0>],
#  [<matplotlib.lines.Line2D at 0x191f6aff850>],
#  [<matplotlib.lines.Line2D at 0x191f6affaf0>],
#  [<matplotlib.lines.Line2D at 0x191f6affd90>],
#  [<matplotlib.lines.Line2D at 0x191f6b0e070>],
#  [<matplotlib.lines.Line2D at 0x191f6b0e310>],
#  [<matplotlib.lines.Line2D at 0x191f6b0e5b0>],
#  [<matplotlib.lines.Line2D at 0x191f6b0e850>],
#  [<matplotlib.lines.Line2D at 0x191f6b0eaf0>],
#  [<matplotlib.lines.Line2D at 0x191f6b0ed90>],
#  [<matplotlib.lines.Line2D at 0x191f6b1c070>],
#  [<matplotlib.lines.Line2D at 0x191f6b1c310>],
#  [<matplotlib.lines.Line2D at 0x191f6b1c5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6b1c880>],
#  [<matplotlib.lines.Line2D at 0x191f6b1cb20>],
#  [<matplotlib.lines.Line2D at 0x191f6b1cdc0>],
#  [<matplotlib.lines.Line2D at 0x191f6b2a0a0>],
#  [<matplotlib.lines.Line2D at 0x191f6b2a340>],
#  [<matplotlib.lines.Line2D at 0x191f6b2a5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6b2a880>],
#  [<matplotlib.lines.Line2D at 0x191f6b2ab20>],
#  [<matplotlib.lines.Line2D at 0x191f6b2adc0>],
#  [<matplotlib.lines.Line2D at 0x191f6b380a0>],
#  [<matplotlib.lines.Line2D at 0x191f6b38340>],
#  [<matplotlib.lines.Line2D at 0x191f6b385e0>],
#  [<matplotlib.lines.Line2D at 0x191f6b38880>],
#  [<matplotlib.lines.Line2D at 0x191f6b38b20>],
#  [<matplotlib.lines.Line2D at 0x191f6b38dc0>],
#  [<matplotlib.lines.Line2D at 0x191f6be70a0>],
#  [<matplotlib.lines.Line2D at 0x191f6be7340>],
#  [<matplotlib.lines.Line2D at 0x191f6be75e0>],
#  [<matplotlib.lines.Line2D at 0x191f6be7880>],
#  [<matplotlib.lines.Line2D at 0x191f6be7b20>],
#  [<matplotlib.lines.Line2D at 0x191f6be7dc0>],
#  [<matplotlib.lines.Line2D at 0x191f6bf60a0>],
#  [<matplotlib.lines.Line2D at 0x191f6bf6340>],
#  [<matplotlib.lines.Line2D at 0x191f6bf65e0>],
#  [<matplotlib.lines.Line2D at 0x191f6bf6880>],
#  [<matplotlib.lines.Line2D at 0x191f6bf6b20>],
#  [<matplotlib.lines.Line2D at 0x191f6bf6dc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c040a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c04340>],
#  [<matplotlib.lines.Line2D at 0x191f6c045e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c04880>],
#  [<matplotlib.lines.Line2D at 0x191f6c04b20>],
#  [<matplotlib.lines.Line2D at 0x191f6c04dc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c120a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c12340>],
#  [<matplotlib.lines.Line2D at 0x191f6c125e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c12880>],
#  [<matplotlib.lines.Line2D at 0x191f6c12b20>],
#  [<matplotlib.lines.Line2D at 0x191f6c12dc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c1f0a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c1f340>],
#  [<matplotlib.lines.Line2D at 0x191f6c1f5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c1f880>],
#  [<matplotlib.lines.Line2D at 0x191f6c1fb20>],
#  [<matplotlib.lines.Line2D at 0x191f6c1fdc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c2e0a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c2e340>],
#  [<matplotlib.lines.Line2D at 0x191f6c2e5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c2e880>],
#  [<matplotlib.lines.Line2D at 0x191f6c2eb20>],
#  [<matplotlib.lines.Line2D at 0x191f6c2edc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c3c0a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c3c340>],
#  [<matplotlib.lines.Line2D at 0x191f6c3c5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c3c880>],
#  [<matplotlib.lines.Line2D at 0x191f6c3cb20>],
#  [<matplotlib.lines.Line2D at 0x191f6c3cdc0>],
#  [<matplotlib.lines.Line2D at 0x191f6c4d0a0>],
#  [<matplotlib.lines.Line2D at 0x191f6c4d340>],
#  [<matplotlib.lines.Line2D at 0x191f6c4d5e0>],
#  [<matplotlib.lines.Line2D at 0x191f6c4d8b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c4db50>],
#  [<matplotlib.lines.Line2D at 0x191f6c4ddf0>],
#  [<matplotlib.lines.Line2D at 0x191f6c580d0>],
#  [<matplotlib.lines.Line2D at 0x191f6c58370>],
#  [<matplotlib.lines.Line2D at 0x191f6c58610>],
#  [<matplotlib.lines.Line2D at 0x191f6c588b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c58b50>],
#  [<matplotlib.lines.Line2D at 0x191f6c58df0>],
#  [<matplotlib.lines.Line2D at 0x191f6c680d0>],
#  [<matplotlib.lines.Line2D at 0x191f6c68370>],
#  [<matplotlib.lines.Line2D at 0x191f6c68610>],
#  [<matplotlib.lines.Line2D at 0x191f6c688b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c68b50>],
#  [<matplotlib.lines.Line2D at 0x191f6c68df0>],
#  [<matplotlib.lines.Line2D at 0x191f6c750d0>],
#  [<matplotlib.lines.Line2D at 0x191f6c75370>],
#  [<matplotlib.lines.Line2D at 0x191f6c75610>],
#  [<matplotlib.lines.Line2D at 0x191f6c758b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c75b50>],
#  [<matplotlib.lines.Line2D at 0x191f6c75df0>],
#  [<matplotlib.lines.Line2D at 0x191f6c840d0>],
#  [<matplotlib.lines.Line2D at 0x191f6c84370>],
#  [<matplotlib.lines.Line2D at 0x191f6c84610>],
#  [<matplotlib.lines.Line2D at 0x191f6c848b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c84b50>],
#  [<matplotlib.lines.Line2D at 0x191f6c84df0>],
#  [<matplotlib.lines.Line2D at 0x191f6c920d0>],
#  [<matplotlib.lines.Line2D at 0x191f6c92370>],
#  [<matplotlib.lines.Line2D at 0x191f6c92610>],
#  [<matplotlib.lines.Line2D at 0x191f6c928b0>],
#  [<matplotlib.lines.Line2D at 0x191f6c92b50>],
#  [<matplotlib.lines.Line2D at 0x191f6c92df0>],
#  [<matplotlib.lines.Line2D at 0x191f6ca10d0>],
#  [<matplotlib.lines.Line2D at 0x191f6ca1370>],
#  [<matplotlib.lines.Line2D at 0x191f6ca1610>],
#  [<matplotlib.lines.Line2D at 0x191f6ca18b0>],
#  [<matplotlib.lines.Line2D at 0x191f6ca1b50>],
#  [<matplotlib.lines.Line2D at 0x191f6ca1df0>],
#  [<matplotlib.lines.Line2D at 0x191f6caf0d0>],
#  [<matplotlib.lines.Line2D at 0x191f6caf370>],
#  [<matplotlib.lines.Line2D at 0x191f6caf610>],
#  [<matplotlib.lines.Line2D at 0x191f6caf8b0>],
#  [<matplotlib.lines.Line2D at 0x191f6cafb50>],
#  [<matplotlib.lines.Line2D at 0x191f6cafdf0>],
#  [<matplotlib.lines.Line2D at 0x191f6cbf0d0>],
#  [<matplotlib.lines.Line2D at 0x191f6cbf370>],
#  [<matplotlib.lines.Line2D at 0x191f6cbf610>],
#  [<matplotlib.lines.Line2D at 0x191f6cbf8b0>],
#  [<matplotlib.lines.Line2D at 0x191f6cbfb50>],
#  [<matplotlib.lines.Line2D at 0x191f6cbfdf0>],
#  [<matplotlib.lines.Line2D at 0x191f6ccb0d0>],
#  [<matplotlib.lines.Line2D at 0x191f6ccb370>],
#  [<matplotlib.lines.Line2D at 0x191f6ccb610>],
#  [<matplotlib.lines.Line2D at 0x191f6ccb8b0>],
#  [<matplotlib.lines.Line2D at 0x191f6ccbb50>],
#  [<matplotlib.lines.Line2D at 0x191f6ccbdf0>],
#  [<matplotlib.lines.Line2D at 0x191f6cd90d0>],
#  [<matplotlib.lines.Line2D at 0x191f6cd9370>],
#  [<matplotlib.lines.Line2D at 0x191f6cd9610>],
#  [<matplotlib.lines.Line2D at 0x191f6cd98b0>],
#  [<matplotlib.lines.Line2D at 0x191f6cd9b50>],
#  [<matplotlib.lines.Line2D at 0x191f6cd9df0>],
#  [<matplotlib.lines.Line2D at 0x191f6ce80d0>],
#  [<matplotlib.lines.Line2D at 0x191f6ce8370>],
#  [<matplotlib.lines.Line2D at 0x191f6ce8610>],
#  [<matplotlib.lines.Line2D at 0x191f6ce88b0>],
#  [<matplotlib.lines.Line2D at 0x191f6ce8b50>],
#  [<matplotlib.lines.Line2D at 0x191f6ce8df0>],
#  [<matplotlib.lines.Line2D at 0x191f6cf70d0>],
#  [<matplotlib.lines.Line2D at 0x191f6cf7370>],
#  [<matplotlib.lines.Line2D at 0x191f6cf7610>],
#  [<matplotlib.lines.Line2D at 0x191f6cf78b0>],
#  [<matplotlib.lines.Line2D at 0x191f6cf7b50>],
#  [<matplotlib.lines.Line2D at 0x191f6cf7df0>],
#  [<matplotlib.lines.Line2D at 0x191f6d040d0>],
#  [<matplotlib.lines.Line2D at 0x191f6d04370>],
#  [<matplotlib.lines.Line2D at 0x191f6d04640>],
#  [<matplotlib.lines.Line2D at 0x191f6d048e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d04b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d04e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d13100>],
#  [<matplotlib.lines.Line2D at 0x191f6d133a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d13640>],
#  [<matplotlib.lines.Line2D at 0x191f6d138e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d13b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d13e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d21100>],
#  [<matplotlib.lines.Line2D at 0x191f6d213a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d21640>],
#  [<matplotlib.lines.Line2D at 0x191f6d218e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d21b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d21e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d30100>],
#  [<matplotlib.lines.Line2D at 0x191f6d303a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d30640>],
#  [<matplotlib.lines.Line2D at 0x191f6d308e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d30b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d30e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d3f100>],
#  [<matplotlib.lines.Line2D at 0x191f6d3f3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d3f640>],
#  [<matplotlib.lines.Line2D at 0x191f6d3f8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d3fb80>],
#  [<matplotlib.lines.Line2D at 0x191f6d3fe20>],
#  [<matplotlib.lines.Line2D at 0x191f6d4c100>],
#  [<matplotlib.lines.Line2D at 0x191f6d4c3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d4c640>],
#  [<matplotlib.lines.Line2D at 0x191f6d4c8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d4cb80>],
#  [<matplotlib.lines.Line2D at 0x191f6d4ce20>],
#  [<matplotlib.lines.Line2D at 0x191f6d5a100>],
#  [<matplotlib.lines.Line2D at 0x191f6d5a3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d5a640>],
#  [<matplotlib.lines.Line2D at 0x191f6d5a8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d5ab80>],
#  [<matplotlib.lines.Line2D at 0x191f6d5ae20>],
#  [<matplotlib.lines.Line2D at 0x191f6d69100>],
#  [<matplotlib.lines.Line2D at 0x191f6d693a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d69640>],
#  [<matplotlib.lines.Line2D at 0x191f6d698e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d69b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d69e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d78100>],
#  [<matplotlib.lines.Line2D at 0x191f6d783a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d78640>],
#  [<matplotlib.lines.Line2D at 0x191f6d788e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d78b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d78e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d85100>],
#  [<matplotlib.lines.Line2D at 0x191f6d853a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d85640>],
#  [<matplotlib.lines.Line2D at 0x191f6d858e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d85b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d85e20>],
#  [<matplotlib.lines.Line2D at 0x191f6d95100>],
#  [<matplotlib.lines.Line2D at 0x191f6d953a0>],
#  [<matplotlib.lines.Line2D at 0x191f6d95640>],
#  [<matplotlib.lines.Line2D at 0x191f6d958e0>],
#  [<matplotlib.lines.Line2D at 0x191f6d95b80>],
#  [<matplotlib.lines.Line2D at 0x191f6d95e20>],
#  [<matplotlib.lines.Line2D at 0x191f6da3100>],
#  [<matplotlib.lines.Line2D at 0x191f6da33a0>],
#  [<matplotlib.lines.Line2D at 0x191f6da3640>],
#  [<matplotlib.lines.Line2D at 0x191f6da38e0>],
#  [<matplotlib.lines.Line2D at 0x191f6da3b80>],
#  [<matplotlib.lines.Line2D at 0x191f6da3e20>],
#  [<matplotlib.lines.Line2D at 0x191f6db0100>],
#  [<matplotlib.lines.Line2D at 0x191f6db03a0>],
#  [<matplotlib.lines.Line2D at 0x191f6db0640>],
#  [<matplotlib.lines.Line2D at 0x191f6db08e0>],
#  [<matplotlib.lines.Line2D at 0x191f6db0b80>],
#  [<matplotlib.lines.Line2D at 0x191f6db0e20>],
#  [<matplotlib.lines.Line2D at 0x191f6dbf100>],
#  [<matplotlib.lines.Line2D at 0x191f6dbf3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6dbf640>],
#  [<matplotlib.lines.Line2D at 0x191f6dbf8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6dbfb80>],
#  [<matplotlib.lines.Line2D at 0x191f6dbfe20>],
#  [<matplotlib.lines.Line2D at 0x191f6dcc100>],
#  [<matplotlib.lines.Line2D at 0x191f6dcc3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6dcc640>],
#  [<matplotlib.lines.Line2D at 0x191f6dcc8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6dccb80>],
#  [<matplotlib.lines.Line2D at 0x191f6dcce20>],
#  [<matplotlib.lines.Line2D at 0x191f6ddd100>],
#  [<matplotlib.lines.Line2D at 0x191f6ddd3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6ddd640>],
#  [<matplotlib.lines.Line2D at 0x191f6ddd8e0>],
#  [<matplotlib.lines.Line2D at 0x191f6dddb80>],
#  [<matplotlib.lines.Line2D at 0x191f6ddde20>],
#  [<matplotlib.lines.Line2D at 0x191f6deb100>],
#  [<matplotlib.lines.Line2D at 0x191f6deb3a0>],
#  [<matplotlib.lines.Line2D at 0x191f6deb640>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4698661 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9324045 seconds ----------------
# iter 0: ||F|| = 0.000402406, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.5029594 seconds ----------------
# iter 1: ||F|| = 0.000401186, sigma = 327.194
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2128768 seconds ----------------
# iter 2: ||F|| = 6.51916e-05, sigma = 321.181
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3234136 seconds ----------------
# iter 3: ||F|| = 1.07586e-05, sigma = 318.507
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0077315 seconds ----------------
# iter 4: ||F|| = 3.16307e-06, sigma = 315.703
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.077449 seconds ----------------
# iter 5: ||F|| = 2.28175e-06, sigma = 221.916
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1031087 seconds ----------------
# iter 6: ||F|| = 1.62489e-06, sigma = 142.763
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0921268 seconds ----------------
# iter 7: ||F|| = 1.02343e-06, sigma = 92.4727
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0879728 seconds ----------------
# iter 8: ||F|| = 3.47399e-06, sigma = 43.3811
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1088796 seconds ----------------
# iter 9: ||F|| = 9.98741e-07, sigma = 42.5048
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0426682 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$Xi$ / -')
ax4.set_xlabel('$z$ / µm')
ax4.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0]*1E6,meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0]*1E6,tolu, "o")

ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig
