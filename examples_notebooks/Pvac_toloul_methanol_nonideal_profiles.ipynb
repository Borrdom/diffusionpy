# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1432311 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1973717 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.375005 seconds ----------------
# iter 0: ||F|| = 0.000862385, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2967015 seconds ----------------
# iter 1: ||F|| = 0.000858951, sigma = 251.139
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4329314 seconds ----------------
# iter 2: ||F|| = 0.000181433, sigma = 262.119
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4455353 seconds ----------------
# iter 3: ||F|| = 4.8507e-05, sigma = 280.574
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.31504 seconds ----------------
# iter 4: ||F|| = 1.2795e-05, sigma = 370.41
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.251523 seconds ----------------
# iter 5: ||F|| = 1.70271e-06, sigma = 397.689
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2450009 seconds ----------------
# iter 6: ||F|| = 4.79351e-07, sigma = 342.715
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2388385 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x29a6da15130>],
#  [<matplotlib.lines.Line2D at 0x29a6da153d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da15670>],
#  [<matplotlib.lines.Line2D at 0x29a6da15910>],
#  [<matplotlib.lines.Line2D at 0x29a6da15bb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da15e50>],
#  [<matplotlib.lines.Line2D at 0x29a6da20130>],
#  [<matplotlib.lines.Line2D at 0x29a6da203d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da20670>],
#  [<matplotlib.lines.Line2D at 0x29a6da20910>],
#  [<matplotlib.lines.Line2D at 0x29a6da20bb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da20e50>],
#  [<matplotlib.lines.Line2D at 0x29a6da2c130>],
#  [<matplotlib.lines.Line2D at 0x29a6da2c3d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da2c670>],
#  [<matplotlib.lines.Line2D at 0x29a6da2c910>],
#  [<matplotlib.lines.Line2D at 0x29a6da2cbb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da2ce50>],
#  [<matplotlib.lines.Line2D at 0x29a6da3a130>],
#  [<matplotlib.lines.Line2D at 0x29a6da3a3d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da3a670>],
#  [<matplotlib.lines.Line2D at 0x29a6da3a910>],
#  [<matplotlib.lines.Line2D at 0x29a6da3abb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da3ae50>],
#  [<matplotlib.lines.Line2D at 0x29a6da49130>],
#  [<matplotlib.lines.Line2D at 0x29a6da493d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da49670>],
#  [<matplotlib.lines.Line2D at 0x29a6da49910>],
#  [<matplotlib.lines.Line2D at 0x29a6da49bb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da49e50>],
#  [<matplotlib.lines.Line2D at 0x29a6da55130>],
#  [<matplotlib.lines.Line2D at 0x29a6da553d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da55670>],
#  [<matplotlib.lines.Line2D at 0x29a6da55910>],
#  [<matplotlib.lines.Line2D at 0x29a6da55bb0>],
#  [<matplotlib.lines.Line2D at 0x29a6da55e50>],
#  [<matplotlib.lines.Line2D at 0x29a6da65130>],
#  [<matplotlib.lines.Line2D at 0x29a6da653d0>],
#  [<matplotlib.lines.Line2D at 0x29a6da65670>],
#  [<matplotlib.lines.Line2D at 0x29a6da65910>],
#  [<matplotlib.lines.Line2D at 0x29a6da65be0>],
#  [<matplotlib.lines.Line2D at 0x29a6da65e80>],
#  [<matplotlib.lines.Line2D at 0x29a6da74160>],
#  [<matplotlib.lines.Line2D at 0x29a6da74400>],
#  [<matplotlib.lines.Line2D at 0x29a6da746a0>],
#  [<matplotlib.lines.Line2D at 0x29a6da74940>],
#  [<matplotlib.lines.Line2D at 0x29a6da74be0>],
#  [<matplotlib.lines.Line2D at 0x29a6da74e80>],
#  [<matplotlib.lines.Line2D at 0x29a6da80160>],
#  [<matplotlib.lines.Line2D at 0x29a6da80400>],
#  [<matplotlib.lines.Line2D at 0x29a6da806a0>],
#  [<matplotlib.lines.Line2D at 0x29a6da80940>],
#  [<matplotlib.lines.Line2D at 0x29a6da80be0>],
#  [<matplotlib.lines.Line2D at 0x29a6da80e80>],
#  [<matplotlib.lines.Line2D at 0x29a6da91160>],
#  [<matplotlib.lines.Line2D at 0x29a6da91400>],
#  [<matplotlib.lines.Line2D at 0x29a6da916a0>],
#  [<matplotlib.lines.Line2D at 0x29a6da91940>],
#  [<matplotlib.lines.Line2D at 0x29a6da91be0>],
#  [<matplotlib.lines.Line2D at 0x29a6da91e80>],
#  [<matplotlib.lines.Line2D at 0x29a6da9f160>],
#  [<matplotlib.lines.Line2D at 0x29a6da9f400>],
#  [<matplotlib.lines.Line2D at 0x29a6da9f6a0>],
#  [<matplotlib.lines.Line2D at 0x29a6da9f940>],
#  [<matplotlib.lines.Line2D at 0x29a6da9fbe0>],
#  [<matplotlib.lines.Line2D at 0x29a6da9feb0>],
#  [<matplotlib.lines.Line2D at 0x29a6daaa190>],
#  [<matplotlib.lines.Line2D at 0x29a6daaa430>],
#  [<matplotlib.lines.Line2D at 0x29a6daaa6d0>],
#  [<matplotlib.lines.Line2D at 0x29a6daaa970>],
#  [<matplotlib.lines.Line2D at 0x29a6daaac10>],
#  [<matplotlib.lines.Line2D at 0x29a6daaaeb0>],
#  [<matplotlib.lines.Line2D at 0x29a6daba190>],
#  [<matplotlib.lines.Line2D at 0x29a6daba430>],
#  [<matplotlib.lines.Line2D at 0x29a6daba6d0>],
#  [<matplotlib.lines.Line2D at 0x29a6daba970>],
#  [<matplotlib.lines.Line2D at 0x29a6dabac10>],
#  [<matplotlib.lines.Line2D at 0x29a6dabaeb0>],
#  [<matplotlib.lines.Line2D at 0x29a6dac8190>],
#  [<matplotlib.lines.Line2D at 0x29a6dac8430>],
#  [<matplotlib.lines.Line2D at 0x29a6dac86d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dac8970>],
#  [<matplotlib.lines.Line2D at 0x29a6dac8c10>],
#  [<matplotlib.lines.Line2D at 0x29a6dac8eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6dad7190>],
#  [<matplotlib.lines.Line2D at 0x29a6dad7430>],
#  [<matplotlib.lines.Line2D at 0x29a6dad76d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dad7970>],
#  [<matplotlib.lines.Line2D at 0x29a6dad7c10>],
#  [<matplotlib.lines.Line2D at 0x29a6dad7eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6dae7190>],
#  [<matplotlib.lines.Line2D at 0x29a6dae7430>],
#  [<matplotlib.lines.Line2D at 0x29a6dae76d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dae7970>],
#  [<matplotlib.lines.Line2D at 0x29a6dae7c10>],
#  [<matplotlib.lines.Line2D at 0x29a6dae7eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6daf3190>],
#  [<matplotlib.lines.Line2D at 0x29a6daf3430>],
#  [<matplotlib.lines.Line2D at 0x29a6daf36d0>],
#  [<matplotlib.lines.Line2D at 0x29a6daf3970>],
#  [<matplotlib.lines.Line2D at 0x29a6daf3c10>],
#  [<matplotlib.lines.Line2D at 0x29a6daf3eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6db02190>],
#  [<matplotlib.lines.Line2D at 0x29a6db02430>],
#  [<matplotlib.lines.Line2D at 0x29a6db026d0>],
#  [<matplotlib.lines.Line2D at 0x29a6db02970>],
#  [<matplotlib.lines.Line2D at 0x29a6db02c10>],
#  [<matplotlib.lines.Line2D at 0x29a6db02eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6db11190>],
#  [<matplotlib.lines.Line2D at 0x29a6db11430>],
#  [<matplotlib.lines.Line2D at 0x29a6db116d0>],
#  [<matplotlib.lines.Line2D at 0x29a6db11970>],
#  [<matplotlib.lines.Line2D at 0x29a6db11c10>],
#  [<matplotlib.lines.Line2D at 0x29a6db11eb0>],
#  [<matplotlib.lines.Line2D at 0x29a6db1f190>],
#  [<matplotlib.lines.Line2D at 0x29a6db1f430>],
#  [<matplotlib.lines.Line2D at 0x29a6db1f6d0>],
#  [<matplotlib.lines.Line2D at 0x29a6db1f970>],
#  [<matplotlib.lines.Line2D at 0x29a6db1fc10>],
#  [<matplotlib.lines.Line2D at 0x29a6db1feb0>],
#  [<matplotlib.lines.Line2D at 0x29a6db2d190>],
#  [<matplotlib.lines.Line2D at 0x29a6db2d430>],
#  [<matplotlib.lines.Line2D at 0x29a6db2d6d0>],
#  [<matplotlib.lines.Line2D at 0x29a6db2d970>],
#  [<matplotlib.lines.Line2D at 0x29a6db2dc10>],
#  [<matplotlib.lines.Line2D at 0x29a6db2deb0>],
#  [<matplotlib.lines.Line2D at 0x29a6db3d1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db3d460>],
#  [<matplotlib.lines.Line2D at 0x29a6db3d700>],
#  [<matplotlib.lines.Line2D at 0x29a6db3d9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db3dc40>],
#  [<matplotlib.lines.Line2D at 0x29a6db3dee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db4a1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db4a460>],
#  [<matplotlib.lines.Line2D at 0x29a6db4a700>],
#  [<matplotlib.lines.Line2D at 0x29a6db4a9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db4ac40>],
#  [<matplotlib.lines.Line2D at 0x29a6db4aee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db581c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db58460>],
#  [<matplotlib.lines.Line2D at 0x29a6db58700>],
#  [<matplotlib.lines.Line2D at 0x29a6db589a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db58c40>],
#  [<matplotlib.lines.Line2D at 0x29a6db58ee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db661c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db66460>],
#  [<matplotlib.lines.Line2D at 0x29a6db66700>],
#  [<matplotlib.lines.Line2D at 0x29a6db669a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db66c40>],
#  [<matplotlib.lines.Line2D at 0x29a6db66ee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db751c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db75460>],
#  [<matplotlib.lines.Line2D at 0x29a6db75700>],
#  [<matplotlib.lines.Line2D at 0x29a6db759a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db75c40>],
#  [<matplotlib.lines.Line2D at 0x29a6db75ee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db831c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db83460>],
#  [<matplotlib.lines.Line2D at 0x29a6db83700>],
#  [<matplotlib.lines.Line2D at 0x29a6db839a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db83c40>],
#  [<matplotlib.lines.Line2D at 0x29a6db83ee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db931c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db93460>],
#  [<matplotlib.lines.Line2D at 0x29a6db93700>],
#  [<matplotlib.lines.Line2D at 0x29a6db939a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db93c40>],
#  [<matplotlib.lines.Line2D at 0x29a6db93ee0>],
#  [<matplotlib.lines.Line2D at 0x29a6db9f1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6db9f460>],
#  [<matplotlib.lines.Line2D at 0x29a6db9f700>],
#  [<matplotlib.lines.Line2D at 0x29a6db9f9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6db9fc40>],
#  [<matplotlib.lines.Line2D at 0x29a6db9fee0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbae1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbae460>],
#  [<matplotlib.lines.Line2D at 0x29a6dbae700>],
#  [<matplotlib.lines.Line2D at 0x29a6dbae9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbaec40>],
#  [<matplotlib.lines.Line2D at 0x29a6dbaeee0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbc1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbc460>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbc700>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbc9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbcc40>],
#  [<matplotlib.lines.Line2D at 0x29a6dbbcee0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcb1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcb460>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcb700>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcb9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcbc40>],
#  [<matplotlib.lines.Line2D at 0x29a6dbcbee0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbda1c0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbda460>],
#  [<matplotlib.lines.Line2D at 0x29a6dbda700>],
#  [<matplotlib.lines.Line2D at 0x29a6dbda9a0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbdac40>],
#  [<matplotlib.lines.Line2D at 0x29a6dbdaee0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe81c0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe8460>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe8700>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe89a0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe8c40>],
#  [<matplotlib.lines.Line2D at 0x29a6dbe8f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf41f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf4490>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf4730>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf49d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf4c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dbf4f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc031f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc03490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc03730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc039d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc03c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc03f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc131f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc13490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc13730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc139d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc13c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc13f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc201f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc20490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc20730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc209d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc20c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc20f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2e1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2e490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2e730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2e9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2ec70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc2ef10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3c1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3c490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3c730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3c9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3cc70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc3cf10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4b1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4b490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4b730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4b9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4bc70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc4bf10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc581f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc58490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc58730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc589d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc58c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc58f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc681f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc68490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc68730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc689d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc68c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc68f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc771f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc77490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc77730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc779d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc77c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc77f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc841f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc84490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc84730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc849d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc84c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc84f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dc921f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc92490>],
#  [<matplotlib.lines.Line2D at 0x29a6dc92730>],
#  [<matplotlib.lines.Line2D at 0x29a6dc929d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dc92c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dc92f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dca01f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dca0490>],
#  [<matplotlib.lines.Line2D at 0x29a6dca0730>],
#  [<matplotlib.lines.Line2D at 0x29a6dca09d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dca0c70>],
#  [<matplotlib.lines.Line2D at 0x29a6dca0f10>],
#  [<matplotlib.lines.Line2D at 0x29a6dcae1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6dcae490>],
#  [<matplotlib.lines.Line2D at 0x29a6dcae730>],
#  [<matplotlib.lines.Line2D at 0x29a6dcae9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6dcaec70>],
#  [<matplotlib.lines.Line2D at 0x29a6dcaef10>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7d1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7d490>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7d730>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7d9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7dc70>],
#  [<matplotlib.lines.Line2D at 0x29a6ef7df10>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8c1f0>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8c490>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8c730>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8c9d0>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8cc70>],
#  [<matplotlib.lines.Line2D at 0x29a6ef8cf10>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2846116 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7543837 seconds ----------------
# iter 0: ||F|| = 0.000394432, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4153444 seconds ----------------
# iter 1: ||F|| = 0.000393203, sigma = 319.171
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4663339 seconds ----------------
# iter 2: ||F|| = 5.57489e-05, sigma = 318.32
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5109782 seconds ----------------
# iter 3: ||F|| = 8.85367e-06, sigma = 324.724
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4987153 seconds ----------------
# iter 4: ||F|| = 2.29924e-06, sigma = 329.68
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4301095 seconds ----------------
# iter 5: ||F|| = 1.29444e-06, sigma = 357.696
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3800071 seconds ----------------
# iter 6: ||F|| = 2.00675e-06, sigma = 160.321
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5206235 seconds ----------------
# iter 7: ||F|| = 1.27363e-06, sigma = 249.102
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5398704 seconds ----------------
# iter 8: ||F|| = 1.06844e-06, sigma = 173.572
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4600586 seconds ----------------
# iter 9: ||F|| = 1.88552e-06, sigma = 110.202
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5339939 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$Xi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0],meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0],tolu, "o")
