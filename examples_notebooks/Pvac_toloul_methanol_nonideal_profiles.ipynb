# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6964422 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5140009 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9244607 seconds ----------------
# iter 0: ||F|| = 0.000535254, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8068166 seconds ----------------
# iter 1: ||F|| = 0.000533372, sigma = 284.318
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.6209297 seconds ----------------
# iter 2: ||F|| = 0.000149838, sigma = 288.415
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4735681 seconds ----------------
# iter 3: ||F|| = 4.16876e-05, sigma = 343.341
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.541728 seconds ----------------
# iter 4: ||F|| = 1.28138e-05, sigma = 414.762
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0725471 seconds ----------------
# iter 5: ||F|| = 4.16046e-06, sigma = 340.164
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2012434 seconds ----------------
# iter 6: ||F|| = 1.30724e-06, sigma = 266.014
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1107614 seconds ----------------
# iter 7: ||F|| = 1.21038e-07, sigma = 261.823
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4796135 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x131a4ca93d0>],
#  [<matplotlib.lines.Line2D at 0x131a4ca9670>],
#  [<matplotlib.lines.Line2D at 0x131a4ca9910>],
#  [<matplotlib.lines.Line2D at 0x131a4ca9bb0>],
#  [<matplotlib.lines.Line2D at 0x131a4ca9e50>],
#  [<matplotlib.lines.Line2D at 0x131a4cb4130>],
#  [<matplotlib.lines.Line2D at 0x131a4cb43d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cb4670>],
#  [<matplotlib.lines.Line2D at 0x131a4cb4910>],
#  [<matplotlib.lines.Line2D at 0x131a4cb4bb0>],
#  [<matplotlib.lines.Line2D at 0x131a4cb4e50>],
#  [<matplotlib.lines.Line2D at 0x131a4cc2130>],
#  [<matplotlib.lines.Line2D at 0x131a4cc23d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cc2670>],
#  [<matplotlib.lines.Line2D at 0x131a4cc2910>],
#  [<matplotlib.lines.Line2D at 0x131a4cc2bb0>],
#  [<matplotlib.lines.Line2D at 0x131a4cc2e50>],
#  [<matplotlib.lines.Line2D at 0x131a4cce130>],
#  [<matplotlib.lines.Line2D at 0x131a4cce3d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cce670>],
#  [<matplotlib.lines.Line2D at 0x131a4cce910>],
#  [<matplotlib.lines.Line2D at 0x131a4ccebb0>],
#  [<matplotlib.lines.Line2D at 0x131a4ccee50>],
#  [<matplotlib.lines.Line2D at 0x131a4cdd130>],
#  [<matplotlib.lines.Line2D at 0x131a4cdd3d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cdd670>],
#  [<matplotlib.lines.Line2D at 0x131a4cdd910>],
#  [<matplotlib.lines.Line2D at 0x131a4cddbb0>],
#  [<matplotlib.lines.Line2D at 0x131a4cdde50>],
#  [<matplotlib.lines.Line2D at 0x131a4cec130>],
#  [<matplotlib.lines.Line2D at 0x131a4cec3d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cec670>],
#  [<matplotlib.lines.Line2D at 0x131a4cec910>],
#  [<matplotlib.lines.Line2D at 0x131a4cecbb0>],
#  [<matplotlib.lines.Line2D at 0x131a4cece50>],
#  [<matplotlib.lines.Line2D at 0x131a4cf9130>],
#  [<matplotlib.lines.Line2D at 0x131a4cf93d0>],
#  [<matplotlib.lines.Line2D at 0x131a4cf9670>],
#  [<matplotlib.lines.Line2D at 0x131a4cf9910>],
#  [<matplotlib.lines.Line2D at 0x131a4cf9bb0>],
#  [<matplotlib.lines.Line2D at 0x131a4cf9e80>],
#  [<matplotlib.lines.Line2D at 0x131a4d07160>],
#  [<matplotlib.lines.Line2D at 0x131a4d07400>],
#  [<matplotlib.lines.Line2D at 0x131a4d076a0>],
#  [<matplotlib.lines.Line2D at 0x131a4d07940>],
#  [<matplotlib.lines.Line2D at 0x131a4d07be0>],
#  [<matplotlib.lines.Line2D at 0x131a4d07e80>],
#  [<matplotlib.lines.Line2D at 0x131a4d18160>],
#  [<matplotlib.lines.Line2D at 0x131a4d18400>],
#  [<matplotlib.lines.Line2D at 0x131a4d186a0>],
#  [<matplotlib.lines.Line2D at 0x131a4d18940>],
#  [<matplotlib.lines.Line2D at 0x131a4d18be0>],
#  [<matplotlib.lines.Line2D at 0x131a4d18e80>],
#  [<matplotlib.lines.Line2D at 0x131a4d25160>],
#  [<matplotlib.lines.Line2D at 0x131a4d25400>],
#  [<matplotlib.lines.Line2D at 0x131a4d256a0>],
#  [<matplotlib.lines.Line2D at 0x131a4d25940>],
#  [<matplotlib.lines.Line2D at 0x131a4d25be0>],
#  [<matplotlib.lines.Line2D at 0x131a4d25e80>],
#  [<matplotlib.lines.Line2D at 0x131a4d33160>],
#  [<matplotlib.lines.Line2D at 0x131a4d33400>],
#  [<matplotlib.lines.Line2D at 0x131a4d336a0>],
#  [<matplotlib.lines.Line2D at 0x131a4d33940>],
#  [<matplotlib.lines.Line2D at 0x131a4d33be0>],
#  [<matplotlib.lines.Line2D at 0x131a4d33e80>],
#  [<matplotlib.lines.Line2D at 0x131a4d40190>],
#  [<matplotlib.lines.Line2D at 0x131a4d40430>],
#  [<matplotlib.lines.Line2D at 0x131a4d406d0>],
#  [<matplotlib.lines.Line2D at 0x131a4d40970>],
#  [<matplotlib.lines.Line2D at 0x131a4d40c10>],
#  [<matplotlib.lines.Line2D at 0x131a4d40eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4d50190>],
#  [<matplotlib.lines.Line2D at 0x131a4d50430>],
#  [<matplotlib.lines.Line2D at 0x131a4d506d0>],
#  [<matplotlib.lines.Line2D at 0x131a4d50970>],
#  [<matplotlib.lines.Line2D at 0x131a4d50c10>],
#  [<matplotlib.lines.Line2D at 0x131a4d50eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4d5d190>],
#  [<matplotlib.lines.Line2D at 0x131a4d5d430>],
#  [<matplotlib.lines.Line2D at 0x131a4d5d6d0>],
#  [<matplotlib.lines.Line2D at 0x131a4d5d970>],
#  [<matplotlib.lines.Line2D at 0x131a4d5dc10>],
#  [<matplotlib.lines.Line2D at 0x131a4d5deb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e4c190>],
#  [<matplotlib.lines.Line2D at 0x131a4e4c430>],
#  [<matplotlib.lines.Line2D at 0x131a4e4c6d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e4c970>],
#  [<matplotlib.lines.Line2D at 0x131a4e4cc10>],
#  [<matplotlib.lines.Line2D at 0x131a4e4ceb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e59190>],
#  [<matplotlib.lines.Line2D at 0x131a4e59430>],
#  [<matplotlib.lines.Line2D at 0x131a4e596d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e59970>],
#  [<matplotlib.lines.Line2D at 0x131a4e59c10>],
#  [<matplotlib.lines.Line2D at 0x131a4e59eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e68190>],
#  [<matplotlib.lines.Line2D at 0x131a4e68430>],
#  [<matplotlib.lines.Line2D at 0x131a4e686d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e68970>],
#  [<matplotlib.lines.Line2D at 0x131a4e68c10>],
#  [<matplotlib.lines.Line2D at 0x131a4e68eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e77190>],
#  [<matplotlib.lines.Line2D at 0x131a4e77430>],
#  [<matplotlib.lines.Line2D at 0x131a4e776d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e77970>],
#  [<matplotlib.lines.Line2D at 0x131a4e77c10>],
#  [<matplotlib.lines.Line2D at 0x131a4e77eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e85190>],
#  [<matplotlib.lines.Line2D at 0x131a4e85430>],
#  [<matplotlib.lines.Line2D at 0x131a4e856d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e85970>],
#  [<matplotlib.lines.Line2D at 0x131a4e85c10>],
#  [<matplotlib.lines.Line2D at 0x131a4e85eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4e93190>],
#  [<matplotlib.lines.Line2D at 0x131a4e93430>],
#  [<matplotlib.lines.Line2D at 0x131a4e936d0>],
#  [<matplotlib.lines.Line2D at 0x131a4e93970>],
#  [<matplotlib.lines.Line2D at 0x131a4e93c10>],
#  [<matplotlib.lines.Line2D at 0x131a4e93eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4ea2190>],
#  [<matplotlib.lines.Line2D at 0x131a4ea2430>],
#  [<matplotlib.lines.Line2D at 0x131a4ea26d0>],
#  [<matplotlib.lines.Line2D at 0x131a4ea2970>],
#  [<matplotlib.lines.Line2D at 0x131a4ea2c10>],
#  [<matplotlib.lines.Line2D at 0x131a4ea2eb0>],
#  [<matplotlib.lines.Line2D at 0x131a4eaf190>],
#  [<matplotlib.lines.Line2D at 0x131a4eaf460>],
#  [<matplotlib.lines.Line2D at 0x131a4eaf700>],
#  [<matplotlib.lines.Line2D at 0x131a4eaf9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4eafc40>],
#  [<matplotlib.lines.Line2D at 0x131a4eafee0>],
#  [<matplotlib.lines.Line2D at 0x131a4ebc1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4ebc460>],
#  [<matplotlib.lines.Line2D at 0x131a4ebc700>],
#  [<matplotlib.lines.Line2D at 0x131a4ebc9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4ebcc40>],
#  [<matplotlib.lines.Line2D at 0x131a4ebcee0>],
#  [<matplotlib.lines.Line2D at 0x131a4ecd1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4ecd460>],
#  [<matplotlib.lines.Line2D at 0x131a4ecd700>],
#  [<matplotlib.lines.Line2D at 0x131a4ecd9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4ecdc40>],
#  [<matplotlib.lines.Line2D at 0x131a4ecdee0>],
#  [<matplotlib.lines.Line2D at 0x131a4edc1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4edc460>],
#  [<matplotlib.lines.Line2D at 0x131a4edc700>],
#  [<matplotlib.lines.Line2D at 0x131a4edc9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4edcc40>],
#  [<matplotlib.lines.Line2D at 0x131a4edcee0>],
#  [<matplotlib.lines.Line2D at 0x131a4ee91c0>],
#  [<matplotlib.lines.Line2D at 0x131a4ee9460>],
#  [<matplotlib.lines.Line2D at 0x131a4ee9700>],
#  [<matplotlib.lines.Line2D at 0x131a4ee99a0>],
#  [<matplotlib.lines.Line2D at 0x131a4ee9c40>],
#  [<matplotlib.lines.Line2D at 0x131a4ee9ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4ef91c0>],
#  [<matplotlib.lines.Line2D at 0x131a4ef9460>],
#  [<matplotlib.lines.Line2D at 0x131a4ef9700>],
#  [<matplotlib.lines.Line2D at 0x131a4ef99a0>],
#  [<matplotlib.lines.Line2D at 0x131a4ef9c40>],
#  [<matplotlib.lines.Line2D at 0x131a4ef9ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f051c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f05460>],
#  [<matplotlib.lines.Line2D at 0x131a4f05700>],
#  [<matplotlib.lines.Line2D at 0x131a4f059a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f05c40>],
#  [<matplotlib.lines.Line2D at 0x131a4f05ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f131c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f13460>],
#  [<matplotlib.lines.Line2D at 0x131a4f13700>],
#  [<matplotlib.lines.Line2D at 0x131a4f139a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f13c40>],
#  [<matplotlib.lines.Line2D at 0x131a4f13ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f211c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f21460>],
#  [<matplotlib.lines.Line2D at 0x131a4f21700>],
#  [<matplotlib.lines.Line2D at 0x131a4f219a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f21c40>],
#  [<matplotlib.lines.Line2D at 0x131a4f21ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f321c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f32460>],
#  [<matplotlib.lines.Line2D at 0x131a4f32700>],
#  [<matplotlib.lines.Line2D at 0x131a4f329a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f32c40>],
#  [<matplotlib.lines.Line2D at 0x131a4f32ee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f3e1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f3e460>],
#  [<matplotlib.lines.Line2D at 0x131a4f3e700>],
#  [<matplotlib.lines.Line2D at 0x131a4f3e9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f3ec40>],
#  [<matplotlib.lines.Line2D at 0x131a4f3eee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f4e1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f4e460>],
#  [<matplotlib.lines.Line2D at 0x131a4f4e700>],
#  [<matplotlib.lines.Line2D at 0x131a4f4e9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f4ec40>],
#  [<matplotlib.lines.Line2D at 0x131a4f4eee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f5b1c0>],
#  [<matplotlib.lines.Line2D at 0x131a4f5b460>],
#  [<matplotlib.lines.Line2D at 0x131a4f5b700>],
#  [<matplotlib.lines.Line2D at 0x131a4f5b9a0>],
#  [<matplotlib.lines.Line2D at 0x131a4f5bc40>],
#  [<matplotlib.lines.Line2D at 0x131a4f5bee0>],
#  [<matplotlib.lines.Line2D at 0x131a4f691f0>],
#  [<matplotlib.lines.Line2D at 0x131a4f69490>],
#  [<matplotlib.lines.Line2D at 0x131a4f69730>],
#  [<matplotlib.lines.Line2D at 0x131a4f699d0>],
#  [<matplotlib.lines.Line2D at 0x131a4f69c70>],
#  [<matplotlib.lines.Line2D at 0x131a4f69f10>],
#  [<matplotlib.lines.Line2D at 0x131a4f771f0>],
#  [<matplotlib.lines.Line2D at 0x131a4f77490>],
#  [<matplotlib.lines.Line2D at 0x131a4f77730>],
#  [<matplotlib.lines.Line2D at 0x131a4f779d0>],
#  [<matplotlib.lines.Line2D at 0x131a4f77c70>],
#  [<matplotlib.lines.Line2D at 0x131a4f77f10>],
#  [<matplotlib.lines.Line2D at 0x131a4f861f0>],
#  [<matplotlib.lines.Line2D at 0x131a4f86490>],
#  [<matplotlib.lines.Line2D at 0x131a4f86730>],
#  [<matplotlib.lines.Line2D at 0x131a4f869d0>],
#  [<matplotlib.lines.Line2D at 0x131a4f86c70>],
#  [<matplotlib.lines.Line2D at 0x131a4f86f10>],
#  [<matplotlib.lines.Line2D at 0x131a4f941f0>],
#  [<matplotlib.lines.Line2D at 0x131a4f94490>],
#  [<matplotlib.lines.Line2D at 0x131a4f94730>],
#  [<matplotlib.lines.Line2D at 0x131a4f949d0>],
#  [<matplotlib.lines.Line2D at 0x131a4f94c70>],
#  [<matplotlib.lines.Line2D at 0x131a4f94f10>],
#  [<matplotlib.lines.Line2D at 0x131a4fa41f0>],
#  [<matplotlib.lines.Line2D at 0x131a4fa4490>],
#  [<matplotlib.lines.Line2D at 0x131a4fa4730>],
#  [<matplotlib.lines.Line2D at 0x131a4fa49d0>],
#  [<matplotlib.lines.Line2D at 0x131a4fa4c70>],
#  [<matplotlib.lines.Line2D at 0x131a4fa4f10>],
#  [<matplotlib.lines.Line2D at 0x131a4faf1f0>],
#  [<matplotlib.lines.Line2D at 0x131a4faf490>],
#  [<matplotlib.lines.Line2D at 0x131a4faf730>],
#  [<matplotlib.lines.Line2D at 0x131a4faf9d0>],
#  [<matplotlib.lines.Line2D at 0x131a4fafc70>],
#  [<matplotlib.lines.Line2D at 0x131a4faff10>],
#  [<matplotlib.lines.Line2D at 0x131a4fbe1f0>],
#  [<matplotlib.lines.Line2D at 0x131a4fbe490>],
#  [<matplotlib.lines.Line2D at 0x131a4fbe730>],
#  [<matplotlib.lines.Line2D at 0x131a4fbe9d0>],
#  [<matplotlib.lines.Line2D at 0x131a4fbec70>],
#  [<matplotlib.lines.Line2D at 0x131a4fbef10>],
#  [<matplotlib.lines.Line2D at 0x131a4fce1f0>],
#  [<matplotlib.lines.Line2D at 0x131a4fce490>],
#  [<matplotlib.lines.Line2D at 0x131a4fce730>],
#  [<matplotlib.lines.Line2D at 0x131a4fce9d0>],
#  [<matplotlib.lines.Line2D at 0x131a4fcec70>],
#  [<matplotlib.lines.Line2D at 0x131a4fcef10>],
#  [<matplotlib.lines.Line2D at 0x131a4fdb1f0>],
#  [<matplotlib.lines.Line2D at 0x131a4fdb490>],
#  [<matplotlib.lines.Line2D at 0x131a4fdb730>],
#  [<matplotlib.lines.Line2D at 0x131a4fdb9d0>],
#  [<matplotlib.lines.Line2D at 0x131a4fdbc70>],
#  [<matplotlib.lines.Line2D at 0x131a4fdbf10>],
#  [<matplotlib.lines.Line2D at 0x131a4fea1f0>],
#  [<matplotlib.lines.Line2D at 0x131a4fea490>],
#  [<matplotlib.lines.Line2D at 0x131a4fea730>],
#  [<matplotlib.lines.Line2D at 0x131a4fea9d0>],
#  [<matplotlib.lines.Line2D at 0x131a4feac70>],
#  [<matplotlib.lines.Line2D at 0x131a4feaf10>],
#  [<matplotlib.lines.Line2D at 0x131a4ff81f0>],
#  [<matplotlib.lines.Line2D at 0x131a4ff8490>],
#  [<matplotlib.lines.Line2D at 0x131a4ff8730>],
#  [<matplotlib.lines.Line2D at 0x131a4ff89d0>],
#  [<matplotlib.lines.Line2D at 0x131a4ff8c70>],
#  [<matplotlib.lines.Line2D at 0x131a4ff8f10>],
#  [<matplotlib.lines.Line2D at 0x131a50071f0>],
#  [<matplotlib.lines.Line2D at 0x131a5007490>],
#  [<matplotlib.lines.Line2D at 0x131a5007730>],
#  [<matplotlib.lines.Line2D at 0x131a50079d0>],
#  [<matplotlib.lines.Line2D at 0x131a5007c70>],
#  [<matplotlib.lines.Line2D at 0x131a5007f10>],
#  [<matplotlib.lines.Line2D at 0x131a50161f0>],
#  [<matplotlib.lines.Line2D at 0x131a5016490>],
#  [<matplotlib.lines.Line2D at 0x131a5016730>],
#  [<matplotlib.lines.Line2D at 0x131a50169d0>],
#  [<matplotlib.lines.Line2D at 0x131a5016c70>],
#  [<matplotlib.lines.Line2D at 0x131a5016f10>],
#  [<matplotlib.lines.Line2D at 0x131a50241f0>],
#  [<matplotlib.lines.Line2D at 0x131a5024490>],
#  [<matplotlib.lines.Line2D at 0x131a5024730>],
#  [<matplotlib.lines.Line2D at 0x131a50249d0>],
#  [<matplotlib.lines.Line2D at 0x131a5024c70>],
#  [<matplotlib.lines.Line2D at 0x131a5024f10>],
#  [<matplotlib.lines.Line2D at 0x131a50321f0>],
#  [<matplotlib.lines.Line2D at 0x131a5032490>],
#  [<matplotlib.lines.Line2D at 0x131a5032730>],
#  [<matplotlib.lines.Line2D at 0x131a50329d0>],
#  [<matplotlib.lines.Line2D at 0x131a5032c70>],
#  [<matplotlib.lines.Line2D at 0x131a5032f10>],
#  [<matplotlib.lines.Line2D at 0x131a50411f0>],
#  [<matplotlib.lines.Line2D at 0x131a5041490>],
#  [<matplotlib.lines.Line2D at 0x131a5041730>],
#  [<matplotlib.lines.Line2D at 0x131a50419d0>],
#  [<matplotlib.lines.Line2D at 0x131a5041c70>],
#  [<matplotlib.lines.Line2D at 0x131a5041f10>],
#  [<matplotlib.lines.Line2D at 0x131a504e1f0>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.945833 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 3.9690403 seconds ----------------
# iter 0: ||F|| = 0.000394167, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.7511369 seconds ----------------
# iter 1: ||F|| = 0.000392918, sigma = 314.966
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1081142 seconds ----------------
# iter 2: ||F|| = 5.51998e-05, sigma = 318.4
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4731252 seconds ----------------
# iter 3: ||F|| = 8.98181e-06, sigma = 329.434
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2508564 seconds ----------------
# iter 4: ||F|| = 2.32692e-06, sigma = 335.681
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1824083 seconds ----------------
# iter 5: ||F|| = 2.81331e-06, sigma = 267.418
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0979971 seconds ----------------
# iter 6: ||F|| = 1.73281e-06, sigma = 228.683
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1333357 seconds ----------------
# iter 7: ||F|| = 8.96817e-07, sigma = 164.043
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3014689 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$Xi$ / -')
ax4.set_xlabel('$z$ / µm')
ax4.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0]*1E6,meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0]*1E6,tolu, "o")
