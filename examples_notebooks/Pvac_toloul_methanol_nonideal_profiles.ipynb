# %% [markdown]
# # Co-drying of methanol and toluol from poly-(vinylacetate)

# %% [markdown]
# This jupyter notebook models the co-drying of two solvents,from a polymer and demonstrate the power of diffusionpy.
# First we import the diffusion model and the pc-saft implementation from diffusionpy

# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,dlnai_dlnxi,D_Matrix,Diffusion_MS_iter
import matplotlib.pyplot as plt

# %% [markdown]
# The experimental data for this example was taken from Schabel et al. 2006 (https://doi.org/10.1016/j.ces.2006.12.062)

# %%
texp=np.asarray([0,4.427792916,14.50035208,23.87257753,33.76909653,45.58674953,58.69408811,71.80142669,91.44521324,120.9089796,147.0930411,177.8656278,212.5493678,264.9136638,429.8518201])

wpvac=np.asarray([0.333333333,0.397028757,0.559683846,0.704648614,0.763915741,0.791401827,0.801167219,0.822653035,0.830878575,0.841458325,0.846286716,0.857199094,0.851138308,0.858388537,0.8723936549])

wtol=np.asarray([0.333333333,0.361083897,0.34858624,0.273123698,0.22781745,0.202716913,0.188759833,0.17692216,0.169121425,0.158541675,0.153713284,0.142800906,0.143816828,0.137082518,0.123003508])

wmet=np.asarray([0.333333333,0.241887346,0.091729914,0.022227687,0.008266808,0.00588126,0.010072947,0.000424805,0,0,0,0,0,0,0])



zexp1=np.asarray([1.9474,4.8216,4.9238,6.5452,11.1408,13.4856,13.5108,15.7391,20.0811,21.531,22.3125,24.4252,29.9245,30.8605,38.8925,47.3389,55.6328])/90.
meth=np.asarray([0.23319,0.7155,1.51472,0.19766,0.14607,1.48775,0.68454,0.11456,0.07899,1.42055,0.53311,0.05949,1.0763,0.39771,1.22609,1.29549,1.17211])/1.6*1

zexp2=np.asarray([0.8693,2.3874,2.8598,4.0545,4.6346,4.9451,6.6285,6.8366,9.8909,11.5564,12.0909,12.6496,13.2874,15.4473,15.6765,18.0826,20.7233,21.026,21.1068,21.9164,21.9851,24.6318,29.6695,30.2134,37.6273,45.746,53.6665])/90.
tolu=np.asarray([0.119214,0.224938,0.119364,0.581156,0.123559,0.336155,0.191408,0.122371,0.111769,0.18907,0.111935,0.508688,0.362508,0.109479,0.16636,0.098846,0.154557,0.092297,0.52828,0.337432,0.081538,0.133187,0.477474,0.25411,0.48078,0.516594,0.404811])/0.6*1

# %% [markdown]
# The drying starts from a mixture of methanol-toloul-PVAc in equal parts. We define the temperature, the presssure, the number of components, their molar mass and the starting and equilibrium weight fractions.

# %%
T=298.15
p=1E5
nc=3 # number of components
L=2.32E-5 # estimated thickness of the film
wi0=np.asarray([0.333333333,0.333333333,0.333333333]) # Weight fractions of the components methanol, toluol and PVAc at t=0
wi8=np.asarray([0.00001,0.127606346,0.872393654]) # Weight fractions of the components methanol, toluol and PVAc at t=8.T
Mi=np.asarray([32.04,92.14,90000.])

# %% [markdown]
# For describing the diffusion in the mixture, a matrix of diffusion coefficients needs to be defined. The matrix for a ternary system is displayed below:

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# Ð_{21} & 0 & Ð_{23} \\
# Ð_{31} & Ð_{32} & 0 \\
# \end{array}\right]$
#
# where $\hat{Ð}$ is the matrix of diffusion coefficients and $Ð_{ij}$ are the binary diffusion coefficients of component i moving in j. Friction between the same species is not required, thus $Ð_{ii}=0$
# Furthermore, the Stefan-Maxwell diffusion coefficients used in diffusionpy retain a convenient property where each pair of binary diffusion coefficients is symmetric i.e $Ð_{ij}=Ð_{ji}$
#
# Thus, for describing the diffusion in a ternary system, only three binary diffusion coefficients need to be defined:
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$
#
# which is stored as a vector of length $\frac{n_c(1-n_c)}{2}$ with $n_c$ being the number of components

# %%
Dvec=np.asarray([1E-5,6E-10,1E-9])
#Dvec=np.asarray([1E-5,2.3E-9,8E-9])

# %% [markdown]
# Diffusionpy internally caclulates the matrix $\hat{Ð}$ using the D_Matrix functionality

# %%
Dmat=D_Matrix(Dvec,nc)

# %% [markdown]
# Lastly, one needs to specify which components is considered mobile and which immobile. In our case, the solvents are obviously mobile while the polymer can be considered immobile due to its large molar mass which is conveniently defined as a boolean array.

# %%
mobile=np.asarray([True,True,False])

# %% [markdown]
# Finally, we can model solvent desorption and plot the results

# %%
nt=300
t=np.linspace(0,texp[-1],nt)
wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile)



font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)


ax.plot(t,wt[:,0], "--",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "--",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "--",color = color3 , 
        linewidth = 2.0, label = "wPVAc")

ax.plot(texp,wmet, "o",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(texp,wtol, "o",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(texp,wpvac, "o",color = color3 , 
        linewidth = 2.0, label = "wPVAc")


ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 1.])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0921834 seconds ----------------

# %% [markdown]
# diffusionpy neglects non-idealities for the default case. If the user wants to consider non-idealities a thermodynamic model is needed.
# diffusionpy comes prepackaged with an implementation of the pc-saft equation of state.
# PC-SAFT parameteters can be defined as follows:

# %%
kij=D_Matrix(np.asarray([0.029,-0.05855362,0.027776682]),nc)
par={"mi":np.asarray([1.5255, 2.8149, 2889.9]),
"si": np.asarray([3.2300, 3.7169, 3.3972]),
"ui" :np.asarray([188.9, 285.69, 204.65]),
"eAi" :np.asarray([2899.5, 0., 0.]),
"kAi":np.asarray([0.035176, 0., 0.]),
"NAi":np.asarray([1., 0., 1047.]),
"Mi": Mi,
"kij":kij}

# %% [markdown]
# However, any other implementatation of any thermodyamic model can be used in conjucntion with diffusionpy.
# This is because, diffusionpy relies soley on the numerical values of second derivative of activities $a_i$ or fugacities $f_i$ of component i.
#
# $\frac{Dlna_i}{Dlnx_i}$ = $\frac{Dlnf_i}{Dlnx_i}$ , where $D$ denotes that the differentiation was performed while neglecting the mass balance.
#
# The nonidealities employed in an iterative fashion and are supplied for each time point for the current weight fraction -time matrix. Here, the ideal solution from before gives the initial point for the iteration.

# %%
vpures=vpure(p,T,**par)
par["vpure"]=vpures
nonidealities=np.asarray([dlnai_dlnxi(T,wt[i,:],**par) for i in range(nt)]).T
dlnai_dlnwi_fun=lambda wi: dlnai_dlnxi(T,wi,**par)

# %% [markdown]
# In esssence, the iteration was performed by using a simple fixed point iteration.
# Alternatively, if one uses the built-in PC-SAFT implementation, diffusiopy offers a more sophisticated functioniality for this iteration based the df-sane algoirthm.
# Additionally, full output can specified in order to recieve e.g the spatial information of the concentrations

# %%
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1242241 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.189284 seconds ----------------
# iter 0: ||F|| = 0.000862385, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1855868 seconds ----------------
# iter 1: ||F|| = 0.000858951, sigma = 251.139
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1990661 seconds ----------------
# iter 2: ||F|| = 0.000181433, sigma = 262.119
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2029507 seconds ----------------
# iter 3: ||F|| = 4.8507e-05, sigma = 280.574
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2056192 seconds ----------------
# iter 4: ||F|| = 1.2795e-05, sigma = 370.41
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2042841 seconds ----------------
# iter 5: ||F|| = 1.70271e-06, sigma = 397.689
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2072689 seconds ----------------
# iter 6: ||F|| = 4.79351e-07, sigma = 342.715
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2106021 seconds ----------------

# %% [markdown]
# We plot the results

# %%
ax.plot(t,wt[:,0], "-",color = color1 , 
        linewidth = 2.0, label = "wMet")
ax.plot(t,wt[:,1], "-",color = color2 , 
        linewidth = 2.0, label = "wTol")
ax.plot(t,wt[:,2], "-",color = color3 , 
        linewidth = 2.0, label = "wPVAc")
fig

# %% [markdown]
# We can plot the time and spatial profiles of methanol and toluene

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
# ax2.plot(zexp2*Lt[0],tolu, "o")
# Out:
# [[<matplotlib.lines.Line2D at 0x289b4a3a730>],
#  [<matplotlib.lines.Line2D at 0x289b4a3a3a0>],
#  [<matplotlib.lines.Line2D at 0x289b4a3af70>],
#  [<matplotlib.lines.Line2D at 0x289b50f6250>],
#  [<matplotlib.lines.Line2D at 0x289b293fca0>],
#  [<matplotlib.lines.Line2D at 0x289b4dc1c40>],
#  [<matplotlib.lines.Line2D at 0x289b53e1910>],
#  [<matplotlib.lines.Line2D at 0x289b4dc3af0>],
#  [<matplotlib.lines.Line2D at 0x289b2957760>],
#  [<matplotlib.lines.Line2D at 0x289b2951250>],
#  [<matplotlib.lines.Line2D at 0x289b2951160>],
#  [<matplotlib.lines.Line2D at 0x289b2951f10>],
#  [<matplotlib.lines.Line2D at 0x289b4a35eb0>],
#  [<matplotlib.lines.Line2D at 0x289b4e1e460>],
#  [<matplotlib.lines.Line2D at 0x289b50dd070>],
#  [<matplotlib.lines.Line2D at 0x289b50dd310>],
#  [<matplotlib.lines.Line2D at 0x289b50dd5b0>],
#  [<matplotlib.lines.Line2D at 0x289b50dd850>],
#  [<matplotlib.lines.Line2D at 0x289b50ddaf0>],
#  [<matplotlib.lines.Line2D at 0x289b50ddd90>],
#  [<matplotlib.lines.Line2D at 0x289b5127070>],
#  [<matplotlib.lines.Line2D at 0x289b5127310>],
#  [<matplotlib.lines.Line2D at 0x289b51275b0>],
#  [<matplotlib.lines.Line2D at 0x289b5127850>],
#  [<matplotlib.lines.Line2D at 0x289b5127af0>],
#  [<matplotlib.lines.Line2D at 0x289b5127d90>],
#  [<matplotlib.lines.Line2D at 0x289b5136070>],
#  [<matplotlib.lines.Line2D at 0x289b5136310>],
#  [<matplotlib.lines.Line2D at 0x289b51365b0>],
#  [<matplotlib.lines.Line2D at 0x289b5136850>],
#  [<matplotlib.lines.Line2D at 0x289b5136af0>],
#  [<matplotlib.lines.Line2D at 0x289b5136d90>],
#  [<matplotlib.lines.Line2D at 0x289b5146070>],
#  [<matplotlib.lines.Line2D at 0x289b5146310>],
#  [<matplotlib.lines.Line2D at 0x289b51465b0>],
#  [<matplotlib.lines.Line2D at 0x289b5146850>],
#  [<matplotlib.lines.Line2D at 0x289b5146af0>],
#  [<matplotlib.lines.Line2D at 0x289b5146d90>],
#  [<matplotlib.lines.Line2D at 0x289b5152070>],
#  [<matplotlib.lines.Line2D at 0x289b5152310>],
#  [<matplotlib.lines.Line2D at 0x289b51525e0>],
#  [<matplotlib.lines.Line2D at 0x289b5152880>],
#  [<matplotlib.lines.Line2D at 0x289b5152b20>],
#  [<matplotlib.lines.Line2D at 0x289b5152dc0>],
#  [<matplotlib.lines.Line2D at 0x289b51610a0>],
#  [<matplotlib.lines.Line2D at 0x289b5161340>],
#  [<matplotlib.lines.Line2D at 0x289b51615e0>],
#  [<matplotlib.lines.Line2D at 0x289b5161880>],
#  [<matplotlib.lines.Line2D at 0x289b5161b20>],
#  [<matplotlib.lines.Line2D at 0x289b5161dc0>],
#  [<matplotlib.lines.Line2D at 0x289b516f0a0>],
#  [<matplotlib.lines.Line2D at 0x289b516f340>],
#  [<matplotlib.lines.Line2D at 0x289b516f5e0>],
#  [<matplotlib.lines.Line2D at 0x289b516f880>],
#  [<matplotlib.lines.Line2D at 0x289b516fb20>],
#  [<matplotlib.lines.Line2D at 0x289b516fdc0>],
#  [<matplotlib.lines.Line2D at 0x289b517d0a0>],
#  [<matplotlib.lines.Line2D at 0x289b517d340>],
#  [<matplotlib.lines.Line2D at 0x289b517d5e0>],
#  [<matplotlib.lines.Line2D at 0x289b517d880>],
#  [<matplotlib.lines.Line2D at 0x289b517db20>],
#  [<matplotlib.lines.Line2D at 0x289b517ddc0>],
#  [<matplotlib.lines.Line2D at 0x289b518c0a0>],
#  [<matplotlib.lines.Line2D at 0x289b518c340>],
#  [<matplotlib.lines.Line2D at 0x289b518c5e0>],
#  [<matplotlib.lines.Line2D at 0x289b518c8b0>],
#  [<matplotlib.lines.Line2D at 0x289b518cb50>],
#  [<matplotlib.lines.Line2D at 0x289b518cdf0>],
#  [<matplotlib.lines.Line2D at 0x289b519a0d0>],
#  [<matplotlib.lines.Line2D at 0x289b519a370>],
#  [<matplotlib.lines.Line2D at 0x289b519a610>],
#  [<matplotlib.lines.Line2D at 0x289b519a8b0>],
#  [<matplotlib.lines.Line2D at 0x289b519ab50>],
#  [<matplotlib.lines.Line2D at 0x289b519adf0>],
#  [<matplotlib.lines.Line2D at 0x289b51a80d0>],
#  [<matplotlib.lines.Line2D at 0x289b51a8370>],
#  [<matplotlib.lines.Line2D at 0x289b51a8610>],
#  [<matplotlib.lines.Line2D at 0x289b51a88b0>],
#  [<matplotlib.lines.Line2D at 0x289b51a8b50>],
#  [<matplotlib.lines.Line2D at 0x289b51a8df0>],
#  [<matplotlib.lines.Line2D at 0x289b51b80d0>],
#  [<matplotlib.lines.Line2D at 0x289b51b8370>],
#  [<matplotlib.lines.Line2D at 0x289b51b8610>],
#  [<matplotlib.lines.Line2D at 0x289b51b88b0>],
#  [<matplotlib.lines.Line2D at 0x289b51b8b50>],
#  [<matplotlib.lines.Line2D at 0x289b51b8df0>],
#  [<matplotlib.lines.Line2D at 0x289b51c40d0>],
#  [<matplotlib.lines.Line2D at 0x289b51c4370>],
#  [<matplotlib.lines.Line2D at 0x289b51c4610>],
#  [<matplotlib.lines.Line2D at 0x289b51c48b0>],
#  [<matplotlib.lines.Line2D at 0x289b51c4b50>],
#  [<matplotlib.lines.Line2D at 0x289b51c4df0>],
#  [<matplotlib.lines.Line2D at 0x289b51d40d0>],
#  [<matplotlib.lines.Line2D at 0x289b51d4370>],
#  [<matplotlib.lines.Line2D at 0x289b51d4610>],
#  [<matplotlib.lines.Line2D at 0x289b51d48b0>],
#  [<matplotlib.lines.Line2D at 0x289b51d4b50>],
#  [<matplotlib.lines.Line2D at 0x289b51d4df0>],
#  [<matplotlib.lines.Line2D at 0x289b51e10d0>],
#  [<matplotlib.lines.Line2D at 0x289b51e1370>],
#  [<matplotlib.lines.Line2D at 0x289b51e1610>],
#  [<matplotlib.lines.Line2D at 0x289b51e18b0>],
#  [<matplotlib.lines.Line2D at 0x289b51e1b50>],
#  [<matplotlib.lines.Line2D at 0x289b51e1df0>],
#  [<matplotlib.lines.Line2D at 0x289b51ef0d0>],
#  [<matplotlib.lines.Line2D at 0x289b51ef370>],
#  [<matplotlib.lines.Line2D at 0x289b51ef610>],
#  [<matplotlib.lines.Line2D at 0x289b51ef8b0>],
#  [<matplotlib.lines.Line2D at 0x289b51efb50>],
#  [<matplotlib.lines.Line2D at 0x289b51efdf0>],
#  [<matplotlib.lines.Line2D at 0x289b51ff0d0>],
#  [<matplotlib.lines.Line2D at 0x289b51ff370>],
#  [<matplotlib.lines.Line2D at 0x289b51ff610>],
#  [<matplotlib.lines.Line2D at 0x289b51ff8b0>],
#  [<matplotlib.lines.Line2D at 0x289b51ffb50>],
#  [<matplotlib.lines.Line2D at 0x289b51ffdf0>],
#  [<matplotlib.lines.Line2D at 0x289b520d0d0>],
#  [<matplotlib.lines.Line2D at 0x289b520d370>],
#  [<matplotlib.lines.Line2D at 0x289b520d610>],
#  [<matplotlib.lines.Line2D at 0x289b520d8b0>],
#  [<matplotlib.lines.Line2D at 0x289b520db50>],
#  [<matplotlib.lines.Line2D at 0x289b520ddf0>],
#  [<matplotlib.lines.Line2D at 0x289b521a0d0>],
#  [<matplotlib.lines.Line2D at 0x289b521a370>],
#  [<matplotlib.lines.Line2D at 0x289b521a610>],
#  [<matplotlib.lines.Line2D at 0x289b521a8b0>],
#  [<matplotlib.lines.Line2D at 0x289b521ab80>],
#  [<matplotlib.lines.Line2D at 0x289b521ae20>],
#  [<matplotlib.lines.Line2D at 0x289b522a100>],
#  [<matplotlib.lines.Line2D at 0x289b522a3a0>],
#  [<matplotlib.lines.Line2D at 0x289b522a640>],
#  [<matplotlib.lines.Line2D at 0x289b522a8e0>],
#  [<matplotlib.lines.Line2D at 0x289b522ab80>],
#  [<matplotlib.lines.Line2D at 0x289b522ae20>],
#  [<matplotlib.lines.Line2D at 0x289b5239100>],
#  [<matplotlib.lines.Line2D at 0x289b52393a0>],
#  [<matplotlib.lines.Line2D at 0x289b5239640>],
#  [<matplotlib.lines.Line2D at 0x289b52398e0>],
#  [<matplotlib.lines.Line2D at 0x289b5239b80>],
#  [<matplotlib.lines.Line2D at 0x289b5239e20>],
#  [<matplotlib.lines.Line2D at 0x289b5247100>],
#  [<matplotlib.lines.Line2D at 0x289b52473a0>],
#  [<matplotlib.lines.Line2D at 0x289b5247640>],
#  [<matplotlib.lines.Line2D at 0x289b52478e0>],
#  [<matplotlib.lines.Line2D at 0x289b5247b80>],
#  [<matplotlib.lines.Line2D at 0x289b5247e20>],
#  [<matplotlib.lines.Line2D at 0x289b5255100>],
#  [<matplotlib.lines.Line2D at 0x289b52553a0>],
#  [<matplotlib.lines.Line2D at 0x289b5255640>],
#  [<matplotlib.lines.Line2D at 0x289b52558e0>],
#  [<matplotlib.lines.Line2D at 0x289b5255b80>],
#  [<matplotlib.lines.Line2D at 0x289b5255e20>],
#  [<matplotlib.lines.Line2D at 0x289b5263100>],
#  [<matplotlib.lines.Line2D at 0x289b52633a0>],
#  [<matplotlib.lines.Line2D at 0x289b5263640>],
#  [<matplotlib.lines.Line2D at 0x289b52638e0>],
#  [<matplotlib.lines.Line2D at 0x289b5263b80>],
#  [<matplotlib.lines.Line2D at 0x289b5263e20>],
#  [<matplotlib.lines.Line2D at 0x289b5272100>],
#  [<matplotlib.lines.Line2D at 0x289b52723a0>],
#  [<matplotlib.lines.Line2D at 0x289b5272640>],
#  [<matplotlib.lines.Line2D at 0x289b52728e0>],
#  [<matplotlib.lines.Line2D at 0x289b5272b80>],
#  [<matplotlib.lines.Line2D at 0x289b5272e20>],
#  [<matplotlib.lines.Line2D at 0x289b5280100>],
#  [<matplotlib.lines.Line2D at 0x289b52803a0>],
#  [<matplotlib.lines.Line2D at 0x289b5280640>],
#  [<matplotlib.lines.Line2D at 0x289b52808e0>],
#  [<matplotlib.lines.Line2D at 0x289b5280b80>],
#  [<matplotlib.lines.Line2D at 0x289b5280e20>],
#  [<matplotlib.lines.Line2D at 0x289b528e100>],
#  [<matplotlib.lines.Line2D at 0x289b528e3a0>],
#  [<matplotlib.lines.Line2D at 0x289b528e640>],
#  [<matplotlib.lines.Line2D at 0x289b528e8e0>],
#  [<matplotlib.lines.Line2D at 0x289b528eb80>],
#  [<matplotlib.lines.Line2D at 0x289b528ee20>],
#  [<matplotlib.lines.Line2D at 0x289b529d100>],
#  [<matplotlib.lines.Line2D at 0x289b529d3a0>],
#  [<matplotlib.lines.Line2D at 0x289b529d640>],
#  [<matplotlib.lines.Line2D at 0x289b529d8e0>],
#  [<matplotlib.lines.Line2D at 0x289b529db80>],
#  [<matplotlib.lines.Line2D at 0x289b529de20>],
#  [<matplotlib.lines.Line2D at 0x289b52a9100>],
#  [<matplotlib.lines.Line2D at 0x289b52a93a0>],
#  [<matplotlib.lines.Line2D at 0x289b52a9640>],
#  [<matplotlib.lines.Line2D at 0x289b52a98e0>],
#  [<matplotlib.lines.Line2D at 0x289b52a9b80>],
#  [<matplotlib.lines.Line2D at 0x289b52a9e20>],
#  [<matplotlib.lines.Line2D at 0x289b52ba100>],
#  [<matplotlib.lines.Line2D at 0x289b52ba3a0>],
#  [<matplotlib.lines.Line2D at 0x289b52ba640>],
#  [<matplotlib.lines.Line2D at 0x289b52ba8e0>],
#  [<matplotlib.lines.Line2D at 0x289b52bab80>],
#  [<matplotlib.lines.Line2D at 0x289b52bae20>],
#  [<matplotlib.lines.Line2D at 0x289b52c7100>],
#  [<matplotlib.lines.Line2D at 0x289b52c73a0>],
#  [<matplotlib.lines.Line2D at 0x289b52c7640>],
#  [<matplotlib.lines.Line2D at 0x289b52c78e0>],
#  [<matplotlib.lines.Line2D at 0x289b52c7b80>],
#  [<matplotlib.lines.Line2D at 0x289b52c7e20>],
#  [<matplotlib.lines.Line2D at 0x289b52d6100>],
#  [<matplotlib.lines.Line2D at 0x289b52d63a0>],
#  [<matplotlib.lines.Line2D at 0x289b52d6640>],
#  [<matplotlib.lines.Line2D at 0x289b52d6910>],
#  [<matplotlib.lines.Line2D at 0x289b52d6bb0>],
#  [<matplotlib.lines.Line2D at 0x289b52d6e50>],
#  [<matplotlib.lines.Line2D at 0x289b52e4130>],
#  [<matplotlib.lines.Line2D at 0x289b52e43d0>],
#  [<matplotlib.lines.Line2D at 0x289b52e4670>],
#  [<matplotlib.lines.Line2D at 0x289b52e4910>],
#  [<matplotlib.lines.Line2D at 0x289b52e4bb0>],
#  [<matplotlib.lines.Line2D at 0x289b52e4e50>],
#  [<matplotlib.lines.Line2D at 0x289b52f3130>],
#  [<matplotlib.lines.Line2D at 0x289b52f33d0>],
#  [<matplotlib.lines.Line2D at 0x289b52f3670>],
#  [<matplotlib.lines.Line2D at 0x289b52f3910>],
#  [<matplotlib.lines.Line2D at 0x289b52f3bb0>],
#  [<matplotlib.lines.Line2D at 0x289b52f3e50>],
#  [<matplotlib.lines.Line2D at 0x289b5300130>],
#  [<matplotlib.lines.Line2D at 0x289b53003d0>],
#  [<matplotlib.lines.Line2D at 0x289b5300670>],
#  [<matplotlib.lines.Line2D at 0x289b5300910>],
#  [<matplotlib.lines.Line2D at 0x289b5300bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5300e50>],
#  [<matplotlib.lines.Line2D at 0x289b530e130>],
#  [<matplotlib.lines.Line2D at 0x289b530e3d0>],
#  [<matplotlib.lines.Line2D at 0x289b530e670>],
#  [<matplotlib.lines.Line2D at 0x289b530e910>],
#  [<matplotlib.lines.Line2D at 0x289b530ebb0>],
#  [<matplotlib.lines.Line2D at 0x289b530ee50>],
#  [<matplotlib.lines.Line2D at 0x289b531d130>],
#  [<matplotlib.lines.Line2D at 0x289b531d3d0>],
#  [<matplotlib.lines.Line2D at 0x289b531d670>],
#  [<matplotlib.lines.Line2D at 0x289b531d910>],
#  [<matplotlib.lines.Line2D at 0x289b531dbb0>],
#  [<matplotlib.lines.Line2D at 0x289b531de50>],
#  [<matplotlib.lines.Line2D at 0x289b532c130>],
#  [<matplotlib.lines.Line2D at 0x289b532c3d0>],
#  [<matplotlib.lines.Line2D at 0x289b532c670>],
#  [<matplotlib.lines.Line2D at 0x289b532c910>],
#  [<matplotlib.lines.Line2D at 0x289b532cbb0>],
#  [<matplotlib.lines.Line2D at 0x289b532ce50>],
#  [<matplotlib.lines.Line2D at 0x289b533a130>],
#  [<matplotlib.lines.Line2D at 0x289b533a3d0>],
#  [<matplotlib.lines.Line2D at 0x289b533a670>],
#  [<matplotlib.lines.Line2D at 0x289b533a910>],
#  [<matplotlib.lines.Line2D at 0x289b533abb0>],
#  [<matplotlib.lines.Line2D at 0x289b533ae50>],
#  [<matplotlib.lines.Line2D at 0x289b5349130>],
#  [<matplotlib.lines.Line2D at 0x289b53493d0>],
#  [<matplotlib.lines.Line2D at 0x289b5349670>],
#  [<matplotlib.lines.Line2D at 0x289b5349910>],
#  [<matplotlib.lines.Line2D at 0x289b5349bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5349e50>],
#  [<matplotlib.lines.Line2D at 0x289b5355130>],
#  [<matplotlib.lines.Line2D at 0x289b53553d0>],
#  [<matplotlib.lines.Line2D at 0x289b5355670>],
#  [<matplotlib.lines.Line2D at 0x289b5355910>],
#  [<matplotlib.lines.Line2D at 0x289b5355bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5355e50>],
#  [<matplotlib.lines.Line2D at 0x289b5364130>],
#  [<matplotlib.lines.Line2D at 0x289b53643d0>],
#  [<matplotlib.lines.Line2D at 0x289b5364670>],
#  [<matplotlib.lines.Line2D at 0x289b5364910>],
#  [<matplotlib.lines.Line2D at 0x289b5364bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5364e50>],
#  [<matplotlib.lines.Line2D at 0x289b5373130>],
#  [<matplotlib.lines.Line2D at 0x289b53733d0>],
#  [<matplotlib.lines.Line2D at 0x289b5373670>],
#  [<matplotlib.lines.Line2D at 0x289b5373910>],
#  [<matplotlib.lines.Line2D at 0x289b5373bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5373e50>],
#  [<matplotlib.lines.Line2D at 0x289b5381130>],
#  [<matplotlib.lines.Line2D at 0x289b53813d0>],
#  [<matplotlib.lines.Line2D at 0x289b5381670>],
#  [<matplotlib.lines.Line2D at 0x289b5381910>],
#  [<matplotlib.lines.Line2D at 0x289b5381bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5381e50>],
#  [<matplotlib.lines.Line2D at 0x289b5390130>],
#  [<matplotlib.lines.Line2D at 0x289b53903d0>],
#  [<matplotlib.lines.Line2D at 0x289b5390670>],
#  [<matplotlib.lines.Line2D at 0x289b5390910>],
#  [<matplotlib.lines.Line2D at 0x289b5390bb0>],
#  [<matplotlib.lines.Line2D at 0x289b5390e50>],
#  [<matplotlib.lines.Line2D at 0x289b539f130>],
#  [<matplotlib.lines.Line2D at 0x289b539f3d0>],
#  [<matplotlib.lines.Line2D at 0x289b539f670>],
#  [<matplotlib.lines.Line2D at 0x289b539f910>],
#  [<matplotlib.lines.Line2D at 0x289b539fbb0>],
#  [<matplotlib.lines.Line2D at 0x289b539fe50>],
#  [<matplotlib.lines.Line2D at 0x289b53fb130>],
#  [<matplotlib.lines.Line2D at 0x289b53fb3d0>],
#  [<matplotlib.lines.Line2D at 0x289b53fb670>],
#  [<matplotlib.lines.Line2D at 0x289b53fb910>],
#  [<matplotlib.lines.Line2D at 0x289b53fbbb0>],
#  [<matplotlib.lines.Line2D at 0x289b53fbe50>],
#  [<matplotlib.lines.Line2D at 0x289b540b130>],
#  [<matplotlib.lines.Line2D at 0x289b540b3d0>],
#  [<matplotlib.lines.Line2D at 0x289b540b670>],
#  [<matplotlib.lines.Line2D at 0x289b540b910>]]

# %% [markdown]
# Finally, diffusionpy provides an interface to change the boundary conditions. For example here, we provide a time-deopendnat surface cocnentartion to consider that the surface concentration needs time to establish

# %%
taui=np.asarray([5,55])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,mobile,taui,lngi_fun=None)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2419493 seconds ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4976073 seconds ----------------
# iter 0: ||F|| = 0.000394432, sigma = 1
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3760582 seconds ----------------
# iter 1: ||F|| = 0.000393203, sigma = 319.171
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4917944 seconds ----------------
# iter 2: ||F|| = 5.57489e-05, sigma = 318.32
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4441409 seconds ----------------
# iter 3: ||F|| = 8.85367e-06, sigma = 324.724
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3956863 seconds ----------------
# iter 4: ||F|| = 2.29924e-06, sigma = 329.68
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4252821 seconds ----------------
# iter 5: ||F|| = 1.29444e-06, sigma = 357.696
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4140009 seconds ----------------
# iter 6: ||F|| = 2.00675e-06, sigma = 160.321
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4448878 seconds ----------------
# iter 7: ||F|| = 1.27363e-06, sigma = 249.102
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3847251 seconds ----------------
# iter 8: ||F|| = 1.06844e-06, sigma = 173.572
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4032243 seconds ----------------
# iter 9: ||F|| = 1.88552e-06, sigma = 110.202
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3822118 seconds ----------------
# iter 10: ||F|| = 1.03188e-06, sigma = 81.4085
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.5116199 seconds ----------------
# iter 11: ||F|| = 1.42313e-06, sigma = 66.8644
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4797772 seconds ----------------
# iter 12: ||F|| = 1.94902e-06, sigma = 70.221
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4141162 seconds ----------------
# iter 13: ||F|| = 1.36798e-06, sigma = 58.8089
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.3882121 seconds ----------------
# iter 14: ||F|| = 1.77729e-06, sigma = 33.957
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4082737 seconds ----------------
# iter 15: ||F|| = 7.79646e-07, sigma = 27.7775
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4631412 seconds ----------------

# %%
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig4, ax4 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
fig4.subplots_adjust(hspace=0.5, wspace=0.3)
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$Xi$ / -')
ax4.set_xlabel('$z$ / µm')
ax4.set_ylabel('$Xi$ / -')
[ax3.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,0,:]/wtz[i,2,:], "-",color = color1 , linewidth = 2.0, label = "wMet") for i,val in enumerate(wtz[:,0,0])]
ax3.plot(zexp1*Lt[0]*1E6,meth, "o")

[ax4.plot(Lt[i]/Lt[0]*zvec*1E6,wtz[i,1,:]/wtz[i,2,:], "-",color = color2 , linewidth = 2.0, label = "wTol") for i,val in enumerate(wtz[:,0,0])]
ax4.plot(zexp2*Lt[0]*1E6,tolu, "o")
