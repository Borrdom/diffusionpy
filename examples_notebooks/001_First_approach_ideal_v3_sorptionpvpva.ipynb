# %% [markdown]
# # First approach on ideal modelling

# %% [markdown]
# 1. Implementing all necessary packages

# %%
import numpy as np
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()

# %% [markdown]
# import the input data for diffusionpy from master thesis

# %%
from numpy import array
mH2O0= 0,5
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wPolL1D03= array([5.1687E-06,8.11419000e-06,1.16988000e-05,1.82872000e-05,2.43481000e-05,2.97692000e-05,3.50846000e-05,3.91787000e-05,4.30863000e-05,4.68326000e-05,4.92799000e-05,5.08487000e-05])
wH2OL1D03= array([9.99994489e-01,9.99991222e-01,9.99986998e-01,9.99979094e-01,9.99971590e-01,9.99964725e-01,9.99957805e-01,9.99951993e-01,9.99946538e-01,9.99940884e-01,9.99937297e-01,9.99934266e-01])
wINDL1D05= array([5.95664000e-07,1.11906000e-06,1.85585000e-06,3.47314000e-06,4.42371000e-06,6.09469000e-06,7.07050000e-06,8.10867000e-06,9.81494000e-06,1.09211000e-05,1.22759000e-05,1.35512000e-05])
wPolL1D05=array([7.34838000e-07,1.07111000e-06,1.42408000e-06,1.86380000e-06,1.99883000e-06,2.04584000e-06,2.04858000e-06,1.96896000e-06,2.13912000e-06,2.19015000e-06,2.16470000e-06,2.24988000e-06])
wH2OL1D05=array([9.99998669e-01,9.99997810e-01,9.99996720e-01,9.99994663e-01,9.99993577e-01,9.99991859e-01,9.99990881e-01,9.99989922e-01, 9.99988046e-01,9.99986889e-01,9.99985559e-01,9.99984199e-01])
wINDL1D07= array([6.52542000e-07,1.19485000e-06,2.98026000e-06,3.78514000e-06,5.18938000e-06,6.62873000e-06,8.19091000e-06,9.45838000e-06,1.10233000e-05,1.23274000e-05,1.34266000e-05,1.46734000e-05])
wPolL1D07=array([5.43067000e-07,2.32437000e-07,-1.31550000e-07,2.39324000e-07,3.19550000e-07,3.11173000e-07,3.24043000e-07,2.83174000e-07,1.86216000e-07,3.26324000e-07,7.64666000e-07,2.35801000e-07])
wH2OL1D07=array([9.99998804e-01,9.99998573e-01,9.99997151e-01,9.99995976e-01,9.99994491e-01,9.99993060e-01,9.99991485e-01,9.99990258e-01,9.99988790e-01,9.99987346e-01,9.99985809e-01,9.99985091e-01])
wINDL25D03=array([3.38334000e-07,7.27514000e-07,1.13529000e-06,2.29403000e-06,3.20807000e-06,4.11030000e-06,4.97144000e-06,5.76267000e-06,6.66612000e-06,7.58597000e-06,8.33222000e-06,9.19885000e-06])
wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])

# %% [markdown]
# Set the Information of the Process (temperature, pressure, wi0, wi8, L, D)

# %%
T=298.15
p=1E5
nc=3 # number of components
L=1E-4 # estimated thickness of the ASD
wi0=np.asarray([0.49999,0.49999,0.00002]) # Weight fractions of the components API, polymer, water at t=0
wi8=np.asarray([0.00001,0.00001,0.99998]) # Weight fractions of the components API, polymer, water at t=8.T
Mi= np.asarray([357.79,65000,16.02])

# %% [markdown]
# Creating a vector which holds the MS diffusion coefficients

# %%
Dvec =np.asarray([1E-5,2E-12,8E-12])

# %% [markdown]
# Calculate the values for the concentrations inside the ASD

# %%
import numpy as np
from numpy import array
import scipy as sp
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()
from scipy.optimize import curve_fit
import xlwings as xw
import pandas as pd

texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wPolL1D03= array([5.1687E-06,8.11419000e-06,1.16988000e-05,1.82872000e-05,2.43481000e-05,2.97692000e-05,3.50846000e-05,3.91787000e-05,4.30863000e-05,4.68326000e-05,4.92799000e-05,5.08487000e-05])
wH2OL1D03= array([9.99994489e-01,9.99991222e-01,9.99986998e-01,9.99979094e-01,9.99971590e-01,9.99964725e-01,9.99957805e-01,9.99951993e-01,9.99946538e-01,9.99940884e-01,9.99937297e-01,9.99934266e-01])
wINDL1D05= array([5.95664000e-07,1.11906000e-06,1.85585000e-06,3.47314000e-06,4.42371000e-06,6.09469000e-06,7.07050000e-06,8.10867000e-06,9.81494000e-06,1.09211000e-05,1.22759000e-05,1.35512000e-05])
wPolL1D05=array([7.34838000e-07,1.07111000e-06,1.42408000e-06,1.86380000e-06,1.99883000e-06,2.04584000e-06,2.04858000e-06,1.96896000e-06,2.13912000e-06,2.19015000e-06,2.16470000e-06,2.24988000e-06])
wH2OL1D05=array([9.99998669e-01,9.99997810e-01,9.99996720e-01,9.99994663e-01,9.99993577e-01,9.99991859e-01,9.99990881e-01,9.99989922e-01, 9.99988046e-01,9.99986889e-01,9.99985559e-01,9.99984199e-01])
wINDL1D07= array([6.52542000e-07,1.19485000e-06,2.98026000e-06,3.78514000e-06,5.18938000e-06,6.62873000e-06,8.19091000e-06,9.45838000e-06,1.10233000e-05,1.23274000e-05,1.34266000e-05,1.46734000e-05])
wPolL1D07=array([5.43067000e-07,2.32437000e-07,-1.31550000e-07,2.39324000e-07,3.19550000e-07,3.11173000e-07,3.24043000e-07,2.83174000e-07,1.86216000e-07,3.26324000e-07,7.64666000e-07,2.35801000e-07])
wH2OL1D07=array([9.99998804e-01,9.99998573e-01,9.99997151e-01,9.99995976e-01,9.99994491e-01,9.99993060e-01,9.99991485e-01,9.99990258e-01,9.99988790e-01,9.99987346e-01,9.99985809e-01,9.99985091e-01])
wINDL25D03=array([3.38334000e-07,7.27514000e-07,1.13529000e-06,2.29403000e-06,3.20807000e-06,4.11030000e-06,4.97144000e-06,5.76267000e-06,6.66612000e-06,7.58597000e-06,8.33222000e-06,9.19885000e-06])
wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
Mi= np.asarray([357.79,65000,16.02])
mobile= np.asarray([True,True,True])
wi_8 =np.asarray([0.0001,0.0001,0.9998])
Dvec =np.asarray([1E-1,2E-12,8E-1])
Dvec=np.asarray([327081.87865031627,386294.20602000307,644379.7545334897])/1E14

Dvec=np.asarray([244258.29860143378,
632465.849552949,
762682.380133524])/1E14
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2

def Conc_ASD(wAPI_B,w0API_B,w0API_ASD,wPol_B,w0Pol_B,w0Pol_ASD,wH2O_B,w0H2O_B,w0H2O_ASD,m_B,m_ASD):
   
    wAPI_ASD= (w0API_B-wAPI_B)*(m_B/m_ASD)+w0API_ASD
    wPol_ASD=(w0Pol_B-wPol_B)*(m_B/m_ASD)+w0Pol_ASD
    wH2O_ASD= (w0H2O_B-wH2O_B)*(m_B/m_ASD)+w0H2O_ASD
    wges_ASD= wAPI_ASD + wPol_ASD + wH2O_ASD
    return wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD


def plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    wAPI_ASD=1-wAPI_ASD/wAPI_ASD[0]
    wPol_ASD=1-wPol_ASD/wPol_ASD[0]
    # wH2O_ASD=1-wH2O_ASD/wH2O_ASD[0]
    plt.plot(texp, wAPI_ASD,'ro')
    plt.plot(texp,wPol_ASD,'go')
    # plt.plot(texp,wH2O_ASD,'bo')
    # plt.plot(texp,wges_ASD,'yo')
    plt.xlabel("t [s]")
    plt.ylabel("wi [-]")

def fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    def funcline(x,a,b):
        return a*x+b
    def funcquad(x,a,b,c):
        return a*x**2+b*x+c
    # popt_API, pcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*popt_API),'r-')
    # qopt_API, qcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*qopt_API),'r--')
    # popt_Pol, pcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*popt_Pol),'g-')
    # qopt_Pol, qcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*qopt_Pol),'g--')
    # popt_H2O, pcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*popt_H2O),'b-')
    # qopt_H2O, qcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*qopt_H2O),'b--')
  #  MSopt, MScov = curve_fit(Diffusion_MS,texp,wAPI_ASD)
  #  plt.plot(texp,Diffusion_MS(texp,*MSopt),'r*')
    
def Choose_ASD(ASD_L,ASD_DL):
    if ASD_L == 1 and ASD_DL == 0.3:
        wIND = wINDL1D03
        w0IND = 0.3
        wPol = wPolL1D03
        wH2O = wH2OL1D03
        mASD = mASDL1D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L ==1 and ASD_DL ==0.5:
        wIND = wINDL1D05
        w0IND = 0.5
        wPol = wPolL1D05
        wH2O = wH2OL1D05
        mASD = mASDL1D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L ==1 and ASD_DL == 0.7:
        wIND = wINDL1D07
        w0IND = 0.7
        wPol = wPolL1D07
        wH2O = wH2OL1D07
        mASD = mASDL1D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    elif ASD_L == 0.25 and ASD_DL== 0.3:
        wIND = wINDL25D03
        w0IND = 0.3
        wPol = wPolL25D03
        wH2O = wH2OL25D03
        mASD = mASDL25D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L == 0.25 and ASD_DL ==0.5:
        wIND = wINDL25D05
        w0IND = 0.5
        wPol = wPolL25D05
        wH2O = wH2OL25D05
        mASD = mASDL25D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L == 0.25 and ASD_DL == 0.7:
        wIND = wINDL25D07
        w0IND = 0.7
        wPol = wPolL25D07
        wH2O = wH2OL25D07
        mASD = mASDL25D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    else: print("Bitte gültige Werte für Länge und Drugload eingeben")
    w0Pol = 1 - w0IND  
    L = ASD_L * 10E-4 
    

    wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD=Conc_ASD(wIND,0,w0IND,wPol,0,w0Pol,wH2O,1,0,mB_0,mASD)

    
    #fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    # wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    # wt= Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    def fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
        def Diffforfit(t,D1,D2,D3):
            Dscale=1E13 #Hilfsvariable
            D1=10
            Dvec=np.asarray([D1,D2,D3])/Dscale #Normieren der Diffusionskoeffs (DKs)
            
            # Dvec=np.fmax(Dvec,1E-16)
            print(D1) #Ausgeben der normierten DKs
            print(D2)
            print(D3)
            wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True,nz=50)
            wt=1-wt/wt[0,:]
            return np.hstack((wt[:,0],wt[:,1])) #Rückgabe von wAPI_ASD und wPol_ASD
        wAPI_ASD=1-wAPI_ASD/wAPI_ASD[0]
        wPol_ASD=1-wPol_ASD/wPol_ASD[0]
        wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-4,1E4),p0=(10,1,1)) #Einsetzen von normierten DKs in Solver
        qopt_H2O[0]=10
        Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        # Dvecopt=np.asarray([1.078000000e-11, 6.76785410e-12, 1.77526389e-11])
        print(Dvecopt)
        

        return Dvecopt
        
        

        
    Dvecopt=  fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-12,1E-8]) 
    wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True,nz=50) #Aufrufen der Diffusionsgleichung mit optimierten Dks
    DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
    wwz=wtz[:,2,:]
    return wt, Dvecopt, wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z,wwz





def Plot_Fit (ASD_L,DL):
    list1 =[]
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z,wwz= Choose_ASD(ASD_L,DL)
    wt=1-wt/wt[0,:]
    plt.plot(t,wt[:,0],'r-') #Plotten der angepassten Kurven
    plt.plot(t,wt[:,1],'g-')
    # plt.plot(t,wt[:,2],'b-')
    plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    xDL =np.linspace(0.3,0.7,3)
   # for D in xDL:
    #     wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD,DL_z= Choose_ASD(ASD_L,D)
    #     list1.append(b)
    #Dvec_array= np.array(list1)
    #fig,axis =plt.subplots()
    #axis.plot(xDL,Dvec_array[0,:],'r*')
    #axis.plot(xDL,Dvec_array[1,:],'g*')
    #axis.plot(xDL,Dvec_array[2,:],'b*')
    #wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    fig,ax =plt.subplots()
    fig1,ax1 =plt.subplots()
    fig2,ax2 =plt.subplots()
    fig3,ax3 =plt.subplots()
    z= np.linspace(0,ASD_L,50)
    X,Z=np.meshgrid(z,z)
    ax.plot(z,DL_z[0,0:-1],'y-',label ='t = 0s')
    ax.plot(z,DL_z[19,0:-1],'c-',label ='t = 4500s')
    ax.plot(z,DL_z[39,0:-1],'m-',label ='t = 9000s')
    ax.plot(z,DL_z[59,0:-1],'k-',label ='t = 13500s')
    ax.plot(z,DL_z[79,0:-1],'g-',label ='t = 18000s')
    ax2.plot(z,wwz[0,0:-1],'y-',label ='t = 0s')
    ax2.plot(z,wwz[19,0:-1],'c-',label ='t = 4500s')
    ax2.plot(z,wwz[39,0:-1],'m-',label ='t = 9000s')
    ax2.plot(z,wwz[59,0:-1],'k-',label ='t = 13500s')
    ax2.plot(z,wwz[79,0:-1],'g-',label ='t = 18000s')
    # ax2.plot(z,wwz[99,0:-1],'g-',label ='t = 22500s')
    cf=ax1.contourf(X,Z,DL_z[79,0:-1][None,:]*np.ones((50,50)),cmap="Oranges",vmin=0.3,vmax=1,levels=100)
    cf2=ax3.contourf(X,Z,wwz[79,0:-1][None,:]*np.ones((50,50)),cmap="Blues",vmin=0,vmax=1,levels=100)
    fig1.colorbar(cf)
    fig3.colorbar(cf2)
    ax.set_xlabel('z [mm]')
    ax.set_ylabel('Drugload []')
    ax.legend()
   
def Export_to_Excel (ASD_L,DL):
    z = np.linspace(0,ASD_L,20)
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    DL_xl= DL_z[79,:-1]
    DL_xl= np.array(DL_xl).flatten()
    z_xl = [z]
    index_Dvec =['DAPI/Pol','DAPI/H2O','DPol/H2O']
    columns= ['1E-12, 1E-10, 1E-12']
    df= pd.DataFrame(DL_xl,index= z_xl, columns=columns)
    df_Dvec= pd.DataFrame(b,index = index_Dvec, columns=columns)
    with pd.ExcelWriter(r"C:\Users\Justin\Documents\Bachelorarbeit\Exp._Data.xlsx",mode='a',if_sheet_exists='overlay', engine='openpyxl') as writer:
        df.to_excel(excel_writer= writer, startrow= 2, startcol= 53)
        df_Dvec.to_excel(excel_writer=writer, startrow=29, startcol=53)
  

    



    
#Choose_ASD(1,0.7)
Plot_Fit (1,0.3)
#Export_to_Excel(1,0.5)
# Out:
# 10
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2429059 seconds ----------------
# ------------- Initialization and postprocessing took 0.0231086 seconds----------------
# 10
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.4230134 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 1.0000000149011612
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.227047 seconds ----------------
# ------------- Initialization and postprocessing took 0.0036247 seconds----------------
# 10
# 1.0
# 1.0000000149011612
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2175155 seconds ----------------
# ------------- Initialization and postprocessing took 0.001 seconds----------------
# 10
# 11.049286923447829
# 5.395827817930783
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1648873 seconds ----------------
# ------------- Initialization and postprocessing took 0.00101 seconds----------------
# 10
# 11.049286923447829
# 5.395827817930783
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1829956 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 11.049287088095035
# 5.395827817930783
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.193704 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015089 seconds----------------
# 10
# 11.049286923447829
# 5.3958278983348835
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.326468 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 3.0220234355884195
# 74.70852529602172
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6222628 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 3.0220234355884195
# 74.70852529602172
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6047057 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010001 seconds----------------
# 10
# 3.022023480620078
# 74.70852529602172
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6606338 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 3.0220234355884195
# 74.7085264092655
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.6489813 seconds ----------------
# ------------- Initialization and postprocessing took 0.0041172 seconds----------------
# 10
# 22.765656429322355
# 324.2411098066939
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7533083 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 22.765656429322355
# 324.2411098066939
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7443122 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010239 seconds----------------
# 10
# 22.765656768557072
# 324.2411098066939
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7303825 seconds ----------------
# ------------- Initialization and postprocessing took 0.0033542 seconds----------------
# 10
# 22.765656429322355
# 324.2411146382629
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.738392 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 24.360318310774918
# 324.2949711371162
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7613648 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 24.360318310774918
# 324.2949711371162
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.77958 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 24.36031867377195
# 324.2949711371162
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8620142 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015426 seconds----------------
# 10
# 24.360318310774918
# 324.29497596948784
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.7738286 seconds ----------------
# ------------- Initialization and postprocessing took 0.0023097 seconds----------------
# 10
# 26.535923239647367
# 818.5696365500523
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9724256 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005207 seconds----------------
# 10
# 26.535923239647367
# 818.5696365500523
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9558321 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005032 seconds----------------
# 10
# 26.535923635063437
# 818.5696365500523
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1704733 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005112 seconds----------------
# 10
# 26.535923239647367
# 818.5696487476904
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.1823314 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025038 seconds----------------
# 10
# 27.519586071792624
# 1781.547005145023
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3341663 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 27.519586071792624
# 1781.547005145023
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9695052 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005098 seconds----------------
# 10
# 27.519586481866412
# 1781.547005145023
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9681025 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009996 seconds----------------
# 10
# 27.519586071792624
# 1781.5470316921421
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0259553 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005283 seconds----------------
# 10
# 27.886997238351796
# 3603.705470837156
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0277908 seconds ----------------
# ------------- Initialization and postprocessing took 0.0045419 seconds----------------
# 10
# 27.886997238351796
# 3603.705470837156
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.433602 seconds ----------------
# ------------- Initialization and postprocessing took 0.0022147 seconds----------------
# 10
# 27.886997653900437
# 3603.705470837156
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0481194 seconds ----------------
# ------------- Initialization and postprocessing took 0.0014303 seconds----------------
# 10
# 27.886997238351796
# 3603.7055245365523
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.977527 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010081 seconds----------------
# 10
# 27.76128999791499
# 3302.0537923960856
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2723225 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025126 seconds----------------
# 10
# 27.96785328614347
# 3528.292564524809
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2801843 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 28.019491579740063
# 3584.8524085882796
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3122225 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027875 seconds----------------
# 10
# 28.03239103777474
# 3598.9929736807644
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 5.4336679 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020007 seconds----------------
# 10
# 28.035575297103847
# 3602.53053394011
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.7839251 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010029 seconds----------------
# 10
# 28.036198278085237
# 3603.4248754542145
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 2.0643683 seconds ----------------
# ------------- Initialization and postprocessing took 0.0035081 seconds----------------
# 10
# 28.00945134725893
# 3603.703284830845
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3_sorptionpvpva.ipynb Cell 11 line 2
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=236'>237</a>         df_Dvec.to_excel(excel_writer=writer, startrow=29, startcol=53)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=244'>245</a> #Choose_ASD(1,0.7)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=245'>246</a> Plot_Fit (1,0.3)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=246'>247</a> #Export_to_Excel(1,0.5)
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3_sorptionpvpva.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=181'>182</a> def Plot_Fit (ASD_L,DL):
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=182'>183</a>     list1 =[]
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=183'>184</a>     wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z,wwz= Choose_ASD(ASD_L,DL)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=184'>185</a>     wt=1-wt/wt[0,:]
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=185'>186</a>     plt.plot(t,wt[:,0],'r-') #Plotten der angepassten Kurven
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3_sorptionpvpva.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=163'>164</a>     print(Dvecopt)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=166'>167</a>     return Dvecopt
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=171'>172</a> Dvecopt=  fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-12,1E-8])
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=172'>173</a> wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True,nz=50) #Aufrufen der Diffusionsgleichung mit optimierten Dks
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=173'>174</a> DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3_sorptionpvpva.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=157'>158</a> wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=158'>159</a> Dscale=1E13
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=159'>160</a> qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-4,1E4),p0=(10,1,1)) #Einsetzen von normierten DKs in Solver
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=160'>161</a> qopt_H2O[0]=10
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=161'>162</a> Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:974, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     971 if 'max_nfev' not in kwargs:
#     972     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 974 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                     **kwargs)
#     977 if not res.success:
#     978     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:938, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     934     result = call_minpack(fun_wrapped, x0, jac_wrapped, ftol, xtol, gtol,
#     935                           max_nfev, x_scale, diff_step)
#     937 elif method == 'trf':
# --> 938     result = trf(fun_wrapped, jac_wrapped, x0, f0, J0, lb, ub, ftol, xtol,
#     939                  gtol, max_nfev, x_scale, loss_function, tr_solver,
#     940                  tr_options.copy(), verbose)
#     942 elif method == 'dogbox':
#     943     if tr_solver == 'lsmr' and 'regularize' in tr_options:
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:123, in trf(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     119     return trf_no_bounds(
#     120         fun, jac, x0, f0, J0, ftol, xtol, gtol, max_nfev, x_scale,
#     121         loss_function, tr_solver, tr_options, verbose)
#     122 else:
# --> 123     return trf_bounds(
#     124         fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale,
#     125         loss_function, tr_solver, tr_options, verbose)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\trf.py:338, in trf_bounds(fun, jac, x0, f0, J0, lb, ub, ftol, xtol, gtol, max_nfev, x_scale, loss_function, tr_solver, tr_options, verbose)
#     334 step, step_h, predicted_reduction = select_step(
#     335     x, J_h, diag_h, g_h, p, p_h, d, Delta, lb, ub, theta)
#     337 x_new = make_strictly_feasible(x + step, lb, ub, rstep=0)
# --> 338 f_new = fun(x_new)
#     339 nfev += 1
#     341 step_h_norm = norm(step_h)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:828, in least_squares.<locals>.fun_wrapped(x)
#     827 def fun_wrapped(x):
# --> 828     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:507, in _lightweight_memoizer.<locals>._memoized_func(params)
#     504 if np.all(_memoized_func.last_params == params):
#     505     return _memoized_func.last_val
# --> 507 val = f(params)
#     509 if _memoized_func.last_params is None:
#     510     _memoized_func.last_params = np.copy(params)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _wrap_func.<locals>.func_wrapped(params)
#     522 def func_wrapped(params):
# --> 523     return func(xdata, *params) - ydata
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3_sorptionpvpva.ipynb Cell 11 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=150'>151</a> print(D2)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=151'>152</a> print(D3)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=152'>153</a> wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True,nz=50)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=153'>154</a> wt=1-wt/wt[0,:]
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3_sorptionpvpva.ipynb#X13sZmlsZQ%3D%3D?line=154'>155</a> return np.hstack((wt[:,0],wt[:,1]))
#
# File C:\GitHub_Projects\diffusionpy\diffusionpy\Stefan_Maxwell_segmental.py:171, in Diffusion_MS(tint, L, Dvec, wi0, wi8, Mi, mobile, full_output, dlnai_dlnwi, **kwargs)
#     168 start=time.time_ns()
#     169 # sol=nbkode.BDF5(ode,tint[0],xinit,params=[tint,THFaktor,mobiles,immobiles,Mi,D,allflux,swelling,rho,wi0,dmuext,rhoiB,drhovdtB]).run(tint)
#     170 # sol=nbrk_ode(ode,(tint[0],tint[-1]),xinit,args=(tint,THFaktor,mobiles,immobiles,Mi,D,allflux,swelling,rho,wi0,dmuext,rhoiB,drhovdtB),rk_method=0,t_eval=tint)#rtol=1E-2,atol=1E-3)
# --> 171 sol=solve_ivp(ode,(tint[0],tint[-1]),xinit,args=(tint,THFaktor,mobiles,immobiles,Mi,D,allflux,wi0,dmuext,wiB),method="Radau",t_eval=tint,atol=1E-3)#rtol=1E-2,atol=1E-3)
#     172 end=time.time_ns()
#     173 print("------------- Diffusion modeling took "+str((end-start)/1E9)+" seconds ----------------")
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\integrate\_ivp\ivp.py:602, in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     600 status = None
#     601 while status is None:
# --> 602     message = solver.step()
#     604     if solver.status == 'finished':
#     605         status = 0
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\integrate\_ivp\base.py:197, in OdeSolver.step(self)
#     195 else:
#     196     t = self.t
# --> 197     success, message = self._step_impl()
#     199     if not success:
#     200         self.status = 'failed'
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\integrate\_ivp\radau.py:457, in Radau._step_impl(self)
#     455 while not converged:
#     456     if LU_real is None or LU_complex is None:
# --> 457         LU_real = self.lu(MU_REAL / h * self.I - J)
#     458         LU_complex = self.lu(MU_COMPLEX / h * self.I - J)
#     460     converged, n_iter, Z, rate = solve_collocation_system(
#     461         self.fun, t, y, h, Z0, scale, self.newton_tol,
#     462         LU_real, LU_complex, self.solve_lu)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\integrate\_ivp\radau.py:332, in Radau.__init__.<locals>.lu(A)
#     330 def lu(A):
#     331     self.nlu += 1
# --> 332     return lu_factor(A, overwrite_a=True)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\linalg\_decomp_lu.py:84, in lu_factor(a, overwrite_a, check_finite)
#      82 overwrite_a = overwrite_a or (_datacopied(a1, a))
#      83 getrf, = get_lapack_funcs(('getrf',), (a1,))
# ---> 84 lu, piv, info = getrf(a1, overwrite_a=overwrite_a)
#      85 if info < 0:
#      86     raise ValueError('illegal value in %dth argument of '
#      87                      'internal getrf (lu_factor)' % -info)
#
# KeyboardInterrupt:

# %% [markdown]
# Fitting the sorption Data und Calculation of the Sorption MS Coefficients

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from diffusionpy import Diffusion_MS
from scipy.optimize import curve_fit

tsorpL1D03= np.array([0,1001,2002,3003,4004,5005,6005,7007,8008,9008,10009,11010,12010,13012,14012,15013,16015,17015,18016])
wwsorpL1D03 = np.array([1.4E-5,8.35E-3,1.443E-2,1.947E-2,2.39E-2,2.79E-2,3.158E-2,3.5E-2,3.821E-2,4.125E-2,4.413E-2,4.689E-2,4.952E-2,5.204E-2,5.447E-2,5.681E-2,5.906E-2,6.124E-2,6.336E-2])
tsorpL1D05= np.array([0,1005,2006,3007,4009,5010,6011,7013,8014,9016,10017,11018,12019,13021,14022,15023,16024,17026,18027])
wwsorpL1D05= np.array([3.1E-6,5.1E-3,7.4E-3,9E-3,1.029E-2,1.114E-2,1.238E-2,1.327E-2,1.408E-2,1.484E-2,1.554E-2,1.62E-2,1.682E-2,1.742E-2,1.798E-2,1.852E-2,1.904E-2,1.954E-2,2.002E-2])
tsorpL1D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL1D07= np.array([0,1.82E-3,2.59E-3,3.08E-3,3.46E-3,3.77E-3,4.04E-3,4.29E-3,4.51E-3,4.71E-3,4.91E-3,5.09E-3,5.26E-3,5.42E-3,5.58E-3,5.73E-3])
tsorpL25D03= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D03= np.array([6.6E-6,4.128E-2,6.4E-2,8.099E-2,9.493E-2,0.10691,0.11746,0.12691,0.13548,0.14328,0.15036,0.15677,0.1625,0.1676,0.1721,0.17607,0.17955,0.18263,0.18535])
# tsorpL25D03=np.array([0,990.6,1981.8,2972.4,3963,4954.2,5944.8,6936,7926.6,8917.8,9908.4,10899.6,11890.2,12881.4,13872,14863.2,15853.8,16844.4,17835.6])
# wwsorpL25D03=np.array([0,0.032197737,0.051746253,0.066878234,0.079514529,0.090600233,0.100391134,0.109238105,0.117336032,0.124844276,0.131764824,0.138088973,0.143849781,0.149063284,0.153688067,0.15779709,0.161400097,0.164581484,0.167453184])
tsorpL25D05= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D05= np.array([1.1E-4,2.438E-2,3.352E-2,3.902E-2,4.284E-2,4.581E-2,4.825E-2,5.048E-2,5.25E-2,5.435E-2,5.606E-2,5.773E-2,5.913E-2,6.056E-2,6.194E-2,6.314E-2,6.429E-2,6.556E-2,6.656E-2])
tsorpL25D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL25D07= np.array([0,8.1E-3,1.106E-2,1.32E-2,1.494E-2,1.642E-2,1.771E-2,1.887E-2,1.994E-2,2.0904E-2,2.1806E-2,2.2643E-2,2.343E-2,2.417E-2,2.487E-2,2.554E-2])
tsorpL1D0=np.array([0,1000.8,2011.2,3021.6,4032.6,5043,6053.4,7063.8,8074.8,9085.2,10096.2,11106.6,12117,13127.4,14138.4,15148.8,16159.2,17170.2,18180.6,19191,20202,21212.4,22222.8,23233.2,24244.2,25254.6,26265,27276,28286.4,29297.4,30307.8,31318.2,32328.6,33339.6,34350])
wwsorpL1D0=np.array([2.32264E-05,0.032490472,0.056981835,0.077413963,0.095178449,0.110986758,0.125309571,0.138440911,0.150612773,0.1619091,0.172361956,0.182051,0.191073767,0.199457794,0.207237963,0.214556109,0.221489884,0.228057404,0.234293133,0.240213112,0.245848113,0.25120615,0.256302361,0.261154739,0.265761433,0.270113111,0.274226366,0.27809627,0.281728653,0.285163287,0.288411191,0.291466507,0.294353471,0.297088495,0.299696478])
wi_0= np.array([0.9999,0.0001])
mobile =np.array([True, True])
Mi0= np.asarray([357.79,65000,16.02])



def Choose_Sorp(L_ASD,DL_ASD):
    if L_ASD == 1 and DL_ASD == 0.3:
        t_sorp= tsorpL1D03
        ww_sorp= wwsorpL1D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==1 and DL_ASD ==0.5: 
        t_sorp= tsorpL1D05
        ww_sorp= wwsorpL1D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==1 and DL_ASD ==0.7: 
        t_sorp= tsorpL1D07
        ww_sorp= wwsorpL1D07
        wi_8 = np.array([0.9405,0.0505])
    elif L_ASD == 0.25 and DL_ASD == 0.3:
        t_sorp= tsorpL25D03
        ww_sorp= wwsorpL25D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==0.25 and DL_ASD ==0.5: 
        t_sorp= tsorpL25D05
        ww_sorp= wwsorpL25D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==0.25 and DL_ASD ==0.7: 
        t_sorp= tsorpL25D07
        ww_sorp= wwsorpL25D07
        wi_8 = np.array([0.9405,0.0505])
    elif L_ASD==1 and DL_ASD ==0:
        t_sorp= tsorpL1D0
        ww_sorp= wwsorpL1D0
        L_ASD=43.0544/1E3/(np.pi/4*0.008**2)/1190
        wi_8 = np.array([0.65,0.35])
    else: print('Bitte gültige Länge und Drugload eingeben!')
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    L= L_ASD*10E-4
    w_APIPol= 1-ww_sorp
    M_APIPol= 1/((DL_ASD/Mi0[0])+((1-DL_ASD)/Mi0[1])) #Mittlere molare Masse
    Mi = np.array([M_APIPol,16.02])
    from numpy import array

    def fit_Diff_Sorp (ww_sorp,w_APIPol):
        def Diff_for_fit(t,D_sorp):
            Dscale=1E13 #Hilfsvariable
            Dsorp_norm=np.array([D_sorp])/Dscale #Normieren des Diffusionskoeffs (DKs)
            print(Dsorp_norm) #Ausgeben des normierten DKs
            ww=Diffusion_MS(t,L,Dsorp_norm,wi_0,wi_8,Mi,mobile) #Ouput ist 2D
            return ww[:,1] #Rückgabe von w_H2O in ww
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diff_for_fit,t_sorp,ww_sorp,bounds=(1E-6,1E10),p0=(1000)) #Einsetzen von normierten DKs in Solver
        Dsorpopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dsorpopt)
        
        return Dsorpopt
    Dsorpopt= fit_Diff_Sorp(ww_sorp,w_APIPol)
    ww,wtz,zvec,Lt= Diffusion_MS(t,L,Dsorpopt,wi_0,wi_8,Mi,mobile,full_output=True)
    wwz=wtz[:,1,:]
    fig,ax =origin_like.subplots()
    origin_like.plot(ax,zvec*1E3*np.average(1/(1-wwz[-1,:])),wwz[-1,:],'b-')
    # ax.set_yticks([0,0.25,0.5,0.75,1.])
    # ax.set_xticks([0,0.25,0.5,0.75,1.])
    return ww, Dsorpopt, t_sorp, ww_sorp
    

def plot_sorp (ax,t_sorp, ww_sorp):
    fig,ax=plt.subplots()
    ax.plot(t_sorp,ww_sorp,'bo')

fig,ax=origin_like.subplots()
fig1,ax1=origin_like.subplots()
origin_like.set_ticks(ax,0,300,0,0.20)
origin_like.set_ticks(ax1,0,1,-13,-10)
ds=[]
def plot_fit_sorp (L,DL):
    list =[]
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(L,DL)
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    if DL==0.:
        sym="o"
    if DL==0.3:
        sym="h"
    elif DL==0.5:
        sym='^'
    elif DL==0.7:
        sym='s'
    origin_like.plot(ax,t/60, ww [:,1],'c-')
    origin_like.plot(ax,t_sorp/60,ww_sorp,'c'+sym)
    origin_like.set_xlabel(ax,"t","min")
    origin_like.set_ylabel(ax,"w_w","-")
    origin_like.plot(ax1,DL,np.log10(Dsorpopt),'co')
    origin_like.set_xlabel(ax1,"DL","-")
    origin_like.set_ylabel(ax1,"D_w","m^2 s^{-1}")
    ds.append(Dsorpopt)
    #xL = np.linspace(0.3,0.7,3)
    #for D in xL:
    #    a,b,c,d = Choose_Sorp(L,D)
    #    list.append(b)
    #Dvec_sorp= np.array(list)
    #fig,axis = plt.subplots()
    #axis.plot(xL,Dvec_sorp,'b*')

def Export_to_Excel (ASD_L,DL):
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(ASD_L,DL)
    index_Dvec =['DASD/DH2O']
    columns= ['1E-9']
    df_Dvec= pd.DataFrame(Dsorpopt,index = index_Dvec, columns=columns)
    with pd.ExcelWriter(r"C:\Users\Justin\Documents\Bachelorarbeit\Exp._Data.xlsx",mode='a',if_sheet_exists='overlay', engine='openpyxl') as writer:
        df_Dvec.to_excel(excel_writer=writer,sheet_name= 'Sheet2', startrow=52, startcol=14)

    
# plot_fit_sorp(1,0.)
# plot_fit_sorp(0.25,0.3)
# plot_fit_sorp(0.25,0.5)
# plot_fit_sorp(0.25,0.7)
#import pandas as pd

plot_fit_sorp(1,0.3)
plot_fit_sorp(1,0.5)
plot_fit_sorp(1,0.7)
print(np.asarray(ds).tolist())
# Export_to_Excel(0.25,0.7)
# Out:
# [1.e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0396172 seconds ----------------
# ------------- Initialization and postprocessing took 0.0014237 seconds----------------
# [1.00000001e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0340655 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011367 seconds----------------
# [8.73611781e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0377592 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011265 seconds----------------
# [8.73611794e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0498019 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [6.69613915e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0491064 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015535 seconds----------------
# [6.69613925e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0298575 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.32694802e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.031792 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010184 seconds----------------
# [7.32694813e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0376955 seconds ----------------
# ------------- Initialization and postprocessing took 0.002443 seconds----------------
# [7.06943406e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0469306 seconds ----------------
# ------------- Initialization and postprocessing took 0.0017672 seconds----------------
# [7.06943416e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0499359 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21146498e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0542468 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009993 seconds----------------
# [7.21146509e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0354511 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21146197e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0491449 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010194 seconds----------------
# [7.21146208e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0369013 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010035 seconds----------------
# [7.21145594e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.030343 seconds ----------------
# ------------- Initialization and postprocessing took 0.0040352 seconds----------------
# [7.21145605e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0319304 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21144388e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0286646 seconds ----------------
# ------------- Initialization and postprocessing took 0.0032423 seconds----------------
# [7.21144398e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0307004 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010364 seconds----------------
# [7.21141975e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0361693 seconds ----------------
# ------------- Initialization and postprocessing took 0.001037 seconds----------------
# [7.21141986e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0456437 seconds ----------------
# ------------- Initialization and postprocessing took 0.0021699 seconds----------------
# [7.21137151e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.03452 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21137162e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.030003 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010351 seconds----------------
# [7.21127502e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0307705 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013453 seconds----------------
# [7.21127513e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0274316 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21108204e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0291277 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.21108215e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.028173 seconds ----------------
# ------------- Initialization and postprocessing took 0.0016989 seconds----------------
# [7.21069609e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0314271 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.2106962e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0341116 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.20992421e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0308357 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.20992431e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0307185 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.20838052e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.030687 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.20838063e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0219564 seconds ----------------
# ------------- Initialization and postprocessing took 0.0179791 seconds----------------
# [7.20529349e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0318548 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.20529359e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0358994 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012713 seconds----------------
# [7.19912074e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0281786 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.19912084e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0382056 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010317 seconds----------------
# [7.18678052e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0389717 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005416 seconds----------------
# [7.18678063e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0389706 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.17445089e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0299647 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025453 seconds----------------
# [7.174451e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0264969 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025103 seconds----------------
# [7.14981279e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0345681 seconds ----------------
# ------------- Initialization and postprocessing took 0.0014326 seconds----------------
# [7.1498129e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0283103 seconds ----------------
# ------------- Initialization and postprocessing took 0.0026053 seconds----------------
# [7.16718446e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0325494 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020347 seconds----------------
# [7.15415571e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.038092 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.15089852e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0310271 seconds ----------------
# ------------- Initialization and postprocessing took 0.0040661 seconds----------------
# [7.15008423e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0318138 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013791 seconds----------------
# [7.14988065e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0326474 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005379 seconds----------------
# [7.14982976e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.031009 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [7.14981704e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0326923 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005449 seconds----------------
# [7.14981385e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0322482 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010316 seconds----------------
# [7.14981306e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0315181 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010354 seconds----------------
# [7.14981317e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0328818 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009954 seconds----------------
# [7.14981306e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0363438 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0337564 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019948 seconds----------------
# [1.00000001e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0322231 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [8.55767789e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0323402 seconds ----------------
# ------------- Initialization and postprocessing took 0.0085678 seconds----------------
# [8.55767802e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0293238 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [3.48908599e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0259411 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010038 seconds----------------
# [3.48908605e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0334677 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005126 seconds----------------
# [2.1881261e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0216273 seconds ----------------
# ------------- Initialization and postprocessing took 0.0046695 seconds----------------
# [2.18812614e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0224607 seconds ----------------
# ------------- Initialization and postprocessing took 0.0045422 seconds----------------
# [1.92882601e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0260229 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027427 seconds----------------
# [1.92882604e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0282409 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.90200083e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0211954 seconds ----------------
# ------------- Initialization and postprocessing took 0.0065073 seconds----------------
# [1.90200086e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0227702 seconds ----------------
# ------------- Initialization and postprocessing took 0.0050632 seconds----------------
# [1.89691362e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0259137 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013295 seconds----------------
# [1.89691365e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0260822 seconds ----------------
# ------------- Initialization and postprocessing took 0.0022718 seconds----------------
# [1.89942365e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0272909 seconds ----------------
# ------------- Initialization and postprocessing took 0.0026019 seconds----------------
# [1.89754113e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0289426 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.8970705e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0209933 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010612 seconds----------------
# [1.89695284e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0232267 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012266 seconds----------------
# [1.89692343e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0191639 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.89691607e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0248235 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009972 seconds----------------
# [1.89691424e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0206759 seconds ----------------
# ------------- Initialization and postprocessing took 0.0070125 seconds----------------
# [1.89691378e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0272787 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015501 seconds----------------
# [1.89691366e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.025914 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.89691369e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0288542 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009967 seconds----------------
# [1.89691366e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0227454 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019306 seconds----------------
# [1.e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0336631 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000001e-10]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0348399 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [4.88756908e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0207872 seconds ----------------
# ------------- Initialization and postprocessing took 0.0044276 seconds----------------
# [4.88756915e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0217008 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005105 seconds----------------
# [1.8107173e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0191344 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.81071733e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0249618 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.08608737e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0291542 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010965 seconds----------------
# [1.08608739e-12]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.032505 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010396 seconds----------------
# [8.8685234e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0282382 seconds ----------------
# ------------- Initialization and postprocessing took 0.0012148 seconds----------------
# [8.86852353e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0261889 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [8.55524355e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0277909 seconds ----------------
# ------------- Initialization and postprocessing took 0.0023634 seconds----------------
# [8.55524368e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0234203 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005063 seconds----------------
# [8.54570067e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0242483 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019988 seconds----------------
# [8.5457008e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0196032 seconds ----------------
# ------------- Initialization and postprocessing took 0.0006754 seconds----------------
# [8.54570067e-13]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0247027 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020313 seconds----------------
# [[7.149813059701458e-12], [1.8969136612798835e-12], [8.545700670713341e-13]]

# %% [markdown]
# First model

# %%
mobile= np.asarray([True,True,True])
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2    
import time

wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)

color1 = "#99CDE9"
color2 = "#F08208"
color3 = "#99CC00"

fig,ax=origin_like.subplots()

origin_like.plot(ax,t,wt[:,0],"c-")
origin_like.plot(ax,t,wt[:,1],"r-")
origin_like.plot(ax,t,wt[:,2],"b-")
origin_like.plot(ax,texp,wINDL1D03,"co")
origin_like.plot(ax,texp,wPolL1D03,"ro")
origin_like.set_xlabel(ax,"t","s")
origin_like.set_ylabel(ax,"w_i","-")
origin_like.set_ticks(ax,0,300,0,1)
plt.show()
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1637101 seconds ----------------
# ------------- Initialization and postprocessing took 0.0087225 seconds----------------

# %% [markdown]
# First try of an fitting function: leastsq

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import scipy as sc
import matplotlib.pyplot as plt

x= np.array([1,3,4,5,7,8,12,15,19,24])
y = np.array([3,7,14,25,41,48,59,73,78,95])

plt.plot(x,y,'ro')

def funcline (x,a,b):
    return a*x+b
def funcquad (x,a,b,c):
    return a*x**2+b*x+c   

X= np.linspace(x.min(),x.max(),50)
popt, pcov = curve_fit(funcline,x,y)
print(popt)
plt.plot(x,funcline(x, *popt))

qopt, qcov= curve_fit(funcquad,x,y)
plt.plot(x,funcquad(x,*qopt))
# Out:
# [4.12009419 3.92307692]

# %% [markdown]
# Correlation Between Diffusion Coeffs. and Drugload

# %%
import numpy as np

D3an103= np.array([0.000829016, 0.001006316, 0.001120834, 0.000711376, 0.000725273])
DLan103= np.array([2.129266346, 1.978956849, 1.895270904, 2.242795041, 2.23009888])
D3an105= np.array([0.023122705,0.017898807,0.033487196,0.02260883,0.01043749,0.003487154,0.000209907])
DLan105= np.array([1.120853854,1.365432671,0.744372507,1.406673126,1.707384131,1.691839457,1.821849459])
D3an2503= np.array([0.002857259,0.002960762,0.002994224,0.002798141,0.0026755])
DLan2503= np.array([2.129436909,2.093832443,2.072496532,2.105566472,2.157690245])
D3an2505= np.array([0.006739994,0.002250945,0.00446893,0.002631958])
DLan2505= np.array([1.467047509,1.757523731,1.583733273,1.725752866])

def lin_Pearson_correlation(x,y):
    if len(x)==len(y):
        Sum_xy = sum((x-x.mean())*(y-y.mean()))
        Sum_x_squared = sum((x-x.mean())**2)
        Sum_y_squared = sum((y-y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
             
print(lin_Pearson_correlation(D3an2505,DLan2505))

def quad_Pearson_correlation(x,y):
    A= 195.71
    B=-0.0486
    C=454.96E-6
    if len(x)==len(y):
        X= B*x + A
        Y= y -C*x
        sigmaX =np.sqrt(sum(X-X.mean())**2/len(X))
        sigmaY=np.sqrt(sum(Y-Y.mean())**2/len(Y))
        CovXY= sum((X-X.mean())*(Y-Y.mean()))
        corrquad= CovXY/(sigmaX*sigmaY)
    return corrquad

print(quad_Pearson_correlation(D3an103,DLan103))
# Out:
# -0.9942838520049285
# 2.022973394682165e+23
