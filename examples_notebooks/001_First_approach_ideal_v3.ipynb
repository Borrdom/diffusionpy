wPolL25D03=array([2.47540000e-06,5.76787000e-06,9.85161000e-06,1.43790000e-05,1.61947000e-05,1.67283000e-05,1.71512000e-05,1.73003000e-05,1.73463000e-05,1.71751000e-05,1.73692000e-05,1.75724000e-05])
wH2OL25D03=array([9.99997186e-01,9.99993505e-01,9.99989013e-01,9.99983327e-01,9.99980597e-01,9.99979161e-01,9.99977877e-01,9.99976937e-01,9.99975988e-01,9.99975239e-01,9.99974299e-01,9.99973229e-01])
wINDL25D05=array([4.58354000e-07,9.25174000e-07,1.14901000e-06,2.66209000e-06,3.70568000e-06,4.83550000e-06,5.81176000e-06,6.78711000e-06,7.66320000e-06,8.61049000e-06,9.53598000e-06,1.05918000e-05])
wPolL25D05=array([7.44788000e-07,1.15094000e-06,1.84658000e-06,1.41097000e-06,1.55351000e-06,1.53632000e-06,1.52075000e-06,1.54180000e-06,1.58611000e-06,1.63294000e-06,1.67478000e-06,1.54857000e-06])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])

# %% [markdown]
# Set the Information of the Process (temperature, pressure, wi0, wi8, L, D)

# %%
T=298.15
p=1E5
nc=3 # number of components
L=1E-4 # estimated thickness of the ASD
wi0=np.asarray([0.49999,0.49999,0.00002]) # Weight fractions of the components API, polymer, water at t=0
wi8=np.asarray([0.00001,0.00001,0.99998]) # Weight fractions of the components API, polymer, water at t=8.T
Mi= np.asarray([357.79,65000,16.02])

# %% [markdown]
# Creating a vector which holds the MS diffusion coefficients

# %%
Dvec =np.asarray([1E-5,2E-12,8E-12])

# %% [markdown]
# Calculate the values for the concentrations inside the ASD

# %%
import numpy as np
from numpy import array
import scipy as sp
from diffusionpy import Diffusion_MS, origin_like
import matplotlib.pyplot as plt
plt.rcdefaults()
from scipy.optimize import curve_fit
import xlwings as xw
import pandas as pd

texp=array([5,15,30,60,90,120,150,180,210,240,270,300])*60
wINDL1D03= array([3.42274E-07,6.63373000e-07,1.30293000e-06,2.61848000e-06,4.06235000e-06,5.50577000e-06,7.11082000e-06,8.82865000e-06,1.03757000e-05,1.22831000e-05,1.34226000e-05,1.48856000e-05])
wH2OL25D05=array([9.99998797e-01,9.99997924e-01,9.99997004e-01,9.99995927e-01,9.99994741e-01,9.99993628e-01,9.99992667e-01,9.99991671e-01,9.99990751e-01,9.99989757e-01, 9.99988789e-01,9.99987860e-01])
wINDL25D07=array([2.10882000e-07,9.53317000e-07,1.13081000e-06,2.30461000e-06,4.49098000e-06,5.31209000e-06,6.49505000e-06,7.53254000e-06, 8.76421000e-06,1.00650000e-05,1.11047000e-05,1.21564000e-05])
wPolL25D07=array([1.17370000e-07,2.51991000e-08,1.62530000e-07,-7.93003000e-08,-3.38246000e-08, 1.63026000e-08,6.65202000e-08,1.43608000e-08,8.95516000e-08,6.91439000e-07,-7.68527000e-07,-7.18490000e-08])
wH2OL25D07=array([9.99999672e-01,9.99999021e-01,9.99998707e-01,9.99997775e-01,9.99995543e-01,9.99994672e-01,9.99993438e-01,9.99992453e-01,9.99991146e-01,9.99989244e-01,9.99989664e-01,9.99987915e-01])
mB_0 = 0.5
mASDL25D03_0= 1.5E-5
mASDL1D03_0= 6.2E-5
mASDL25D05_0= 1.6E-5
mASDL1D05_0= 6.3E-5
mASDL25D07_0= 1.6E-5
mASDL1D07_0= 6.4E-5
Mi= np.asarray([357.79,65000,16.02])
mobile= np.asarray([True,True,True])
wi_8 =np.asarray([0.0001,0.0001,0.9998])
Dvec =np.asarray([1E-1,2E-12,8E-1])
Dvec=np.asarray([327081.87865031627,386294.20602000307,644379.7545334897])/1E14

Dvec=np.asarray([244258.29860143378,
632465.849552949,
762682.380133524])/1E14
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2

def Conc_ASD(wAPI_B,w0API_B,w0API_ASD,wPol_B,w0Pol_B,w0Pol_ASD,wH2O_B,w0H2O_B,w0H2O_ASD,m_B,m_ASD):
   
    wAPI_ASD= (w0API_B-wAPI_B)*(m_B/m_ASD)+w0API_ASD
    wPol_ASD=(w0Pol_B-wPol_B)*(m_B/m_ASD)+w0Pol_ASD
    wH2O_ASD= (w0H2O_B-wH2O_B)*(m_B/m_ASD)+w0H2O_ASD
    wges_ASD= wAPI_ASD + wPol_ASD + wH2O_ASD
    return wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD


def plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    plt.plot(texp, wAPI_ASD,'ro')
    plt.plot(texp,wPol_ASD,'go')
    plt.plot(texp,wH2O_ASD,'bo')
    plt.plot(texp,wges_ASD,'yo')
    plt.xlabel("t [s]")
    plt.ylabel("wi [-]")

def fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
    def funcline(x,a,b):
        return a*x+b
    def funcquad(x,a,b,c):
        return a*x**2+b*x+c
    # popt_API, pcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*popt_API),'r-')
    # qopt_API, qcov_API= curve_fit(funcline,texp,wAPI_ASD)
    # plt.plot(texp,funcline(texp,*qopt_API),'r--')
    # popt_Pol, pcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*popt_Pol),'g-')
    # qopt_Pol, qcov_Pol= curve_fit(funcline,texp,wPol_ASD)
    # plt.plot(texp,funcline(texp,*qopt_Pol),'g--')
    # popt_H2O, pcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*popt_H2O),'b-')
    # qopt_H2O, qcov_H2O= curve_fit(funcline,texp,wH2O_ASD)
    # plt.plot(texp,funcline(texp,*qopt_H2O),'b--')
  #  MSopt, MScov = curve_fit(Diffusion_MS,texp,wAPI_ASD)
  #  plt.plot(texp,Diffusion_MS(texp,*MSopt),'r*')
    
def Choose_ASD(ASD_L,ASD_DL):
    if ASD_L == 1 and ASD_DL == 0.3:
        wIND = wINDL1D03
        w0IND = 0.3
        wPol = wPolL1D03
        wH2O = wH2OL1D03
        mASD = mASDL1D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L ==1 and ASD_DL ==0.5:
        wIND = wINDL1D05
        w0IND = 0.5
        wPol = wPolL1D05
        wH2O = wH2OL1D05
        mASD = mASDL1D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L ==1 and ASD_DL == 0.7:
        wIND = wINDL1D07
        w0IND = 0.7
        wPol = wPolL1D07
        wH2O = wH2OL1D07
        mASD = mASDL1D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    elif ASD_L == 0.25 and ASD_DL== 0.3:
        wIND = wINDL25D03
        w0IND = 0.3
        wPol = wPolL25D03
        wH2O = wH2OL25D03
        mASD = mASDL25D03_0
        wi_0 = np.asarray([0.2999,0.6999,0.0002])
    elif ASD_L == 0.25 and ASD_DL ==0.5:
        wIND = wINDL25D05
        w0IND = 0.5
        wPol = wPolL25D05
        wH2O = wH2OL25D05
        mASD = mASDL25D05_0
        wi_0 = np.asarray([0.4999,0.4999,0.0002])
    elif ASD_L == 0.25 and ASD_DL == 0.7:
        wIND = wINDL25D07
        w0IND = 0.7
        wPol = wPolL25D07
        wH2O = wH2OL25D07
        mASD = mASDL25D07_0
        wi_0 = np.asarray([0.6999,0.2999,0.0002])
    else: print("Bitte gültige Werte für Länge und Drugload eingeben")
    w0Pol = 1 - w0IND  
    L = ASD_L * 10E-4 
    

    wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD=Conc_ASD(wIND,0,w0IND,wPol,0,w0Pol,wH2O,1,0,mB_0,mASD)

    
    #fit_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    # wt=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    # wt= Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile)
    def fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD):
        def Diffforfit(t,D1,D2,D3):
            Dscale=1E13 #Hilfsvariable
            D1=10
            Dvec=np.asarray([D1,D2,D3])/Dscale #Normieren der Diffusionskoeffs (DKs)
            
            # Dvec=np.fmax(Dvec,1E-16)
            print(D1) #Ausgeben der normierten DKs
            print(D2)
            print(D3)
            wt,wtz,_,_=Diffusion_MS(t,L,Dvec,wi_0,wi_8,Mi,mobile,full_output=True,nz=50)
            return np.hstack((wt[:,0],wt[:,1])) #Rückgabe von wAPI_ASD und wPol_ASD
        wexp=np.hstack((wAPI_ASD,wPol_ASD)) #Zusammenfügen zu einem Array
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diffforfit,texp,wexp,bounds=(1E-6,1E12),p0=(10,1,1)) #Einsetzen von normierten DKs in Solver
        qopt_H2O[0]=10
        Dvecopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        # Dvecopt=np.asarray([1.078000000e-11, 6.76785410e-12, 1.77526389e-11])
        print(Dvecopt)
        

        return Dvecopt
        
        

        
    Dvecopt=  fit_Diff_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD) #Aufrufen der Fit- Funktion  #np.array([1E-8,1E-12,1E-8]) 
    wt,wtz,_,_=Diffusion_MS(t,L,Dvecopt,wi_0,wi_8,Mi,mobile,full_output=True,nz=50) #Aufrufen der Diffusionsgleichung mit optimierten Dks
    DL_z= wtz[:,0,:]/(wtz[:,0,:]+wtz[:,1,:])
    
    return wt, Dvecopt, wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z





def Plot_Fit (ASD_L,DL):
    list1 =[]
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    plt.plot(t,wt[:,0],'r-') #Plotten der angepassten Kurven
    plt.plot(t,wt[:,1],'g-')
    plt.plot(t,wt[:,2],'b-')
    plot_ASD(wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD)
    xDL =np.linspace(0.3,0.7,3)
   # for D in xDL:
    #     wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD,DL_z= Choose_ASD(ASD_L,D)
    #     list1.append(b)
    #Dvec_array= np.array(list1)
    #fig,axis =plt.subplots()
    #axis.plot(xDL,Dvec_array[0,:],'r*')
    #axis.plot(xDL,Dvec_array[1,:],'g*')
    #axis.plot(xDL,Dvec_array[2,:],'b*')
    #wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    fig,ax =plt.subplots()
    z= np.linspace(0,ASD_L,50)
    ax.plot(z,DL_z[0,0:-1],'y-',label ='t = 0s')
    ax.plot(z,DL_z[19,0:-1],'c-',label ='t = 4500s')
    ax.plot(z,DL_z[39,0:-1],'m-',label ='t = 9000s')
    ax.plot(z,DL_z[59,0:-1],'k-',label ='t = 13500s')
    ax.plot(z,DL_z[79,0:-1],'g-',label ='t = 18000s')
    ax.set_xlabel('z [mm]')
    ax.set_ylabel('Drugload []')
    ax.legend()
   
def Export_to_Excel (ASD_L,DL):
    z = np.linspace(0,ASD_L,20)
    wt,b,wAPI_ASD,wPol_ASD,wH2O_ASD,wges_ASD, DL_z= Choose_ASD(ASD_L,DL)
    DL_xl= DL_z[79,:-1]
    DL_xl= np.array(DL_xl).flatten()
    z_xl = [z]
    index_Dvec =['DAPI/Pol','DAPI/H2O','DPol/H2O']
    columns= ['1E-12, 1E-10, 1E-12']
    df= pd.DataFrame(DL_xl,index= z_xl, columns=columns)
    df_Dvec= pd.DataFrame(b,index = index_Dvec, columns=columns)
    with pd.ExcelWriter(r"C:\Users\Justin\Documents\Bachelorarbeit\Exp._Data.xlsx",mode='a',if_sheet_exists='overlay', engine='openpyxl') as writer:
        df.to_excel(excel_writer= writer, startrow= 2, startcol= 53)
        df_Dvec.to_excel(excel_writer=writer, startrow=29, startcol=53)
  

    



    
#Choose_ASD(1,0.7)
Plot_Fit (1,0.3)
#Export_to_Excel(1,0.5)
# Out:
# 10
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2417615 seconds ----------------
# ------------- Initialization and postprocessing took 0.001018 seconds----------------
# 10
# 1.0
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.218551 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020533 seconds----------------
# 10
# 1.0000000149011612
# 1.0
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1871771 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 1.0
# 1.0000000149011612
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1935858 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 23.77267967423998
# 11.049870645907957
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0
seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.6595438789561
# 851.5110309817582
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1085049 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65954449973168
# 851.5110309817582
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.5347868 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010001 seconds----------------
# 10
# 41.6595438789561
# 851.5110436702613
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0997472 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009969 seconds----------------
# 10
# 41.65953364581943
# 851.510801996943
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0822441 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364581943
# 851.510801996943
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0571851 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011387 seconds----------------
# 10
# 41.659534266594854
# 851.510801996943
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2727777 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364581943
# 851.5108146854427
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0766258 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364410554
# 853.5122278262072
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0706911 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364410554
# 853.5122278262072
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0405488 seconds ----------------
# ------------- Initialization and postprocessing took 0.015126 seconds----------------
# 10
# 41.65953426488096
# 853.5122278262072
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2269485 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364410554
# 853.5122405445305
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0523552 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.6595336416692
# 854.0125841455457
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0936593 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.6595336416692
# 854.0125841455457
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0671485 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953426244462
# 854.0125841455457
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0340839 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009991 seconds----------------
# 10
# 41.6595336416692
# 854.0125968713248
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.159646 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364085267
# 855.0132970609877
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0919697 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364085267
# 855.0132970609877
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0746087 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.659534261628096
# 855.0132970609877
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3300197 seconds ----------------
# ------------- Initialization and postprocessing took 0.0044531 seconds----------------
# 10
# 41.65953364085267
# 855.0133098016787
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.5766825 seconds ----------------
# ------------- Initialization and postprocessing took 0.0035073 seconds----------------
# 10
# 41.65953364009294
# 856.0140099775031
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2924113 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364009294
# 856.0140099775031
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.48745 seconds ----------------
# ------------- Initialization and postprocessing took 0.0014441 seconds----------------
# 10
# 41.65953426086836
# 856.0140099775031
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.5445283 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65953364009294
# 856.0140227331058
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2298784 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65952720905653
# 856.0140072549826
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1936278 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65952720905653
# 856.0140072549826
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1677026 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65952782983186
# 856.0140072549826
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4040771 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# 10
# 41.65952720905653
# 856.0140200105853
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.156049 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [1.00000000e-12 4.16595272e-12 8.56014007e-11]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1588275 seconds ----------------
# ------------- Initialization and postprocessing took 0.0062338 seconds----------------

# %% [markdown]
# Fitting the sorption Data und Calculation of the Sorption MS Coefficients

# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
from diffusionpy import Diffusion_MS
from scipy.optimize import curve_fit

tsorpL1D03= np.array([0,1001,2002,3003,4004,5005,6005,7007,8008,9008,10009,11010,12010,13012,14012,15013,16015,17015,18016])
wwsorpL1D03 = np.array([1.4E-5,8.35E-3,1.443E-2,1.947E-2,2.39E-2,2.79E-2,3.158E-2,3.5E-2,3.821E-2,4.125E-2,4.413E-2,4.689E-2,4.952E-2,5.204E-2,5.447E-2,5.681E-2,5.906E-2,6.124E-2,6.336E-2])
tsorpL1D05= np.array([0,1005,2006,3007,4009,5010,6011,7013,8014,9016,10017,11018,12019,13021,14022,15023,16024,17026,18027])
wwsorpL1D05= np.array([3.1E-6,5.1E-3,7.4E-3,9E-3,1.029E-2,1.114E-2,1.238E-2,1.327E-2,1.408E-2,1.484E-2,1.554E-2,1.62E-2,1.682E-2,1.742E-2,1.798E-2,1.852E-2,1.904E-2,1.954E-2,2.002E-2])
tsorpL1D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL1D07= np.array([0,1.82E-3,2.59E-3,3.08E-3,3.46E-3,3.77E-3,4.04E-3,4.29E-3,4.51E-3,4.71E-3,4.91E-3,5.09E-3,5.26E-3,5.42E-3,5.58E-3,5.73E-3])
tsorpL25D03= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D03= np.array([6.6E-6,4.128E-2,6.4E-2,8.099E-2,9.493E-2,0.10691,0.11746,0.12691,0.13548,0.14328,0.15036,0.15677,0.1625,0.1676,0.1721,0.17607,0.17955,0.18263,0.18535])
tsorpL25D05= np.array([0,1001,2003,3004,4006,5007,6008,7010,8011,9012,10013,11015,12016,13018,14019,15020,16022,17023,18025])
wwsorpL25D05= np.array([1.1E-4,2.438E-2,3.352E-2,3.902E-2,4.284E-2,4.581E-2,4.825E-2,5.048E-2,5.25E-2,5.435E-2,5.606E-2,5.773E-2,5.913E-2,6.056E-2,6.194E-2,6.314E-2,6.429E-2,6.556E-2,6.656E-2])
tsorpL25D07= np.array([0,1200,2400,3600,4800,6000,7200,8400,9600,10800,12000,13200,14400,15600,16800,18000])
wwsorpL25D07= np.array([0,8.1E-3,1.106E-2,1.32E-2,1.494E-2,1.642E-2,1.771E-2,1.887E-2,1.994E-2,2.0904E-2,2.1806E-2,2.2643E-2,2.343E-2,2.417E-2,2.487E-2,2.554E-2])
wi_0= np.array([0.9999,0.0001])
mobile =np.array([True, True])
Mi0= np.asarray([357.79,65000,16.02])



def Choose_Sorp(L_ASD,DL_ASD):
    if L_ASD == 1 and DL_ASD == 0.3:
        t_sorp= tsorpL1D03
        ww_sorp= wwsorpL1D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==1 and DL_ASD ==0.5: 
        t_sorp= tsorpL1D05
        ww_sorp= wwsorpL1D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==1 and DL_ASD ==0.7: 
        t_sorp= tsorpL1D07
        ww_sorp= wwsorpL1D07
        wi_8 = np.array([0.9405,0.0505])
    elif L_ASD == 0.25 and DL_ASD == 0.3:
        t_sorp= tsorpL25D03
        ww_sorp= wwsorpL25D03
        wi_8 = np.array([0.8521,0.1479])
    elif L_ASD==0.25 and DL_ASD ==0.5: 
        t_sorp= tsorpL25D05
        ww_sorp= wwsorpL25D05
        wi_8 = np.array([0.9054,0.0946])
    elif L_ASD==0.25 and DL_ASD ==0.7: 
        t_sorp= tsorpL25D07
        ww_sorp= wwsorpL25D07
        wi_8 = np.array([0.9405,0.0505])
    else: print('Bitte gültige Länge und Drugload eingeben!')
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    L= L_ASD*10E-4
    w_APIPol= 1-ww_sorp
    M_APIPol= 1/((DL_ASD/Mi0[0])+((1-DL_ASD)/Mi0[1])) #Mittlere molare Masse
    Mi = np.array([M_APIPol,16.02])
    from numpy import array

    def fit_Diff_Sorp (ww_sorp,w_APIPol):
        def Diff_for_fit(t,D_sorp):
            Dscale=1E13 #Hilfsvariable
            Dsorp_norm=np.array([D_sorp])/Dscale #Normieren des Diffusionskoeffs (DKs)
            print(Dsorp_norm) #Ausgeben des normierten DKs
            ww=Diffusion_MS(t,L,Dsorp_norm,wi_0,wi_8,Mi,mobile) #Ouput ist 2D
            return ww[:,1] #Rückgabe von w_H2O in ww
        Dscale=1E13
        qopt_H2O, qcov_H2O= curve_fit(Diff_for_fit,t_sorp,ww_sorp,bounds=(1E-6,1E10),p0=(10000)) #Einsetzen von normierten DKs in Solver
        Dsorpopt=qopt_H2O/Dscale #Zurückskalieren der optimierten DKs in Array
        print(Dsorpopt)
        
        return Dsorpopt
    Dsorpopt= fit_Diff_Sorp(ww_sorp,w_APIPol)
    ww= Diffusion_MS(t,L,Dsorpopt,wi_0,wi_8,Mi,mobile)
    return ww, Dsorpopt, t_sorp, ww_sorp
    

def plot_sorp (t_sorp, ww_sorp):
    plt.plot(t_sorp,ww_sorp,'bo')
    plt.xlabel('t [s]')
    plt.ylabel('ww [-]')

def plot_fit_sorp (L,DL):
    list =[]
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(L,DL)
    nt=len(t_sorp)
    t=np.linspace(0,t_sorp[-1]**0.5,nt)**2
    plt.plot(t, ww [:,1],'b-')
    plot_sorp (t_sorp, ww_sorp)
    #xL = np.linspace(0.3,0.7,3)
    #for D in xL:
    #    a,b,c,d = Choose_Sorp(L,D)
    #    list.append(b)
    #Dvec_sorp= np.array(list)
    #fig,axis = plt.subplots()
    #axis.plot(xL,Dvec_sorp,'b*')

def Export_to_Excel (ASD_L,DL):
    ww, Dsorpopt, t_sorp, ww_sorp= Choose_Sorp(ASD_L,DL)
    index_Dvec =['DASD/DH2O']
    columns= ['1E-9']
    df_Dvec= pd.DataFrame(Dsorpopt,index = index_Dvec, columns=columns)
    with pd.ExcelWriter(r"C:\Users\Justin\Documents\Bachelorarbeit\Exp._Data.xlsx",mode='a',if_sheet_exists='overlay', engine='openpyxl') as writer:
        df_Dvec.to_excel(excel_writer=writer,sheet_name= 'Sheet2', startrow=52, startcol=14)

    



plot_fit_sorp(0.25,0.7)
Export_to_Excel(0.25,0.7)
# Out:
# [1.e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0186643 seconds ----------------
# ------------- Initialization and postprocessing took 0.0009963 seconds----------------
# [1.00000001e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0357766 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0327112 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.00000003e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0339497 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.24999987e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0257448 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.24999991e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0320772 seconds ----------------
# ------------- Initialization and postprocessing took 0.0007298 seconds----------------
# [2.31249984e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.033607 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.31249987e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0271168 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.32812483e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0265519 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010245 seconds----------------
# [2.32812486e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0329349 seconds ----------------
# ------------- Initialization and postprocessing took 0.0020044 seconds----------------
# [2.33203107e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0290727 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33203111e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0356142 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010496 seconds----------------
# [2.33300763e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0173666 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33300767e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.03088 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010301 seconds----------------
# [2.33325178e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0338084 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33325181e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0183782 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331281e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0277925 seconds ----------------
# ------------- Initialization and postprocessing took 0.0061509 seconds----------------
# [2.33331285e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0296443 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013241 seconds----------------
# [2.33332807e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0173674 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010449 seconds----------------
# [2.33331663e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0164585 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331376e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0255738 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331305e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0300111 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331287e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0247206 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.3333129e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0249326 seconds ----------------
# ------------- Initialization and postprocessing took 0.0016061 seconds----------------
# [2.33331287e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0223666 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005398 seconds----------------
# [1.e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0163388 seconds ----------------
# ------------- Initialization and postprocessing took 0.014044 seconds----------------
# [1.00000001e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0172548 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0157395 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.00000003e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0315022 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.24999987e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0356592 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005483 seconds----------------
# [2.24999991e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0330593 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.31249984e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0224878 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029948 seconds----------------
# [2.31249987e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0327444 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015493 seconds----------------
# [2.32812483e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.018366 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.32812486e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0227032 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33203107e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0156215 seconds ----------------
# ------------- Initialization and postprocessing took 0.0156231 seconds----------------
# [2.33203111e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0346758 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33300763e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0255292 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005441 seconds----------------
# [2.33300767e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0206686 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33325178e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0312407 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33325181e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0306118 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331281e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0312871 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331285e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0323929 seconds ----------------
# ------------- Initialization and postprocessing took 0.0005353 seconds----------------
# [2.33332807e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0353206 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331663e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.030213 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331376e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0247772 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331305e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0316201 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331287e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0275767 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.3333129e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0317818 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# [2.33331287e-09]
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0315875 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3.ipynb Cell 13 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=102'>103</a>         df_Dvec.to_excel(excel_writer=writer,sheet_name= 'Sheet2', startrow=52, startcol=14)
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=108'>109</a> plot_fit_sorp(0.25,0.7)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=109'>110</a> Export_to_Excel(0.25,0.7)
#
# c:\GitHub_Projects\diffusionpy\examples_notebooks\001_First_approach_ideal_v3.ipynb Cell 13 line 1
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=99'>100</a> columns= ['1E-9']
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=100'>101</a> df_Dvec= pd.DataFrame(Dsorpopt,index = index_Dvec, columns=columns)
# --> <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=101'>102</a> with pd.ExcelWriter(r"C:\Users\Justin\Documents\Bachelorarbeit\Exp._Data.xlsx",mode='a',if_sheet_exists='overlay', engine='openpyxl') as writer:
#     <a href='vscode-notebook-cell:/c%3A/GitHub_Projects/diffusionpy/examples_notebooks/001_First_approach_ideal_v3.ipynb#X15sZmlsZQ%3D%3D?line=102'>103</a>     df_Dvec.to_excel(excel_writer=writer,sheet_name= 'Sheet2', startrow=52, startcol=14)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\excel\_base.py:1219, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1215 self._handles = IOHandles(
#    1216     cast(IO[bytes], path), compression={"compression": None}
#    1217 )
#    1218 if not isinstance(path, ExcelWriter):
# -> 1219     self._handles = get_handle(
#    1220         path, mode, storage_options=storage_options, is_text=False
#    1221     )
#    1222 self._cur_sheet = None
#    1224 if date_format is None:
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Justin\\Documents\\Bachelorarbeit\\Exp._Data.xlsx'

# %% [markdown]
# First model

# %%
mobile= np.asarray([True,True,True])
nt=80
t=np.linspace(0,texp[-1]**0.5,nt)**2    
import time

wt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,nz=20)

color1 = "#99CDE9"
color2 = "#F08208"
color3 = "#99CC00"

fig,ax=origin_like.subplots()

origin_like.plot(ax,t,wt[:,0],"c-")
origin_like.plot(ax,t,wt[:,1],"r-")
origin_like.plot(ax,t,wt[:,2],"b-")
origin_like.plot(ax,texp,wINDL1D03,"co")
origin_like.plot(ax,texp,wPolL1D03,"ro")
origin_like.set_xlabel(ax,"t","s")
origin_like.set_ylabel(ax,"w_i","-")
origin_like.set_ticks(ax,0,300,0,1)
plt.show()
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.211784 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027025 seconds----------------

# %% [markdown]
# First try of an fitting function: leastsq

# %%
import numpy as np
from scipy.optimize import leastsq
from scipy.optimize import curve_fit
import scipy as sc
import matplotlib.pyplot as plt

x= np.array([1,3,4,5,7,8,12,15,19,24])
y = np.array([3,7,14,25,41,48,59,73,78,95])

plt.plot(x,y,'ro')

def funcline (x,a,b):
    return a*x+b
def funcquad (x,a,b,c):
    return a*x**2+b*x+c   

X= np.linspace(x.min(),x.max(),50)
popt, pcov = curve_fit(funcline,x,y)
print(popt)
plt.plot(x,funcline(x, *popt))

qopt, qcov= curve_fit(funcquad,x,y)
plt.plot(x,funcquad(x,*qopt))
# Out:
# [4.12009419 3.92307692]

# %% [markdown]
# Correlation Between Diffusion Coeffs. and Drugload

# %%
import numpy as np

D3an103= np.array([0.000829016, 0.001006316, 0.001120834, 0.000711376, 0.000725273])
DLan103= np.array([2.129266346, 1.978956849, 1.895270904, 2.242795041, 2.23009888])
D3an105= np.array([0.023122705,0.017898807,0.033487196,0.02260883,0.01043749,0.003487154,0.000209907])
DLan105= np.array([1.120853854,1.365432671,0.744372507,1.406673126,1.707384131,1.691839457,1.821849459])
D3an2503= np.array([0.002857259,0.002960762,0.002994224,0.002798141,0.0026755])
DLan2503= np.array([2.129436909,2.093832443,2.072496532,2.105566472,2.157690245])
D3an2505= np.array([0.006739994,0.002250945,0.00446893,0.002631958])
DLan2505= np.array([1.467047509,1.757523731,1.583733273,1.725752866])

def lin_Pearson_correlation(x,y):
    if len(x)==len(y):
        Sum_xy = sum((x-x.mean())*(y-y.mean()))
        Sum_x_squared = sum((x-x.mean())**2)
        Sum_y_squared = sum((y-y.mean())**2)       
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr
             
print(lin_Pearson_correlation(D3an2505,DLan2505))

def quad_Pearson_correlation(x,y):
    A= 195.71
    B=-0.0486
    C=454.96E-6
    if len(x)==len(y):
        X= B*x + A
        Y= y -C*x
        sigmaX =np.sqrt(sum(X-X.mean())**2/len(X))
        sigmaY=np.sqrt(sum(Y-Y.mean())**2/len(Y))
        CovXY= sum((X-X.mean())*(Y-Y.mean()))
        corrquad= CovXY/(sigmaX*sigmaY)
    return corrquad

print(quad_Pearson_correlation(D3an103,DLan103))
# Out:
# -0.9942838520049285
# 2.022973394682165e+23
