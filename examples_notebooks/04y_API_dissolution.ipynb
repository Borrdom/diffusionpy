# %% [markdown]
# # Stefan-Maxwell diffusion involving three components

# %% [markdown]
# This example demonstrates the modeling of the multicomponent Stefan-Maxwell model involving three componentt.
# First we import the Stefan-Maxwell diffusion module

# %%
import numpy as np
from numpy import array
from diffusionpy import Diffusion_MS,D_Matrix,Diffusion_MS_iter,vpure,dlnai_dlnxi,lngi,dlnai_dlnxi_loop,massbalancecorrection
import matplotlib.pyplot as plt

# %% [markdown]
# experimental data

# %%
texp=array([5,15,30,60,90,120,150,180,210,240,270,300])
wL1D03=array([[5.1687E-06,	3.42274E-07, 9.99994489e-01],
        [8.11419000e-06, 6.63373000e-07, 9.99991222e-01],
       [1.16988000e-05, 1.30293000e-06, 9.99986998e-01],
       [1.82872000e-05, 2.61848000e-06, 9.99979094e-01],
       [2.43481000e-05, 4.06235000e-06, 9.99971590e-01],
       [2.97692000e-05, 5.50577000e-06, 9.99964725e-01],
       [3.50846000e-05, 7.11082000e-06, 9.99957805e-01],
       [3.91787000e-05, 8.82865000e-06, 9.99951993e-01],
       [4.30863000e-05, 1.03757000e-05, 9.99946538e-01],
       [4.68326000e-05, 1.22831000e-05, 9.99940884e-01],
       [4.92799000e-05, 1.34226000e-05, 9.99937297e-01],
       [5.08487000e-05, 1.48856000e-05, 9.99934266e-01]])

# wL1D03=array([[2.47540000e-06, 3.38334000e-07, 9.99997186e-01],
#        [5.76787000e-06, 7.27514000e-07, 9.99993505e-01],
#        [9.85161000e-06, 1.13529000e-06, 9.99989013e-01],
#        [1.43790000e-05, 2.29403000e-06, 9.99983327e-01],
#        [1.61947000e-05, 3.20807000e-06, 9.99980597e-01],
#        [1.67283000e-05, 4.11030000e-06, 9.99979161e-01],
#        [1.71512000e-05, 4.97144000e-06, 9.99977877e-01],
#        [1.73003000e-05, 5.76267000e-06, 9.99976937e-01],
#        [1.73463000e-05, 6.66612000e-06, 9.99975988e-01],
#        [1.71751000e-05, 7.58597000e-06, 9.99975239e-01],
#        [1.73692000e-05, 8.33222000e-06, 9.99974299e-01],
#        [1.75724000e-05, 9.19885000e-06, 9.99973229e-01]])

msol=500000
m0=array([43.491+18.639,0])
ww0=0.01
dl0=1
dl8=1
wi0=np.asarray([dl0*(1-ww0),ww0])
# release=wL1D03*msol/m0
# notreleased=1-release
# wexp=notreleased*wi0
# wexp[:,2]=1-wexp[:,0]-wexp[:,1]

wexp=wL1D03

# %% [markdown]
# We want to describe the diffusion of water into an ASD film. The ASD-water mixture is a ternary system. First we define starting and equilibrium weight fractions.

# %%
nc=2
L=0.001
ww8=0.14
# ww8=0.99999
wi8=np.asarray([dl8*(1-ww8),ww8])
Mi=np.asarray([357.57,18.015])
T=298.15
p=1E5

kij=D_Matrix(np.asarray([-0.025]),nc)
par={"mi":np.asarray([ 14.283,1.20469]),
"si": np.asarray([ 3.535,2.797059952]),
"ui" :np.asarray([262.79,353.95]),
"eAi" :np.asarray([ 886.4,2425.67]),
"kAi":np.asarray([ 0.02,0.04509]),
"NAi":np.asarray([3.,1.]),
"Mi": Mi,
"kij":kij,
"kijA":np.asarray([[0.]])}

vpures=vpure(p,T,**par)
par["vpure"]=vpures
lngi_fun=lambda wi :lngi(T,wi,**par)
mobile=np.asarray([True,False])
dlnai_dlnwi_fun=lambda wi: massbalancecorrection(dlnai_dlnxi_loop(T,np.ascontiguousarray(wi),**par),wi,wi0,Mi,mobile)

# %% [markdown]
# For a the diffusion of three components, three binary diffusion coefficients need to be defined

# %% [markdown]
# $\hat{Ð} =$
# $\left[\begin{array}{rrr}
# 0 & Ð_{12} & Ð_{13} \\
# 0 & 0 & Ð_{23} \\
# 0 & 0 & 0 \\
# \end{array}\right]$
#
# $Ð_{vec} = \left[\begin{array}{rrr} Ð_{12} & Ð_{13} & Ð_{23} \end{array}\right]$

# %%
Dvec=np.asarray([6E-13,2E-12,1E-12]) #ideal
# Dvec=np.asarray([1E-13,1E-14,1E-14]) #real
# Dvec=np.asarray([1E-13,1E-13,1E-13])
Dvec=np.asarray([10E-12])*10 #real

# %% [markdown]
# Next we define the time array and which component is mobile

# %%
nt=21
t=np.linspace(0,(300*60)**0.5,nt)**2
# t=np.linspace(0,(22000)**0.5,nt)**2

# mobile=np.asarray([False,False,True])

# %%
wt,wtz,zvec,Lt=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,swelling=True,full_output=True,nz=20)
taui=np.asarray([500])
from diffusionpy.surface_activity import time_dep_surface
witB=time_dep_surface(t,wi0,wi8,np.asarray([True,False]),taui)

wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,Mi,mobile,full_output=True,swelling=True,dlnai_dlnwi_fun=dlnai_dlnwi_fun,method="weg",maxit=9,nz=20)
notreleased=wt/wi0
release=1-notreleased# wtid=Diffusion_MS(t,L,Dvec,wi0,wi8,Mi,mobile,swelling=True)

wt=m0/msol*release
wt[:,1]=1-wt[:,0]
wtid=wt
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2107183 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2912941 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011714 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0626723 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9843062 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0467935 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9135218 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 1: ||F|| = 0.0015791884019094966
# iter 1: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0435355 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.433149 seconds ----------------
# ------------- Initialization and postprocessing took 0.0013078 seconds----------------
# iter 2: ||F|| = 0.0012402001910137856
# iter 2: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0367566 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8657928 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 3: ||F|| = 0.0018195741109166697
# iter 3: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0324317 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.8931646 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029022 seconds----------------
# iter 4: ||F|| = 0.0011093934013330729
# iter 4: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0359165 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9193511 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 5: ||F|| = 0.0011953775050265723
# iter 5: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0491402 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0104981 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010083 seconds----------------
# iter 6: ||F|| = 0.0008713874603702053
# iter 6: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.039716 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1697006 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 7: ||F|| = 0.0004068481259708682
# iter 7: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0477357 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3788408 seconds ----------------
# ------------- Initialization and postprocessing took 0.011375 seconds----------------
# iter 8: ||F|| = 0.0007816882475135037
# iter 8: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0382531 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0729997 seconds ----------------
# ------------- Initialization and postprocessing took 0.002461 seconds----------------
# iter 9: ||F|| = 0.0005528867470863501
# iter 9: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0322385 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2338419 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 10: ||F|| = 0.00047910220049166127
# iter 10: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0397252 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4148503 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010356 seconds----------------
# iter 11: ||F|| = 0.000998132861291846
# iter 11: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0403312 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.9955835 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 12: ||F|| = 0.0017783857907164662
# iter 12: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0375535 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 4.2899263 seconds ----------------
# ------------- Initialization and postprocessing took 0.0093449 seconds----------------
# iter 13: ||F|| = 0.0013263101430676476
# iter 13: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0604499 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.2188068 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 14: ||F|| = 0.0009676732277259662
# iter 14: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0422988 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1475297 seconds ----------------
# ------------- Initialization and postprocessing took 0.0011716 seconds----------------
# iter 15: ||F|| = 0.0010352676815231175
# iter 15: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0376445 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3170614 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 16: ||F|| = 0.0005898592387283806
# iter 16: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0334306 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4336616 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010346 seconds----------------
# iter 17: ||F|| = 0.0007001723548258012
# iter 17: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0281277 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0347756 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 18: ||F|| = 0.0006176084826387219
# iter 18: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0472581 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.4534963 seconds ----------------
# ------------- Initialization and postprocessing took 0.0 seconds----------------
# iter 19: ||F|| = 0.0011614136217588543
# iter 19: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0397422 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.0472205 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015775 seconds----------------
# iter 20: ||F|| = 0.001420441068652083
# iter 20: q = 0.0
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.0427628 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.1736753 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019575 seconds----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 1.3113992 seconds ----------------
# ------------- Initialization and postprocessing took 0.0010018 seconds----------------

# %% [markdown]
# We can determine the mass dissolved in the dissolution medium by quantifying the mass that leaves the ASD. The initial mass of the ASD and the mass of the dissolution medium must be known

# %% [markdown]
# We plot the results

# %%
font = {'weight' : 'normal',
        'size'   : 12}
plt.rc('font', **font)

color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig, ax = plt.subplots(figsize=(5, 4), dpi = 200)
fig.subplots_adjust(hspace=0.5, wspace=0.3)

# ax.plot(t/60,wtid[:,0], "--",color = color1 , 
#         linewidth = 2.0, label = "wPol")
# ax.plot(t/60,wtid[:,1], "--",color = color2 , 
#         linewidth = 2.0, label = "wAPI")

ax.plot(t/60,wt[:,1], "-",color = color1 , 
        linewidth = 2.0, label = "wPol")
ax.plot(t/60,wt[:,0], "-",color = color2 , 
        linewidth = 2.0, label = "wAPI")

ax.plot(texp,wexp[:,0], "ro",color = color1 , 
        linewidth = 2.0, label = "wPol")
ax.plot(texp,wexp[:,1], "go",color = color2 , 
        linewidth = 2.0, label = "wAPI")



ax.legend(fontsize="small")
ax.set_xlabel('$t$ / s')
ax.set_ylabel('$wi$ / -')
ax.axis([0, 300., 0., 6E-5])
start, end = ax.get_xlim()
ax.xaxis.set_ticks(np.linspace(start, end, 5))
start, end = ax.get_ylim()
ax.yaxis.set_ticks(np.linspace(start, end, 5))
plt.show()



# ax2.plot(zexp2*Lt[0],tolu, "o")

# %%
color1 = "#99CC00"
color2 = "#F08208"
color3 = "#99CDE9"

fig1, ax1 = plt.subplots(figsize=(5, 4), dpi = 200)
fig2, ax2 = plt.subplots(figsize=(5, 4), dpi = 200)
fig3, ax3 = plt.subplots(figsize=(5, 4), dpi = 200)
fig1.subplots_adjust(hspace=0.5, wspace=0.3)
fig2.subplots_adjust(hspace=0.5, wspace=0.3)
fig3.subplots_adjust(hspace=0.5, wspace=0.3)
ax1.set_xlabel('$z$ / µm')
ax1.set_ylabel('$wi$ / -')
ax2.set_xlabel('$z$ / µm')
ax2.set_ylabel('$wi$ / -')
ax3.set_xlabel('$z$ / µm')
ax3.set_ylabel('$wi$ / -')
[ax1.plot(zvec*1E6,wtz[i,0,:], "-",color = color1 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]
# ax1.plot(zexp1*Lt[0],meth, "o")

[ax2.plot(zvec*1E6,wtz[i,1,:], "-",color = color2 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]

# [ax3.plot(zvec*1E6,wtz[i,2,:], "-",color = color3 , linewidth = 2.0) for i,val in enumerate(wtz[:,0,0])]
# Out:
# [[<matplotlib.lines.Line2D at 0x20df2f52f10>],
#  [<matplotlib.lines.Line2D at 0x20df35a6310>],
#  [<matplotlib.lines.Line2D at 0x20df35a6c50>],
#  [<matplotlib.lines.Line2D at 0x20df35a74d0>],
#  [<matplotlib.lines.Line2D at 0x20df35a7d50>],
#  [<matplotlib.lines.Line2D at 0x20df35ac690>],
#  [<matplotlib.lines.Line2D at 0x20df35acf50>],
#  [<matplotlib.lines.Line2D at 0x20df35ad7d0>],
#  [<matplotlib.lines.Line2D at 0x20df35ae0d0>],
#  [<matplotlib.lines.Line2D at 0x20df35ae8d0>],
#  [<matplotlib.lines.Line2D at 0x20df35af0d0>],
#  [<matplotlib.lines.Line2D at 0x20df35afa10>],
#  [<matplotlib.lines.Line2D at 0x20df35b0310>],
#  [<matplotlib.lines.Line2D at 0x20df35b0b50>],
#  [<matplotlib.lines.Line2D at 0x20df35b13d0>],
#  [<matplotlib.lines.Line2D at 0x20df35b1c90>],
#  [<matplotlib.lines.Line2D at 0x20df35b25d0>],
#  [<matplotlib.lines.Line2D at 0x20df35b2ed0>],
#  [<matplotlib.lines.Line2D at 0x20df35b3810>],
#  [<matplotlib.lines.Line2D at 0x20df35b8110>],
#  [<matplotlib.lines.Line2D at 0x20df35b8a10>]]
