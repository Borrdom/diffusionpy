# %%
import numpy as np
from diffusionpy import Diffusion_MS,vpure,D_Matrix,Diffusion_MS_iter,lngi,time_dep_surface,DIdeal2DReal,Gammaij
import matplotlib.pyplot as plt

T=303.15
p=1E5
nc=2 # number of components
L=0.0185 # estimated thickness of the film


mobile=np.asarray([True,False])
wi0=np.asarray([0.9,0.1])
wi8=np.asarray([0.01,0.98])
taui=np.asarray([35711.02587])
kijvec=np.asarray([-0.128000])
kijHBvec=np.asarray([0.])
Mi=np.asarray([18.015,65000.])
mi=np.asarray([1.2047,2420.99])
sigi=np.asarray([2.79533,2.947])
ui=np.asarray([353.95,205.27])
epsAiBi=np.asarray([2425.7,0.])
kAiBi=np.asarray([0.045099,0.02])
Na=np.asarray([1.,653.])
vpures=vpure(p,T,mi,sigi,ui,epsAiBi,kAiBi,Na)
t=np.linspace(0,(1600*60)**0.5,51)**2
kij=D_Matrix(kijvec,nc)
kijHB=D_Matrix(kijHBvec,nc)
par={"mi":mi,
"si": sigi,
"ui" :ui,
"eAi" :epsAiBi,
"kAi":kAiBi,
"NAi":Na,
"Mi": Mi,
"kij":kij,
"kijA":kijHB,
"vpure":vpures}
mobiles=np.where(mobile)[0]
# dlnai_dlnwi_fun=lambda wi: massbalancecorrection(dlnai_dlnxi_loop(T,np.ascontiguousarray(wi),**par)*wi[:,:,:,None],wi,wi0,Mi,mobile)
dlnai_dlnwi_fun=lambda wi: Gammaij(T,wi,par)

Dvec=np.asarray([1.69E-8])

witB=time_dep_surface(t,wi0,wi8,mobile,taui)
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,Dvec,wi0,wi8,mobile,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB)
# Out:
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.0833199 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025114 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6461929 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1486258 seconds ----------------
# ------------- Initialization and postprocessing took 0.0028447 seconds----------------
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6709593 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.1910139 seconds ----------------
# ------------- Initialization and postprocessing took 0.002851 seconds----------------
# iter 1: ||F|| = 0.0013411135213572604
# iter 1: q = 0.10155371935749781
# ------------- Start PC-SAFT modeling ----------------
# C:\GitHub_Projects\diffusionpy\diffusionpy\diffusion.py:307: RuntimeWarning: invalid value encountered in divide
#   a = df/dx
# ------------- PC-SAFT modeling took 0.6573293 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2026523 seconds ----------------
# ------------- Initialization and postprocessing took 0.0032125 seconds----------------
# iter 2: ||F|| = 0.0007617752954645707
# iter 2: q = 0.21542070342039024
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.649113 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2235816 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029963 seconds----------------
# iter 3: ||F|| = 0.000352207257997089
# iter 3: q = 0.26043057479105336
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6525908 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2135463 seconds ----------------
# ------------- Initialization and postprocessing took 0.0015044 seconds----------------
# iter 4: ||F|| = 0.00011788335312510938
# iter 4: q = 0.1958130049427022
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6526371 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2372734 seconds ----------------
# ------------- Initialization and postprocessing took 0.0025968 seconds----------------
# iter 5: ||F|| = 5.54130395811938e-05
# iter 5: q = 0.2396856866590185
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6749487 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2132536 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027609 seconds----------------
# iter 6: ||F|| = 3.1835505239483825e-05
# iter 6: q = 0.2246470043724276
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6093511 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2508834 seconds ----------------
# ------------- Initialization and postprocessing took 0.0028795 seconds----------------
# iter 7: ||F|| = 1.0974265662961485e-05
# iter 7: q = 0.22852563338295168
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6342084 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2695507 seconds ----------------
# ------------- Initialization and postprocessing took 0.0018427 seconds----------------
# iter 8: ||F|| = 4.461586389022753e-06
# iter 8: q = 0.23265263387375543
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6642692 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2633939 seconds ----------------
# ------------- Initialization and postprocessing took 0.0016845 seconds----------------
# iter 9: ||F|| = 2.4965804898723954e-06
# iter 9: q = 0.22208935052015097
# ------------- Start PC-SAFT modeling ----------------
# C:\GitHub_Projects\diffusionpy\diffusionpy\diffusion.py:308: RuntimeWarning: divide by zero encountered in divide
#   q= np.average(np.fmin(np.fmax(np.nan_to_num(a/(a-1),nan=0,posinf=0,neginf=0),0),1))
# ------------- PC-SAFT modeling took 0.6178023 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2379857 seconds ----------------
# ------------- Initialization and postprocessing took 0.0019993 seconds----------------
# iter 10: ||F|| = 1.221002353152437e-06
# iter 10: q = 0.22634455971992876
# ------------- Start PC-SAFT modeling ----------------
# ------------- PC-SAFT modeling took 0.6470372 seconds ----------------
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2689609 seconds ----------------
# ------------- Initialization and postprocessing took 0.0029992 seconds----------------
# iter 11: ||F|| = 5.28453276975923e-07
# ------------- Initialization and postprocessing ----------------
# ------------- Start diffusion modeling ----------------
# ------------- Diffusion modeling took 0.2860749 seconds ----------------
# ------------- Initialization and postprocessing took 0.0027988 seconds----------------

# %%
texpw=np.asarray([0,60,120,193,250,296,330,410,470,530,570,630,691,754,810,1780])
wexpw=np.asarray([0.9,0.89299,0.8846,0.88365,0.86635,0.86052,0.8531,0.83376,0.8072,0.77584,0.75664,0.71119,0.64861,0.56269,0.34671,0.03925])

texpe=np.asarray([0,64,120,177,247,301,347,407,2000])
wexpe=np.asarray([0.9,0.84537,0.68653,0.47765,0.36149,0.33674,0.29972,0.27454,0.07407])

texpp=np.asarray([0,60,128,160,222,283,343,400,510,635,1572])
wexpp1=np.asarray([0.10222,0.10793,0.11579,0.11968,0.11112,0.08517,0.06692,0.05747,0.04321,0.03578,0.01578])
wexpp2=np.asarray([0.79779,0.75332,0.66681,0.60852,0.40236,0.33188,0.31786,0.31535,0.29871,0.24788,0.14054])
wexpp3=np.asarray([0.1,0.13875,0.21739,0.2718,0.48652,0.58294,0.61522,0.62718,0.65808,0.71633,0.84368])






fig,ax=plt.subplots()
ax.plot(texpw,wexpw,'C1s')
ax.plot(texpw,1-wexpw,'C5o')

fig2,ax2=plt.subplots()
ax2.plot(texpe,wexpe,'C1s')
ax2.plot(texpe,1-wexpe,'C5o')



fig3,ax3=plt.subplots()
ax3.plot(texpp,wexpp1,'C1s')
ax3.plot(texpp,wexpp2,'C5o')
ax3.plot(texpp,wexpp3,'C3^')

ax.plot(t/60,wt[:,0],'C1-')
ax.plot(t/60,wt[:,1],'C5-')
# ax3.plot(t/60,wt[:,2],'C3-')
plt.show()

# %%
texp=np.asarray([0.,20.83333333,62.5,125,191.6666667,241.6666667,287.5,333.3333333,408.3333333,466.6666667,516.6666667,579.1666667,1525])
w1exp=np.asarray([0.1,0.096803653,0.107468124,0.115349682,0.119496855,0.093297101,0.057657658,0.049818841,0.036231884,0.033423668,0.025157233,0.019927536,0.009981851])
w2exp=np.asarray([0.8,0.806392694,0.746812386,0.67938238,0.421383648,0.365036232,0.29009009,0.280797101,0.264492754,0.258355917,0.224618149,0.210144928,0.158802178])
w3exp=np.asarray([0.1,0.096803653,0.14571949,0.205267938,0.459119497,0.541666667,0.652252252,0.669384058,0.699275362,0.708220416,0.750224618,0.769927536,0.831215971])
witB2=time_dep_surface(texp,wi0,wi8,mobile,taui)

import scipy
def fun(x,D1,D2):
    print(10**D1)
    print(10**D2)
    # witB2=time_dep_surface(x*60,wi0,wi8,mobile,np.asarray([10**tau1,10**tau2]))
    res=Diffusion_MS_iter(x,L,np.asarray([1E-6,10**D1,10**D1,10**D2,10**D2,1E-21]),wi0,wi8,mobile,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB2,nz=7)[0][:,0]
    print(res)
    return res

Dvecopt=scipy.optimize.curve_fit(fun,texp*60,w1exp,p0=(-9,-9),bounds=([-11,-11],[-6,-6]))[0]
D1=Dvecopt[0]
D2=Dvecopt[1]
wt,wtz,zvec,Lt=Diffusion_MS_iter(t,L,np.asarray([1E-6,10**D1,10**D1,10**D2,10**D2,1E-21]),wi0,wi8,mobile,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB,nz=21)
print(np.asarray([1E-6,10**D1,10**D1,10**D2,10**D2,1E-21]))


fig,ax=plt.subplots()
ax.plot(t/60,wt[:,0],'C1-')
ax.plot(t/60,wt[:,1],'C3-')
ax.plot(t/60,wt[:,2]+wt[:,3],'C0-')
ax.plot(texp,w1exp,'C1o')
ax.plot(texp,w2exp,'C3o')
ax.plot(texp,w3exp,'C0o')
ax.set_xlabel("t/min")
ax.set_ylabel("$w_i$/-")

plt.xlim([0,2000])
plt.ylim([0,1])
# Out:
# 1e-09
# 1e-09
# ------------- Initialization and postprocessing ----------------
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[3], line 16
#      13     print(res)
#      14     return res
# ---> 16 Dvecopt=scipy.optimize.curve_fit(fun,texp*60,w1exp,p0=(-9,-9),bounds=([-11,-11],[-6,-6]))[0]
#      17 D1=Dvecopt[0]
#      18 D2=Dvecopt[1]
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:974, in curve_fit(f, xdata, ydata, p0, sigma, absolute_sigma, check_finite, bounds, method, jac, full_output, nan_policy, **kwargs)
#     971 if 'max_nfev' not in kwargs:
#     972     kwargs['max_nfev'] = kwargs.pop('maxfev', None)
# --> 974 res = least_squares(func, p0, jac=jac, bounds=bounds, method=method,
#     975                     **kwargs)
#     977 if not res.success:
#     978     raise RuntimeError("Optimal parameters not found: " + res.message)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:830, in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     827 def fun_wrapped(x):
#     828     return np.atleast_1d(fun(x, *args, **kwargs))
# --> 830 f0 = fun_wrapped(x0)
#     832 if f0.ndim != 1:
#     833     raise ValueError("`fun` must return at most 1-d array_like. "
#     834                      "f0.shape: {}".format(f0.shape))
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_lsq\least_squares.py:828, in least_squares.<locals>.fun_wrapped(x)
#     827 def fun_wrapped(x):
# --> 828     return np.atleast_1d(fun(x, *args, **kwargs))
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:507, in _lightweight_memoizer.<locals>._memoized_func(params)
#     504 if np.all(_memoized_func.last_params == params):
#     505     return _memoized_func.last_val
# --> 507 val = f(params)
#     509 if _memoized_func.last_params is None:
#     510     _memoized_func.last_params = np.copy(params)
#
# File c:\Users\domin\AppData\Local\Programs\Python\Python311\Lib\site-packages\scipy\optimize\_minpack_py.py:523, in _wrap_func.<locals>.func_wrapped(params)
#     522 def func_wrapped(params):
# --> 523     return func(xdata, *params) - ydata
#
# Cell In[3], line 12, in fun(x, D1, D2)
#      10 print(10**D2)
#      11 # witB2=time_dep_surface(x*60,wi0,wi8,mobile,np.asarray([10**tau1,10**tau2]))
# ---> 12 res=Diffusion_MS_iter(x,L,np.asarray([1E-6,10**D1,10**D1,10**D2,10**D2,1E-21]),wi0,wi8,mobile,dlnai_dlnwi_fun=dlnai_dlnwi_fun,witB=witB2,nz=7)[0][:,0]
#      13 print(res)
#      14 return res
#
# File C:\GitHub_Projects\diffusionpy\diffusionpy\diffusion.py:325, in Diffusion_MS_iter(t, L, Dvec, wi0, wi8, mobile, dlnai_dlnwi_fun, **kwargs)
#     318 def Diffusion_MS_iter(t,L,Dvec,wi0,wi8,mobile,dlnai_dlnwi_fun=None,**kwargs):
#     319     """iterates dlnai_dlnwi as a function of the concentration wi
#     320     See also:
#     321         diffusionpy.Diffusion_MS
#     322
#     323     """
# --> 325     res_old=Diffusion_MS(t,L,Dvec,wi0,wi8,mobile,**kwargs)
#     326     wt_old=res_old[1]
#     327     nt,nc,nz_1=wt_old.shape
#
# File C:\GitHub_Projects\diffusionpy\diffusionpy\diffusion.py:102, in Diffusion_MS(tint, L, Dvec, wi0, wi8, mobile, dlnai_dlnwi, saftpar, **kwargs)
#     100 z=np.linspace(0,L,nz+1)
#     101 dz=L/(nz)
# --> 102 D=D_Matrix(Dvec/dz**2,nc)
#     103 zvec=z*L
#     104 nf=int(np.sum(mobile))
#
# File C:\GitHub_Projects\diffusionpy\diffusionpy\diffusion.py:221, in D_Matrix(Dvec, nc)
#     219 nd=(nc-1)*nc//2 #Anzahl der Diffusionskoeffizienten
#     220 if len(Dvec)!=nd: #Länge des Vektors der Diff.Koeffs. muss mit Anzahl der Koeffs- übereinstimmen
# --> 221     raise Exception("Wrong length of ``Dvec``. Provide array with ``(nc-1)*nc/2`` entries") #Sonst wird ein Fehler ausgegeben
#     222 else:
#     223     D=np.zeros((nc,nc)) # 0-Matrix der Dimension nc,nc wird erstellt
#
# Exception: Wrong length of ``Dvec``. Provide array with ``(nc-1)*nc/2`` entries
